# %% [markdown]
# **How to Query the RxNorm Data (BigQuery Dataset)**

# %%
import bq_helper
from bq_helper import BigQueryHelper
# https://www.kaggle.com/sohier/introduction-to-the-bq-helper-package
RxNorm = bq_helper.BigQueryHelper(active_project="bigquery-public-data",
                                   dataset_name="nlm_rxnorm")

# %%
bq_assistant = BigQueryHelper("bigquery-public-data", "nlm_rxnorm")
bq_assistant.list_tables()
# Out:
# ['rxn_all_pathways_01_18',
#  'rxn_all_pathways_02_18',
#  'rxn_all_pathways_04_17',
#  'rxn_all_pathways_05_17',
#  'rxn_all_pathways_06_17',
#  'rxn_all_pathways_07_17',
#  'rxn_all_pathways_08_17',
#  'rxn_all_pathways_09_17',
#  'rxn_all_pathways_10_17',
#  'rxn_all_pathways_11_17',
#  'rxn_all_pathways_12_17',
#  'rxn_all_pathways_current',
#  'rxnatomarchive_01_18',
#  'rxnatomarchive_02_18',
#  'rxnatomarchive_04_17',
#  'rxnatomarchive_05_17',
#  'rxnatomarchive_06_17',
#  'rxnatomarchive_07_17',
#  'rxnatomarchive_08_17',
#  'rxnatomarchive_09_17',
#  'rxnatomarchive_10_17',
#  'rxnatomarchive_11_17',
#  'rxnatomarchive_12_17',
#  'rxnatomarchive_current',
#  'rxnconso_01_18',
#  'rxnconso_02_18',
#  'rxnconso_04_17',
#  'rxnconso_05_17',
#  'rxnconso_06_17',
#  'rxnconso_07_17',
#  'rxnconso_08_17',
#  'rxnconso_09_17',
#  'rxnconso_10_17',
#  'rxnconso_11_17',
#  'rxnconso_12_17',
#  'rxnconso_current',
#  'rxncui_01_18',
#  'rxncui_02_18',
#  'rxncui_04_17',
#  'rxncui_05_17',
#  'rxncui_06_17',
#  'rxncui_07_17',
#  'rxncui_08_17',
#  'rxncui_09_17',
#  'rxncui_10_17',
#  'rxncui_11_17',
#  'rxncui_12_17',
#  'rxncui_current',
#  'rxncuichange_01_18',
#  'rxncuichange_02_18',
#  'rxncuichange_04_17',
#  'rxncuichange_05_17',
#  'rxncuichange_06_17',
#  'rxncuichange_07_17',
#  'rxncuichange_08_17',
#  'rxncuichange_09_17',
#  'rxncuichange_10_17',
#  'rxncuichange_11_17',
#  'rxncuichange_12_17',
#  'rxncuichanges_current',
#  'rxndoc_01_18',
#  'rxndoc_02_18',
#  'rxndoc_04_17',
#  'rxndoc_05_17',
#  'rxndoc_06_17',
#  'rxndoc_07_17',
#  'rxndoc_08_17',
#  'rxndoc_09_17',
#  'rxndoc_10_17',
#  'rxndoc_11_17',
#  'rxndoc_12_17',
#  'rxndoc_current',
#  'rxnrel_01_18',
#  'rxnrel_02_18',
#  'rxnrel_04_17',
#  'rxnrel_05_17',
#  'rxnrel_06_17',
#  'rxnrel_07_17',
#  'rxnrel_08_17',
#  'rxnrel_09_17',
#  'rxnrel_10_17',
#  'rxnrel_11_17',
#  'rxnrel_12_17',
#  'rxnrel_current',
#  'rxnsab_01_18',
#  'rxnsab_02_18',
#  'rxnsab_04_17',
#  'rxnsab_05_17',
#  'rxnsab_06_17',
#  'rxnsab_07_17',
#  'rxnsab_08_17',
#  'rxnsab_09_17',
#  'rxnsab_10_17',
#  'rxnsab_11_17',
#  'rxnsab_12_17',
#  'rxnsab_current',
#  'rxnsat_04_17',
#  'rxnsat_05_17',
#  'rxnsat_06_17',
#  'rxnsat_07_17',
#  'rxnsat_08_17',
#  'rxnsat_09_17',
#  'rxnsat_10_17',
#  'rxnsat_12_17',
#  'rxnsat_current',
#  'rxnsty_01_18',
#  'rxnsty_02_18',
#  'rxnsty_04_17',
#  'rxnsty_05_17',
#  'rxnsty_06_17',
#  'rxnsty_07_17',
#  'rxnsty_08_17',
#  'rxnsty_09_17',
#  'rxnsty_10_17',
#  'rxnsty_11_17',
#  'rxnsty_12_17',
#  'rxnsty_current']

# %%
bq_assistant.head("rxnsat_current", num_rows=20)
# Out:
#      rxcui lui sui    rxaui stype code atui satui                 atn  sab  \
# 0   798479          8719703   AUI   52                 VACCINE_STATUS  CVX
# 1     8471          8719840   AUI   89                            SOS  CVX
# 2   298583          8719833   AUI   33                 VACCINE_STATUS  CVX
# 3   798306          8719880   AUI   35                    NON_VACCINE  CVX
# 4    39384          8719919   AUI   21             DATE_LAST_MODIFIED  CVX
# 5   762602          8719902   AUI   25             DATE_LAST_MODIFIED  CVX
# 6    17993          8719779   AUI   65             DATE_LAST_MODIFIED  CVX
# 7   204527          8719881   AUI   35             DATE_LAST_MODIFIED  CVX
# 8   465388          8719737   AUI  111                    NON_VACCINE  CVX
# 9    29406          8719785   AUI   03                 VACCINE_STATUS  CVX
# 10  798244          8719831   AUI  100                 VACCINE_STATUS  CVX
# 11  253457          8719790   AUI   68                    NON_VACCINE  CVX
# 12  798244          8719831   AUI  100             DATE_LAST_MODIFIED  CVX
# 13  214515          8719457   AUI   50                    NON_VACCINE  CVX
# 14  798274          8719730   AUI   62                    NON_VACCINE  CVX
# 15  280071          8719803   AUI  103             DATE_LAST_MODIFIED  CVX
# 16  203033          8719815   AUI  167                 VACCINE_STATUS  CVX
# 17  200435          8719864   AUI   38             DATE_LAST_MODIFIED  CVX
# 18  214781          8719838   AUI   10                    NON_VACCINE  CVX
# 19  594251          8719852   AUI   72                    NON_VACCINE  CVX
#
#                                                   atv suppress cvf
# 0                                              Active        N
# 1   This CVX code allows reporting of a vaccinatio...        N
# 2                                              Active        N
# 3                                               FALSE        N
# 4                                          05/28/2010        N
# 5                                          05/28/2010        N
# 6                                          05/28/2010        N
# 7                                          08/14/2015        N
# 8                                               FALSE        N
# 9                                              Active        N
# 10                                           Inactive        N
# 11                                              FALSE        N
# 12                                         06/26/2014        N
# 13                                              FALSE        N
# 14                                              FALSE        N
# 15                                         05/28/2010        N
# 16                                           Inactive        N
# 17                                         05/28/2010        N
# 18                                              FALSE        N
# 19                                              FALSE        N

# %%
bq_assistant.head("rxnsab_current", num_rows=20)
# Out:
#        vcui      rcui                     vsab          rsab  \
# 0  C4518878  C3539983           CVX_2018_01_18           CVX
# 1  C4518874  C1140288         VANDF_2017_12_27         VANDF
# 2  C4505037  C1135584       MSH2018_2017_08_11           MSH
# 3  C4518880  C1371271  NDFRT_FDASPL_2018_02_05  NDFRT_FDASPL
# 4  C4518880  C1371271  NDFRT_FMTSME_2018_02_05  NDFRT_FMTSME
# 5  C4518880  C1371271         NDFRT_2018_02_05         NDFRT
# 6  C4518881  C1140284      RXNORM_17AB_180205F        RXNORM
# 7  C4518875  C1812643        MTHSPL_2018_01_25        MTHSPL
# 8  C3858950  C3858951           MTHCMSFRF_2014     MTHCMSFRF
#
#                                                  son         sf  \
# 0                  Vaccines Administered, 2017_02_08        CVX
# 1  Veterans Health Administration National Drug File      VANDF
# 2          Medical Subject Headings, 2018_2017_08_11        MSH
# 3                        National Drug File - FDASPL      NDFRT
# 4                        National Drug File - FMTSME      NDFRT
# 5                                 National Drug File      NDFRT
# 6                                  RxNorm Vocabulary     RXNORM
# 7        Metathesaurus FDA Structured Product Labels     MTHSPL
# 8         Metathesaurus CMS Formulary Reference File  MTHCMSFRF
#
#               sver      vstart vend   imeta  \
# 0       2018_01_18                   2017AB
# 1       2017_12_27                   2017AB
# 2  2018_2017_08_11                   2017AB
# 3       2018_02_05                   2017AB
# 4       2018_02_05                   2017AB
# 5       2018_02_05                   2017AB
# 6     17AB_180205F                   2017AB
# 7       2018_01_25  2006_12_21       2017AB
# 8   MTHCMSFRF_2014                   2014AB
#
#                          ...                         cfr           cxty  \
# 0                        ...
# 1                        ...
# 2                        ...                              FULL-MULTIPLE
# 3                        ...
# 4                        ...
# 5                        ...
# 6                        ...
# 7                        ...
# 8                        ...
#
#                                                 ttyl  \
# 0                                       RXN_PT,AB,PT
# 1                             IN,CD,AB,MTH_RXN_CD,PT
# 2          QAB,PM,CE,NM,PCE,PEP,DEV,QEV,N1,TQ,MH,DSV
# 3
# 4
# 5                         HT,AB,MTH_RXN_RHT,FN,PT,SY
# 6  DF,IN,GPCK,SCD,MIN,SBDF,SCDF,DFG,TMSY,PIN,BN,E...
# 7                                   DP,SU,MTH_RXN_DP
# 8                                                 PT
#
#                                                 atnl  lat   cenc curver sabin  \
# 0  DATE_LAST_MODIFIED,SOS,NON_VACCINE,VACCINE_STA...  ENG  UTF-8      Y     Y
# 1  VAC,DRUG_CLASS_TYPE,VA_CLASS_NAME,DDF,NFI,DCSA...  ENG  UTF-8      Y     Y
# 2  LT,AN,DX,FX,EC,II,AQL,SOS,PA,PI,TH,RN,MN,SC,MD...  ENG  UTF-8      Y     Y
# 3                                                     ENG  UTF-8      Y     Y
# 4                                                     ENG  UTF-8      Y     Y
# 5  VAC,SNOMED_CHILD,NDFRT_KIND,MESH_NAME,DEFINITI...  ENG  UTF-8      Y     Y
# 6  ORIG_SOURCE,RXN_STRENGTH,RXN_VET_DRUG,RXN_QUAN...  ENG  UTF-8      Y     Y
# 7  MARKETING_STATUS,LABEL_TYPE,NADA,EXEMPT_DEVICE...  ENG  UTF-8      Y     Y
# 8                                                     ENG  UTF-8      Y     Y
#
#                                                  ssn  \
# 0                              Vaccines Administered
# 1                                 National Drug File
# 2                                               MeSH
# 3  National Drug File - Reference Terminology - F...
# 4  National Drug File - Reference Terminology - F...
# 5         National Drug File - Reference Terminology
# 6  RxNorm work done by the National Library of Me...
# 7                      FDA Structured Product Labels
# 8                                          MTHCMSFRF
#
#                                                 scit
# 0  ;;National Center for Immunization and Respira...
# 1  ;;;;Veterans Health Administration National Dr...
# 2  ;;;;Medical Subject Headings (MeSH);;;2018;;U....
# 3  ;;;;National Drug File - Reference Terminology...
# 4  ;;;;National Drug File - Reference Terminology...
# 5  ;;;;National Drug File - Reference Terminology...
# 6  ;;;;RxNorm;;;META2017AB Full Update 2018_02_05...
# 7  ;;;;Metathesaurus Forms of the FDA Structured ...
# 8  ;;;;Metathesaurus Forms of CMS Formulary Refer...
#
# [9 rows x 25 columns]

# %%
bq_assistant.table_schema("rxnsab_current")
# Out:
# [SchemaField('vcui', 'STRING', 'NULLABLE', 'CUI of the versioned SRC concept for a source', ()),
#  SchemaField('rcui', 'STRING', 'NULLABLE', 'CUI of the root SRC concept for a source', ()),
#  SchemaField('vsab', 'STRING', 'NULLABLE', 'The versioned source abbreviation for a source, e.g., NDDF_2004_11_03', ()),
#  SchemaField('rsab', 'STRING', 'NULLABLE', 'The root source abbreviation, for a source e.g. NDDF', ()),
#  SchemaField('son', 'STRING', 'NULLABLE', 'The official name for a source', ()),
#  SchemaField('sf', 'STRING', 'NULLABLE', 'The Source Family for a source', ()),
#  SchemaField('sver', 'STRING', 'NULLABLE', 'The source version, e.g., 2001', ()),
#  SchemaField('vstart', 'STRING', 'NULLABLE', 'The date a source became active, e.g., 2001_04_03', ()),
#  SchemaField('vend', 'STRING', 'NULLABLE', 'The date a source ceased to be active, e.g., 2001_05_10', ()),
#  SchemaField('imeta', 'STRING', 'NULLABLE', 'The version of the Metathesaurus a source first appeared, e.g., 2001AB', ()),
#  SchemaField('rmeta', 'STRING', 'NULLABLE', 'The version of the Metathesaurus a source was removed, e.g., 2001AC', ()),
#  SchemaField('slc', 'STRING', 'NULLABLE', 'The source license contact information. A semi-colon separated list containing the following fields: Name; Title; Organization; Address 1; Address 2; City; State or Province; Country; Zip or Postal Code; Telephone; Contact Fax; Email; URL', ()),
#  SchemaField('scc', 'STRING', 'NULLABLE', 'The source content contact information. A semi-colon separated list containing the following fields: Name; Title; Organization; Address 1; Address 2; City; State or Province; Country; Zip or Postal Code; Telephone; Contact Fax; Email; URL', ()),
#  SchemaField('srl', 'STRING', 'NULLABLE', '0,1,2,3,4 - explained in the License Agreement.', ()),
#  SchemaField('tfr', 'STRING', 'NULLABLE', 'The number of terms for this source in RXNCONSO.RRF, e.g., 12343 (not implemented yet)', ()),
#  SchemaField('cfr', 'STRING', 'NULLABLE', 'The number of CUIs associated with this source, e.g., 10234 (not implemented yet)', ()),
#  SchemaField('cxty', 'STRING', 'NULLABLE', 'The type of relationship label (Section 2.4.2 of UMLS Reference Manual)', ()),
#  SchemaField('ttyl', 'STRING', 'NULLABLE', 'Term type list from source, e.g., MH,EN,PM,TQ', ()),
#  SchemaField('atnl', 'STRING', 'NULLABLE', 'The attribute name list, e.g., MUI,RN,TH,...', ()),
#  SchemaField('lat', 'STRING', 'NULLABLE', 'The language of the terms in the source', ()),
#  SchemaField('cenc', 'STRING', 'NULLABLE', 'Character set as specified by the IANA official names for character assignments http://www.iana.org/assignments/character-sets', ()),
#  SchemaField('curver', 'STRING', 'NULLABLE', 'A Y or N flag indicating whether or not this row corresponds to the current version of the named source', ()),
#  SchemaField('sabin', 'STRING', 'NULLABLE', 'A Y or N flag indicating whether or not this row is represented in the current MetamorphoSys subset. Initially always Y where CURVER is Y, but later is recomputed by MetamorphoSys.', ()),
#  SchemaField('ssn', 'STRING', 'NULLABLE', 'The short name of a source as used by the NLM Knowledge Source Server.', ()),
#  SchemaField('scit', 'STRING', 'NULLABLE', 'Citation information for a source. A semi-colon separated list containing the following fields: Author(s); Author(s) address; Author(s) organization; Editor(s); Title; Content Designator; Medium Designator; Edition; Place of Publication; Publisher; Date of Publication/copyright; Date of revision; Location; Extent; Series; Availability Statement (URL); Language; Notes', ())]

# %% [markdown]
# What are the RXCUI codes for the ingredients of a list of drugs?

# %%
query1 = """SELECT
  *
FROM
  `bigquery-public-data.nlm_rxnorm.rxn_all_pathways_current`
WHERE
  SOURCE_NAME IN ('Vancomycin 100 MG/ML',
    'Ceftriaxone 250 MG Injection',
    'Metronidazole Pill',
    '1 ML Morphine Sulfate 15 MG/ML Cartridge',
    '{14 (Estrogens, Conjugated (USP) 0.625 MG / medroxyprogesterone acetate 5 MG Oral Tablet) / 14 (Estrogens, Conjugated (USP) 0.625 MG Oral Tablet) } Pack [Premphase 28 Day]',
    'Warfarin Sodium 4 MG Oral Tablet',
    'Diphenhydramine',
    'Metformin / pioglitazone',
    'Ibuprofen 800 MG Extended Release Oral Tablet',
    'Valium' )
  AND TARGET_TTY = 'IN'
ORDER BY
  SOURCE_RXCUI;
        """
response1 = RxNorm.query_to_pandas_safe(query1)
response1.head(20)
# Out:
#    SOURCE_RXCUI SOURCE_TTY                                        SOURCE_NAME  \
# 0       1000487       BPCK  {14 (Estrogens, Conjugated (USP) 0.625 MG / me...
# 1       1000487       BPCK  {14 (Estrogens, Conjugated (USP) 0.625 MG / me...
# 2       1164084       SCDG                                 Metronidazole Pill
# 3       1733080        SCD           1 ML Morphine Sulfate 15 MG/ML Cartridge
# 4        202472         BN                                             Valium
# 5        250418        SCD      Ibuprofen 800 MG Extended Release Oral Tablet
# 6        309092        SCD                       Ceftriaxone 250 MG Injection
# 7        342893       SCDC                               Vancomycin 100 MG/ML
# 8          3498         IN                                    Diphenhydramine
# 9        607999        MIN                           Metformin / pioglitazone
# 10       607999        MIN                           Metformin / pioglitazone
# 11       855324        SCD                   Warfarin Sodium 4 MG Oral Tablet
#
#    TARGET_RXCUI TARGET_TTY                  TARGET_NAME
# 0          4099         IN  Estrogens, Conjugated (USP)
# 1          6691         IN          Medroxyprogesterone
# 2          6922         IN                Metronidazole
# 3          7052         IN                     Morphine
# 4          3322         IN                     Diazepam
# 5          5640         IN                    Ibuprofen
# 6          2193         IN                  Ceftriaxone
# 7         11124         IN                   Vancomycin
# 8          3498         IN              Diphenhydramine
# 9          6809         IN                    Metformin
# 10        33738         IN                 pioglitazone
# 11        11289         IN                     Warfarin

# %% [markdown]
# Which ingredients have the most variety of dose forms?

# %%
query2 = """SELECT
  SOURCE_NAME AS IN_NAME,
  COUNT (*) AS DF_COUNT
FROM
  `bigquery-public-data.nlm_rxnorm.rxn_all_pathways_current`
WHERE
  SOURCE_TTY='IN'
  AND TARGET_TTY='DF'
GROUP BY
  IN_NAME
ORDER BY
  DF_COUNT DESC
LIMIT
  10;
        """
response2 = RxNorm.query_to_pandas_safe(query2, max_gb_scanned=10)
response2.head(20)
# Out:
#               IN_NAME  DF_COUNT
# 0       Phenylephrine        30
# 1          Benzocaine        29
# 2      Hydrocortisone        29
# 3             Menthol        28
# 4           Lidocaine        27
# 5     Diphenhydramine        24
# 6     Sodium Chloride        23
# 7            Glycerin        22
# 8  Sodium Bicarbonate        20
# 9      Salicylic Acid        19

# %% [markdown]
# In what dose forms is the drug phenylephrine found?

# %%
query3 = """SELECT
  *
FROM
  `bigquery-public-data.nlm_rxnorm.rxn_all_pathways_current`
WHERE
  SOURCE_NAME='Phenylephrine'
  AND target_TTY = 'DF';
        """
response3 = RxNorm.query_to_pandas_safe(query3, max_gb_scanned=10)
response3.head(20)
# Out:
#    SOURCE_RXCUI SOURCE_TTY    SOURCE_NAME TARGET_RXCUI TARGET_TTY  \
# 0          8163         IN  Phenylephrine       316942         DF
# 1          8163         IN  Phenylephrine       346164         DF
# 2          8163         IN  Phenylephrine       316968         DF
# 3          8163         IN  Phenylephrine       317005         DF
# 4          8163         IN  Phenylephrine        91058         DF
# 5          8163         IN  Phenylephrine       316982         DF
# 6          8163         IN  Phenylephrine       316985         DF
# 7          8163         IN  Phenylephrine       126542         DF
# 8          8163         IN  Phenylephrine       316945         DF
# 9          8163         IN  Phenylephrine       316978         DF
# 10         8163         IN  Phenylephrine       316962         DF
# 11         8163         IN  Phenylephrine       346165         DF
# 12         8163         IN  Phenylephrine       797271         DF
# 13         8163         IN  Phenylephrine      1535727         DF
# 14         8163         IN  Phenylephrine       244286         DF
# 15         8163         IN  Phenylephrine       346170         DF
# 16         8163         IN  Phenylephrine       316965         DF
# 17         8163         IN  Phenylephrine       316969         DF
# 18         8163         IN  Phenylephrine       316943         DF
# 19         8163         IN  Phenylephrine       316975         DF
#
#                        TARGET_NAME
# 0       Disintegrating Oral Tablet
# 1                       Oral Spray
# 2                    Oral Solution
# 3                  Rectal Ointment
# 4                  Chewable Tablet
# 5                    Topical Cream
# 6                 Topical Ointment
# 7                      Nasal Spray
# 8     Extended Release Oral Tablet
# 9               Rectal Suppository
# 10                  Nasal Solution
# 11                   Topical Spray
# 12                   Medicated Pad
# 13        Effervescent Oral Tablet
# 14  Ophthalmic Irrigation Solution
# 15                      Rectal Gel
# 16                    Oral Capsule
# 17                 Oral Suspension
# 18   Extended Release Oral Capsule
# 19                    Rectal Cream
