# %% [markdown]
# **Map of Outdoor Recreation Areas near Boulder, Colorado**
#
# * Data from https://bouldercolorado.gov/open-data

# %%
import numpy as np
import pandas as pd
import os
import folium
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)


def plotPointsOnMap(dataframe,beginIndex,endIndex,latitudeColumn,latitudeValue,longitudeColumn,longitudeValue,zoom):
    df = dataframe[beginIndex:endIndex]
    location = [latitudeValue,longitudeValue]
    plot = folium.Map(location=location,zoom_start=zoom)
    for i in range(0,len(df)):
        popup = folium.Popup(str(df.name[i:i+1]))
        folium.Marker([df[latitudeColumn].iloc[i],df[longitudeColumn].iloc[i]],popup=popup).add_to(plot)
    return(plot)

def color_coded_map(df, center_lat, center_lon, zoom,bubbleSize,latitudeColumn,longitudeColumn,coloredColumn,labeledColumn,fillBool,opacityValue):  
    # Adapted from  https://www.kaggle.com/dejavu23/openaq-from-queries-to-world-maps
    m = folium.Map(location=[center_lat, center_lon],
                   zoom_start = zoom)
    for index, row in df.iterrows():
        folium.CircleMarker([row[[latitudeColumn]], row[[longitudeColumn]]],radius=bubbleSize, 
                             color=custom_colormap(row[coloredColumn]), #
                             fill_color=custom_colormap(row[coloredColumn]), #
                             fill=fillBool, fill_opacity=opacityValue,             
                             popup=row[[labeledColumn]]).add_to(m) 
    custom_colormap.add_to(m)
    folium.TileLayer(tiles='Stamen Toner',name="Stamen Toner").add_to(m)
    folium.TileLayer(tiles='Stamen Terrain',name="Stamen Terrain").add_to(m)
    folium.TileLayer(tiles='cartodbpositron',name="cartodbpositron").add_to(m)
    folium.LayerControl().add_to(m)       
    return m

def plotMultipleChoice(selectedColumn,data,title,yAxisTitle):
    counts = data[selectedColumn].value_counts()
    countsDf = pd.DataFrame(counts)
    trace1 = go.Bar(
                    x = countsDf.index,
                    y = countsDf[selectedColumn],
                    name = "Kaggle",
                    marker = dict(color = 'rgba(0, 0, 255, 0.8)',
                                 line=dict(color='rgb(0,0,0)',width=1.5)),
                    text = countsDf.index)
    data = [trace1]
    layout = go.Layout(barmode = "group",title=title, yaxis= dict(title=yAxisTitle),showlegend=False)
    fig = go.Figure(data = data, layout = layout)
    iplot(fig)

OSMP_Trails = pd.read_csv('../input/OSMP_Trails.csv')
OSMP_Trails=OSMP_Trails[['TRAILNAME','TRAILTYPE','BICYCLES','HORSES','MILEAGE']]
OSMP_Trailheads = pd.read_csv('../input/OSMP_Trailheads.csv')
OSMP_Trailheads=OSMP_Trailheads[['OSMPTrailheadsOSMPTHNAME','OSMPTrailheadsOSMPADDRESS','OSMPTrailheadsOSMPELEVATION','OSMPTrailheadsOSMPPARKSPACES',
                                 'OSMPTrailheadsOSMPRESTROOMS','OSMPTrailheadsOSMPBIKERACK','OSMPTrailheadsOSMPBIKETRAIL','X','Y']]
OSMP_Climbing_Formations = pd.read_csv('../input/OSMP_Climbing_Formations.csv')
OSMP_Climbing_Formations=OSMP_Climbing_Formations[['FEATURE','AreaAccess','ROUTES','UseRating','FormationType','X','Y']]
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# **Map of Outdoor Climbing Formations near Boulder, Colorado**

# %%
custom_colormap = folium.StepColormap(['yellow','orange','red','black'], 
                         vmin=0, vmax=4,
                         index=[0,1,2,3],
                        caption='User Rating')
OSMP_Climbing_Formations = OSMP_Climbing_Formations.sort_values(by='UseRating', ascending=0)
OSMP_Climbing_Formations.head(60)
# Out:
#                            FEATURE    ...              Y
# 62                  Third Flatiron    ...      39.987199
# 86                      Der Zerkle    ...      39.974134
# 116            Elephant Buttresses    ...      40.012528
# 99                        The Dome    ...      40.013957
# 122             South Shelf Blocks    ...      40.021977
# 92                       Twin Fins    ...      40.022538
# 17              North Shelf Blocks    ...      40.022234
# 55                 Second Flatiron    ...      39.989629
# 63                      The Maiden    ...      39.950017
# 31                  Sanitas Proper    ...      40.021632
# 103                    Corner Rock    ...      40.023014
# 87                     Classy Wall    ...      40.023252
# 54                      Scoop Wall    ...      40.022529
# 95                  Ridge Gap Wall    ...      40.023723
# 28                      Crown Rock    ...      40.001431
# 64          Beer Barrel/Tree Slab/    ...      40.001000
# 113                Monkey Traverse    ...      40.000770
# 119               3-of-a-Kind Wall    ...      40.003884
# 223                    A-7 Boulder    ...      39.988950
# 224                    BBC Boulder    ...      39.988800
# 222               Stardust Boulder    ...      39.989180
# 56                     Ampitheatre    ...      40.002908
# 220                Sputnik Boulder    ...      39.989570
# 221               G-friend Boulder    ...      39.988950
# 315                Industrial Wall    ...      39.916626
# 33               Mickey Mouse Wall    ...      39.918083
# 108                   Cloud Shadow    ...      40.002789
# 105                        Capstan    ...      40.002742
# 32                      Upper Area    ...      40.003819
# 94                     Candel Area    ...      39.998810
# 82                           Alamo    ...      40.000059
# 27                   Upper Peanuts    ...      39.927403
# 47                   Dinosaur Rock    ...      39.973471
# 6                   First Flatiron    ...      39.991022
# 295                       The Slab    ...      39.963009
# 259              Funk Soul Boulder    ...      39.961320
# 331            Animal Chin Boulder    ...      39.961381
# 332  The Ice Cube-Fairview Boulder    ...      39.961454
# 313              Ghetto Bouldering    ...      39.986718
# 323               Compound Boulder    ...      39.989820
# 0                     Pumpkin Rock    ...      40.005020
# 14                      The Matron    ...      39.942781
# 84                      Cookie Jar    ...      40.005097
# 75                       Seal Rock    ...      39.968385
# 312              Gutter Bouldering    ...      39.989215
# 45                   Overhang Rock    ...      39.970718
# 318             Satellite Boulders    ...      39.988631
# 322             Satellite Boulders    ...      39.988476
# 321             Satellite Boulders    ...      39.988920
# 320             Satellite Boulders    ...      39.988329
# 319             Satellite Boulders    ...      39.988535
# 80                        The Hand    ...      39.973883
# 67                  Der Freischutz    ...      39.973083
# 328                  The Love Boat    ...      39.961196
# 333        Having Moment Part Deux    ...      39.960415
# 102        Stonehenge (Jellystone)    ...      39.972082
# 245               Platform Boulder    ...      39.972470
# 248     Bear Canyon Creek Boulders    ...      39.971730
# 93                 Finger Flatiron    ...      39.974143
# 247                    Gully Block    ...      39.972470
#
# [60 rows x 7 columns]

# %%
temperature_map = color_coded_map(OSMP_Climbing_Formations, 39.965411,-105.293598,12,5,'Y','X','UseRating','FEATURE',True,1,)
temperature_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data= OSMP_Climbing_Formations
selectedColumn = 'FormationType'
title='Types of Climbing Formations near Boulder'
yAxisTitle = title
plotMultipleChoice(selectedColumn,data,title,yAxisTitle)
# Out:
# <div>
#
#
#             <div id="bcabaa01-d36a-4a00-a457-4cb5b3f38161" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bcabaa01-d36a-4a00-a457-4cb5b3f38161")) {
#                     Plotly.newPlot(
#                         'bcabaa01-d36a-4a00-a457-4cb5b3f38161',
#                         [{"marker": {"color": "rgba(0, 0, 255, 0.8)", "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "name": "Kaggle", "text": ["Boulder", "Wall"], "type": "bar", "uid": "9699243d-b810-4728-aff6-843e891715bc", "x": ["Boulder", "Wall"], "y": [308, 158]}],
#                         {"barmode": "group", "showlegend": false, "title": {"text": "Types of Climbing Formations near Boulder"}, "yaxis": {"title": {"text": "Types of Climbing Formations near Boulder"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('bcabaa01-d36a-4a00-a457-4cb5b3f38161');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
data= OSMP_Climbing_Formations
selectedColumn = 'AreaAccess'
title='Number of Climbing Formations at Each Location'
yAxisTitle = title
plotMultipleChoice(selectedColumn,data,title,yAxisTitle)
# Out:
# <div>
#
#
#             <div id="5992523f-64b2-4a81-95c4-6654ccef9ebd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5992523f-64b2-4a81-95c4-6654ccef9ebd")) {
#                     Plotly.newPlot(
#                         '5992523f-64b2-4a81-95c4-6654ccef9ebd',
#                         [{"marker": {"color": "rgba(0, 0, 255, 0.8)", "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "name": "Kaggle", "text": ["Cragmoor Rd", "Sacred Cliffs", "NCAR", "Bear Mountain Drive", "Chautauqua", "South Mesa Trail", "Eldo", "Flagstaff", "Eldorado Mountain", "Gregory Canyon", "Mt Sanitas", "Boulder Canyon"], "type": "bar", "uid": "de363976-1108-42f5-b2d2-435fd8365359", "x": ["Cragmoor Rd", "Sacred Cliffs", "NCAR", "Bear Mountain Drive", "Chautauqua", "South Mesa Trail", "Eldo", "Flagstaff", "Eldorado Mountain", "Gregory Canyon", "Mt Sanitas", "Boulder Canyon"], "y": [81, 78, 68, 65, 64, 42, 23, 15, 12, 8, 8, 2]}],
#                         {"barmode": "group", "showlegend": false, "title": {"text": "Number of Climbing Formations at Each Location"}, "yaxis": {"title": {"text": "Number of Climbing Formations at Each Location"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('5992523f-64b2-4a81-95c4-6654ccef9ebd');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# **Map of Trailsheads in Boulder, Colorado**

# %%
custom_colormap = folium.StepColormap( ['purple','blue','green','yellow','orange','red'], 
                         vmin=5000, vmax=10000,
                         index=[5000,6000,7000,8000,9000,10000],
                        caption='Elevation')
OSMP_Trailheads = OSMP_Trailheads.sort_values(by='OSMPTrailheadsOSMPELEVATION', ascending=0)
OSMP_Trailheads.head(20)
# Out:
#    OSMPTrailheadsOSMPTHNAME    ...              Y
# 5            Fourth of July    ...      39.995048
# 17    Flagstaff Summit West    ...      40.005021
# 18    Flagstaff Summit East    ...      40.004188
# 1         Realization Point    ...      39.997336
# 32               Crown Rock    ...      40.001781
# 4                      NCAR    ...      39.978708
# 0             Halfway House    ...      40.006501
# 13           Panorama Point    ...      40.005965
# 33          Buckingham Park    ...      40.111298
# 16          Flatirons Vista    ...      39.923962
# 14        Greenbelt Plateau    ...      39.928632
# 11           Gregory Canyon    ...      39.997511
# 10           Enchanted Mesa    ...      39.997302
# 9                Chautauqua    ...      39.998790
# 3                Doudy Draw    ...      39.938244
# 26          Four Mile Creek    ...      40.062717
# 2                South Mesa    ...      39.938595
# 15            Marshall Mesa    ...      39.953085
# 21               Centennial    ...      40.020073
# 27                Foothills    ...      40.070483
#
# [20 rows x 9 columns]

# %%
temperature_map = color_coded_map(OSMP_Trailheads, 39.997336,-105.294556, 12,5,'Y','X','OSMPTrailheadsOSMPELEVATION','OSMPTrailheadsOSMPTHNAME',True,1,)
temperature_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data= OSMP_Trails
selectedColumn = 'TRAILTYPE'
title='Types of Hiking Trails near Boulder'
yAxisTitle = title
plotMultipleChoice(selectedColumn,data,title,yAxisTitle)
# Out:
# <div>
#
#
#             <div id="8e0c7c6b-eac7-40c5-8018-3a871d71be5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8e0c7c6b-eac7-40c5-8018-3a871d71be5c")) {
#                     Plotly.newPlot(
#                         '8e0c7c6b-eac7-40c5-8018-3a871d71be5c',
#                         [{"marker": {"color": "rgba(0, 0, 255, 0.8)", "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "name": "Kaggle", "text": ["Hiking Trail", "Multi-Use Trail", "Climbing Access", "Gliding Access"], "type": "bar", "uid": "91158273-84fb-463e-8b78-d242ea2ac382", "x": ["Hiking Trail", "Multi-Use Trail", "Climbing Access", "Gliding Access"], "y": [433, 129, 7, 4]}],
#                         {"barmode": "group", "showlegend": false, "title": {"text": "Types of Hiking Trails near Boulder"}, "yaxis": {"title": {"text": "Types of Hiking Trails near Boulder"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8e0c7c6b-eac7-40c5-8018-3a871d71be5c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
data= OSMP_Trails
selectedColumn = 'HORSES'
title='Are Horses Allowed?'
yAxisTitle = title
plotMultipleChoice(selectedColumn,data,title,yAxisTitle)
# Out:
# <div>
#
#
#             <div id="08ee014e-99d3-4cbd-a2c9-5d616fe32f0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("08ee014e-99d3-4cbd-a2c9-5d616fe32f0c")) {
#                     Plotly.newPlot(
#                         '08ee014e-99d3-4cbd-a2c9-5d616fe32f0c',
#                         [{"marker": {"color": "rgba(0, 0, 255, 0.8)", "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "name": "Kaggle", "text": ["Yes", "No"], "type": "bar", "uid": "74ac046c-8a26-47fc-bb44-e6ad039c4d2c", "x": ["Yes", "No"], "y": [463, 110]}],
#                         {"barmode": "group", "showlegend": false, "title": {"text": "Are Horses Allowed?"}, "yaxis": {"title": {"text": "Are Horses Allowed?"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('08ee014e-99d3-4cbd-a2c9-5d616fe32f0c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
data= OSMP_Trails
selectedColumn = 'BICYCLES'
title='Are Bicycles Allowed?'
yAxisTitle = title
plotMultipleChoice(selectedColumn,data,title,yAxisTitle)
# Out:
# <div>
#
#
#             <div id="2531d3c5-caba-45c9-afd5-f540ab60268f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2531d3c5-caba-45c9-afd5-f540ab60268f")) {
#                     Plotly.newPlot(
#                         '2531d3c5-caba-45c9-afd5-f540ab60268f',
#                         [{"marker": {"color": "rgba(0, 0, 255, 0.8)", "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "name": "Kaggle", "text": ["No", "Yes"], "type": "bar", "uid": "37a36bdd-1be7-4863-91fc-5ce50b225db9", "x": ["No", "Yes"], "y": [443, 130]}],
#                         {"barmode": "group", "showlegend": false, "title": {"text": "Are Bicycles Allowed?"}, "yaxis": {"title": {"text": "Are Bicycles Allowed?"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('2531d3c5-caba-45c9-afd5-f540ab60268f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
