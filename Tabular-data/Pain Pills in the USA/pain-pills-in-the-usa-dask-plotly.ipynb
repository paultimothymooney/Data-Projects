# %% [markdown]
# **Pain Pills in the USA**
# * Data from [The Washington Post](https://www.washingtonpost.com/graphics/2019/investigations/dea-pain-pill-database)

# %% [markdown]
# Step 1: Import Python modules and define helper functions
# * [Dask](https://dask.org/)
# * [Plotly](https://plot.ly/python/)

# %%
import pandas as pd 
import dask.dataframe as dd
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
import warnings
warnings.filterwarnings('ignore')
init_notebook_mode(connected=True)

def valueCounter(dataframe,columnToCount):
    valueCounts = dataframe[columnToCount].value_counts().compute()
    df = pd.DataFrame(data=valueCounts)
    return df

def quantityCounter(dataframe,columnToCount):
    quantityCount = dataframe.groupby(columnToCount)['QUANTITY'].sum()
    quantityCount = quantityCount.compute().sort_values(ascending=False)
    df = pd.DataFrame(data=quantityCount)
    return df

def calculateQuantityPerPerson(dataframe,columnToCount,indexValue,populationValue):
    cityQuantity = dataframe.groupby(columnToCount)['QUANTITY'].sum()
    cityQuantity = cityQuantity.compute().sort_values(ascending=False)[indexValue]
    quantityPerPerson = cityQuantity/populationValue
    return quantityPerPerson

def plotHorizontalBarGraph(dataframe,column,title,yAxisTitle,width,height,begin,end):
    trace1 = go.Bar(
                    x = dataframe[column][begin:end],
                    y = dataframe.index,
                    orientation='h',
                    name = "Kaggle",
                    marker = dict(color = 'rgba(0, 0, 255, 0.8)',
                                 line=dict(color='rgb(0,0,0)',width=1.5)),
                    text = dataframe.index)
    data = [trace1]
    layout = go.Layout(barmode = "group",title=title, 
                       xaxis=dict(title=yAxisTitle),
                       yaxis=dict(autorange="reversed"),
                       width = width,
                       height = height,
                       showlegend=False)
    fig = go.Figure(data = data, layout = layout)
    fig.update_yaxes(automargin=True)
    iplot(fig)
    
TRAIN_PATH = '../input/arcos_all_washpost.tsv/arcos_all_washpost.tsv'
interestingColumns = ['BUYER_NAME','BUYER_ADDRESS1', 'BUYER_ADDRESS2', 'BUYER_CITY', 'BUYER_STATE',
       'BUYER_ZIP', 'BUYER_COUNTY','DRUG_NAME', 'QUANTITY', 'UNIT', 'TRANSACTION_DATE', 'CALC_BASE_WT_IN_GM',
       'DOSAGE_UNIT', 'Product_Name', 'Ingredient_Name','Revised_Company_Name', 'Reporter_family']
df_tmp = pd.read_csv(TRAIN_PATH,sep='\t',usecols=interestingColumns,nrows=5)
df_tmp.head()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#                     BUYER_NAME             ...                         Reporter_family
# 0         TABRIZI, HAMID R DMD             ...              ACE Surgical Supply Co Inc
# 1  APOTHECARY SHOP DEER VALLEY             ...                            Apotheca Inc
# 2      HOBBS, DOUGLAS DON,  MD             ...                            Apotheca Inc
# 3      HOBBS, DOUGLAS DON,  MD             ...                            Apotheca Inc
# 4      HOBBS, DOUGLAS DON,  MD             ...                            Apotheca Inc
#
# [5 rows x 17 columns]

# %% [markdown]
# Step 2: Load the data using Dask
# * 1 x 80GB TSV file
# * adapted from [jpmiller/szelee's method](https://www.kaggle.com/szelee/how-to-import-a-csv-file-of-55-million-rows)

# %%
traintypes = {'BUYER_NAME': 'str',
              'BUYER_ADDRESS1': 'str', 
              'BUYER_ADDRESS2': 'str',
              'BUYER_CITY': 'str',
              'BUYER_STATE': 'str',
              'BUYER_ZIP': 'int64',
              'BUYER_COUNTY': 'str',
              'DRUG_NAME': 'str',
              'QUANTITY': 'int64',
              'UNIT': 'str',
              'TRANSACTION_DATE': 'int64',
              'CALC_BASE_WT_IN_GM': 'float64',
              'DOSAGE_UNIT': 'float64',
              'Product_Name': 'str',
              'Ingredient_Name': 'str',
              'Revised_Company_Name': 'str',
              'Reporter_family': 'str'}
cols = list(traintypes.keys())
df = dd.read_csv(TRAIN_PATH,sep='\t', usecols=interestingColumns,dtype=traintypes)
df.head(5)
# Out:
#                     BUYER_NAME             ...                         Reporter_family
# 0         TABRIZI, HAMID R DMD             ...              ACE Surgical Supply Co Inc
# 1  APOTHECARY SHOP DEER VALLEY             ...                            Apotheca Inc
# 2      HOBBS, DOUGLAS DON,  MD             ...                            Apotheca Inc
# 3      HOBBS, DOUGLAS DON,  MD             ...                            Apotheca Inc
# 4      HOBBS, DOUGLAS DON,  MD             ...                            Apotheca Inc
#
# [5 rows x 17 columns]

# %% [markdown]
# Step 3: Visualize data for the entire USA

# %%
stateCounts = quantityCounter(df,'BUYER_STATE')
plotHorizontalBarGraph(stateCounts,'QUANTITY','Pain Pills per State','Pain Pills per State',750,1500,0,50)
del stateCounts
# Out:
# <div>
#
#
#             <div id="81b9492e-b7a4-45fd-9ba3-cf282e13b2e1" class="plotly-graph-div" style="height:1500px; width:750px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("81b9492e-b7a4-45fd-9ba3-cf282e13b2e1")) {
#                     Plotly.newPlot(
#                         '81b9492e-b7a4-45fd-9ba3-cf282e13b2e1',
#                         [{"marker": {"color": "rgba(0, 0, 255, 0.8)", "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "name": "Kaggle", "orientation": "h", "text": ["CA", "FL", "TX", "NY", "PA", "OH", "NC", "TN", "GA", "MI", "SC", "WA", "IN", "NJ", "AZ", "VA", "IL", "KY", "MO", "MA", "MD", "OR", "AL", "WI", "LA", "OK", "CO", "NV", "KS", "AR", "WV", "CT", "MN", "UT", "MS", "NM", "IA", "ME", "ID", "DE", "NH", "NE", "MT", "RI", "HI", "AK", "VT", "WY", "SD", "ND", "PR", "DC", "VI", "GU", "MP", "PW", "AE"], "type": "bar", "uid": "e34e0067-c851-498a-882a-588c91617bc2", "x": [54057115, 39053364, 25605244, 22543212, 20764697, 20597201, 16983664, 15199778, 14179170, 13989490, 12862806, 12590916, 12547587, 11760824, 10986577, 10624633, 10492376, 9806368, 9495839, 9440894, 9379480, 9096078, 9013690, 7996459, 7946972, 7712584, 7077010, 6260642, 5379163, 5207399, 5063228, 5035179, 4959550, 4814603, 4513005, 3330624, 2995569, 2939004, 2332507, 2124833, 2072730, 1967370, 1543776, 1527520, 1469276, 1015507, 856909, 780425, 769256, 561409], "y": ["CA", "FL", "TX", "NY", "PA", "OH", "NC", "TN", "GA", "MI", "SC", "WA", "IN", "NJ", "AZ", "VA", "IL", "KY", "MO", "MA", "MD", "OR", "AL", "WI", "LA", "OK", "CO", "NV", "KS", "AR", "WV", "CT", "MN", "UT", "MS", "NM", "IA", "ME", "ID", "DE", "NH", "NE", "MT", "RI", "HI", "AK", "VT", "WY", "SD", "ND", "PR", "DC", "VI", "GU", "MP", "PW", "AE"]}],
#                         {"barmode": "group", "height": 1500, "showlegend": false, "title": {"text": "Pain Pills per State"}, "width": 750, "xaxis": {"title": {"text": "Pain Pills per State"}}, "yaxis": {"automargin": true, "autorange": "reversed"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('81b9492e-b7a4-45fd-9ba3-cf282e13b2e1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# Note population numbers are estimates from Wikipedia for the year 2018
print('Quantity of Pain Pills per Person: ','\n')
print('California: ',calculateQuantityPerPerson(df,'BUYER_STATE',0,39557045))
print('Florida: ',calculateQuantityPerPerson(df,'BUYER_STATE',1,21299325))
print('Texas: ',calculateQuantityPerPerson(df,'BUYER_STATE',2,28701845))
# Out:
# Quantity of Pain Pills per Person:
#
# California:  1.3665610007016449
# Florida:  1.833549373043512
# Texas:  0.8921114304672748

# %%
cityCounts = quantityCounter(df,'BUYER_CITY')
plotHorizontalBarGraph(cityCounts,'QUANTITY','Pain Pills per City','Pain Pills per City',750,1500,0,50)
del cityCounts
# Out:
# <div>
#
#
#             <div id="ae81730c-2082-44b3-8861-e30b4239e1bb" class="plotly-graph-div" style="height:1500px; width:750px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ae81730c-2082-44b3-8861-e30b4239e1bb")) {
#                     Plotly.newPlot(
#                         'ae81730c-2082-44b3-8861-e30b4239e1bb',
#                         [{"marker": {"color": "rgba(0, 0, 255, 0.8)", "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "name": "Kaggle", "orientation": "h", "text": ["LIVERMORE", "NORTH CHARLESTON", "LAS VEGAS", "TAMPA", "HOUSTON", "PHILADELPHIA", "COLUMBUS", "PHOENIX", "PORTLAND", "JACKSONVILLE", "DOWNEY", "BALTIMORE", "INDIANAPOLIS", "SACRAMENTO", "SPRINGFIELD", "TUCSON", "LOUISVILLE", "SAN DIEGO", "ORLANDO", "NEW YORK", "SAN ANTONIO", "BROOKLYN", "CINCINNATI", "DALLAS", "KNOXVILLE", "MILWAUKEE", "ALBUQUERQUE", "RICHMOND", "LEAVENWORTH", "OKLAHOMA CITY", "GREENVILLE", "ROCHESTER", "PITTSBURGH", "LOS ANGELES", "CLEVELAND", "MIAMI", "CHICAGO", "HENDERSON", "TULSA", "LANCASTER", "COLUMBIA", "MADISON", "SALT LAKE CITY", "FORT WORTH", "AUSTIN", "WILMINGTON", "JACKSON", "MURFREESBORO", "TOLEDO", "NASHVILLE", "BRONX", "SEATTLE", "WASHINGTON", "SALEM", "MESA", "LEXINGTON", "SAN FRANCISCO", "MODESTO", "KANSAS CITY", "FRESNO", "FLORENCE", "SPOKANE", "STATEN ISLAND", "WICHITA", "LONG BEACH", "CHARLOTTE", "FAYETTEVILLE", "BATON ROUGE", "FRANKLIN", "VANCOUVER", "LAFAYETTE", "BAKERSFIELD", "ATLANTA", "WARREN", "COLORADO SPRINGS", "ARLINGTON", "GLENDALE", "DETROIT", "MONROE", "LEBANON", "AUBURN", "MIDDLETOWN", "DAYTON", "DENVER", "CLINTON", "SARASOTA", "OMAHA", "NEWARK", "BUFFALO", "SANFORD", "CLEARWATER", "ROSEVILLE", "MEDFORD", "TROY", "GAINESVILLE", "CANTON", "ANDERSON", "HUNTSVILLE", "AURORA", "CHATTANOOGA", "BIRMINGHAM", "RIVERSIDE", "BRADENTON", "DECATUR", "MARION", "COVINGTON", "MEMPHIS", "MILFORD", "RENO", "ATHENS", "MANCHESTER", "ALEXANDRIA", "ASHLAND", "NEW CASTLE", "MOBILE", "MARIETTA", "TACOMA", "CHARLESTON", "WEST PALM BEACH", "STOCKTON", "LAKEWOOD", "CARLSBAD", "OAKLAND", "CHANDLER", "ALBANY", "PEORIA", "SAN JOSE", "SAINT LOUIS", "PUEBLO", "NEWPORT", "HUDSON", "AUGUSTA", "AKRON", "PASADENA", "LINCOLN", "RALEIGH", "SHREVEPORT", "BRISTOL", "GREENSBORO", "EVERETT", "GRAND RAPIDS", "BURLINGTON", "BOISE", "DELRAY BEACH", "EVANSVILLE", "FAIRFIELD", "NEW PORT RICHEY", "NAPLES", "SALISBURY", "HOLLYWOOD", "OCALA", "HAMILTON", "PENSACOLA", "ANTIOCH", "LARGO", "DANVILLE", "LODI", "SANTA ANA", "MACON", "SPARTANBURG", "ENCINO", "VIRGINIA BEACH", "ANAHEIM", "ANCHORAGE", "FT LAUDERDALE", "HUNTINGTON", "OVERLAND PARK", "PLANTATION", "SCOTTSDALE", "CONCORD", "CLARKSVILLE", "LAKELAND", "ST PETERSBURG", "LONGVIEW", "FREMONT", "LUBBOCK", "DES MOINES", "TEMPE", "ROANOKE", "MINNEAPOLIS", "JASPER", "ERIE", "MORRISTOWN", "SYRACUSE", "MONTGOMERY", "FARMINGTON", "WALNUT CREEK", "BELLEVUE", "KINGSPORT", "DURHAM", "EL PASO", "INDEPENDENCE", "GREENWOOD", "EUGENE", "BOCA RATON", "BLOOMINGTON", "TORRANCE", "HICKORY", "CAMDEN", "NOBLESVILLE", "GLEN BURNIE", "SAVANNAH", "MARYSVILLE", "DOVER", "SANTA ROSA", "NORTH LAS VEGAS", "JOHNSTOWN", "RENTON", "YORK", "WINCHESTER", "WORCESTER", "MELBOURNE", "ONTARIO", "LAKE WORTH", "HONOLULU", "REDDING", "PORTSMOUTH", "LITTLE ROCK", "BEDFORD", "WESTMINSTER", "FORT SMITH", "DES PLAINES", "TYLER", "ENGLEWOOD", "CORPUS CHRISTI", "HILLSBORO", "NEW ORLEANS", "POMPANO BEACH", "ASHEVILLE", "ST LOUIS", "OXFORD", "PEMBROKE PINES", "ROME", "GEORGETOWN", "METAIRIE", "FREDERICKSBURG", "CARROLLTON", "UNION CITY", "HENDERSONVILLE", "GREENFIELD", "CAPE CORAL", "SPRING HILL", "MERIDIAN", "PLYMOUTH", "KISSIMMEE", "HARRISBURG", "MANSFIELD", "FORT LAUDERDALE", "VALLEJO", "HUNTINGTON BEACH", "CONWAY", "FORT MYERS", "ROCKFORD", "EL CAJON", "CLACKAMAS", "PUYALLUP", "GILBERT", "PORT CHARLOTTE", "BOYNTON BEACH", "MUNCIE", "KINGSTON", "BROCKTON", "STAFFORD", "BRANDON", "ORANGE", "ANDOVER", "FORT WAYNE", "LANSING", "SMYRNA", "LITTLETON", "MARSHALL", "JOHNSON CITY", "MIDLAND", "PLANO", "ALLENTOWN", "SOMERSET", "TRENTON", "CAMBRIDGE", "WEST CHESTER", "SANTA CLARA", "TALLAHASSEE", "MONTICELLO", "JAMESTOWN", "PINELLAS PARK", "ALTOONA", "YOUNGSTOWN", "SLIDELL", "BROOKSVILLE", "PARIS", "BRUNSWICK", "DAVIE", "SHERMAN OAKS", "CORONA", "PRINCETON", "BILLINGS", "LAUREL", "SANTA FE", "CHICO", "ABERDEEN", "WOODBURY", "NEW ALBANY", "PORTAGE", "LIVONIA", "TOMS  ...

# %%
# Note population numbers are estimates from Wikipedia for the year 2018
print('Quantity of Pain Pills per Person: ','\n')
print('Livermore, California: ',calculateQuantityPerPerson(df,'BUYER_CITY',0,90269))
print('North Charleston, South Carolina: ',calculateQuantityPerPerson(df,'BUYER_CITY',1,113237))
print('Las Vegas, Nevada: ',calculateQuantityPerPerson(df,'BUYER_CITY',2,644644))
# Out:
# Quantity of Pain Pills per Person:
#
# Livermore, California:  58.33906435210316
# North Charleston, South Carolina:  41.95341628619621
# Las Vegas, Nevada:  5.566723649021785

# %% [markdown]
# Step 4: Compare top three states to the rest of the USA

# %%
drugCounts = quantityCounter(df,'DRUG_NAME')
plotHorizontalBarGraph(drugCounts,'QUANTITY','Most Popular Pain Pills in the USA','Quantity of Pain Pills',500,500,0,2)
del drugCounts
# Out:
# <div>
#
#
#             <div id="9abdb2e4-d13a-43c2-857b-2221e96c66bf" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9abdb2e4-d13a-43c2-857b-2221e96c66bf")) {
#                     Plotly.newPlot(
#                         '9abdb2e4-d13a-43c2-857b-2221e96c66bf',
#                         [{"marker": {"color": "rgba(0, 0, 255, 0.8)", "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "name": "Kaggle", "orientation": "h", "text": ["HYDROCODONE", "OXYCODONE"], "type": "bar", "uid": "1b0b7a05-dcdf-4f0d-9a33-f1ee930ec72d", "x": [244599198, 235667016], "y": ["HYDROCODONE", "OXYCODONE"]}],
#                         {"barmode": "group", "height": 500, "showlegend": false, "title": {"text": "Most Popular Pain Pills in the USA"}, "width": 500, "xaxis": {"title": {"text": "Quantity of Pain Pills"}}, "yaxis": {"automargin": true, "autorange": "reversed"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9abdb2e4-d13a-43c2-857b-2221e96c66bf');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# Pick a few states to focus on
value_list = ['CA','FL','TX','CO']
df = df[df.BUYER_STATE.isin(value_list)]
drugCounts = quantityCounter(df,'DRUG_NAME')
plotHorizontalBarGraph(drugCounts,'QUANTITY','Most Popular Pain Pills in CA, FL, and TX','Quantity of Pain Pills',500,500,0,2)
del drugCounts
# Out:
# <div>
#
#
#             <div id="494383b6-dfd2-4cd3-b9df-546bd59ced81" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("494383b6-dfd2-4cd3-b9df-546bd59ced81")) {
#                     Plotly.newPlot(
#                         '494383b6-dfd2-4cd3-b9df-546bd59ced81',
#                         [{"marker": {"color": "rgba(0, 0, 255, 0.8)", "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "name": "Kaggle", "orientation": "h", "text": ["HYDROCODONE", "OXYCODONE"], "type": "bar", "uid": "7b3abcaf-29f0-4113-87c2-eab0de685dea", "x": [76766151, 49026582], "y": ["HYDROCODONE", "OXYCODONE"]}],
#                         {"barmode": "group", "height": 500, "showlegend": false, "title": {"text": "Most Popular Pain Pills in CA, FL, and TX"}, "width": 500, "xaxis": {"title": {"text": "Quantity of Pain Pills"}}, "yaxis": {"automargin": true, "autorange": "reversed"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('494383b6-dfd2-4cd3-b9df-546bd59ced81');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# Step 5: Compare to data from Colorado

# %%
# Note population numbers are estimates from Wikipedia for the year 2018
value_list = ['CO']
df = df[df.BUYER_STATE.isin(value_list)]

# %%
print('Quantity of Pain Pills per Person: ','\n')
print('Denver: ',calculateQuantityPerPerson(df,'BUYER_CITY',1,716492))
print('Colorado Springs: ',calculateQuantityPerPerson(df,'BUYER_CITY',0,472688))
print('Pueblo: ',calculateQuantityPerPerson(df,'BUYER_CITY',2,111750))
# Out:
# Quantity of Pain Pills per Person:
#
# Denver:  0.8046942603685735
# Colorado Springs:  1.5133089902853467
# Pueblo:  4.497190156599553

# %% [markdown]
# Step 6: Make conclusions
# * Hydrocodone and oxycodone have similar sales levels in the USA.
# * California, Florida, and Texas consume more pain pills than any of other state.
# * Hydrocodone is more popular than oxycodone in California, Florida, and Texas.
# * Livermore, California consumes more pain pills than any other city in the USA.
