# %% [markdown]
# **Predict NCAA Basketball 2018
# **
#
# Here we will use Logistic Regression to predict the outcomes of every possible matchup in the 2018 March Madness basketball tournament.  Our classifier will make its decision based off of the values for 17 features.  One important feature is a ranking metric called ELO ([Link #1](https://en.wikipedia.org/wiki/Elo_rating_system), [Link #2](https://fivethirtyeight.com/features/how-we-calculate-nba-elo-ratings/)) while the remaining 16 features are traditional basketball metrics (described below).  Note that many functions are adapted from [this solution]( https://github.com/harvitronix/kaggle-march-madness-machine-learning) from 2016.

# %% [markdown]
# *Step 1: Import Libraries*

# %%
import pandas as pd
import numpy
import math
import csv
import random
from sklearn import cross_validation, linear_model, model_selection
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# *Step 2: Load Data*

# %%
folder = '../input'
season_data = pd.read_csv(folder + '/mens-machine-learning-competition-2018/RegularSeasonDetailedResults.csv')
tourney_data = pd.read_csv(folder + '/mens-machine-learning-competition-2018/NCAATourneyDetailedResults.csv')
seeds = pd.read_csv(folder + '/mens-machine-learning-competition-2018/NCAATourneySeeds.csv')
frames = [season_data, tourney_data]
all_data = pd.concat(frames)
stat_fields = ['score', 'fga', 'fgp', 'fga3', '3pp', 'ftp', 'or', 'dr',
                   'ast', 'to', 'stl', 'blk', 'pf']
prediction_year = 2018
base_elo = 1600
team_elos = {}
team_stats = {}
X = []
y = []
submission_data = []
def initialize_data():
    for i in range(1985, prediction_year+1):
        team_elos[i] = {}
        team_stats[i] = {}
initialize_data()

# %% [markdown]
# *Step 3: Explore Data*

# %%
all_data.head(10)
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
# 5    2003      11     1458      81     1186      55    H      0    26    57
# 6    2003      12     1161      80     1236      62    H      0    23    55
# 7    2003      12     1186      75     1457      61    N      0    28    62
# 8    2003      12     1194      71     1156      66    N      0    28    58
# 9    2003      12     1458      84     1296      56    H      0    32    67
#
#   ...   LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0 ...      10    16    22   10   22     8   18     9     2   20
# 1 ...      24     9    20   20   25     7   12     8     6   16
# 2 ...      26    14    23   31   22     9   12     2     5   23
# 3 ...      22     8    15   17   20     9   19     4     3   23
# 4 ...      16    17    27   21   15    12   10     7     1   14
# 5 ...      11    12    17    6   22     8   19     4     3   25
# 6 ...      15    20    28    9   21    11   30    10     4   28
# 7 ...      17    17    23    8   25    10   15    14     8   18
# 8 ...      18    12    27   13   26    13   25     8     2   18
# 9 ...      14     7    12    9   23    10   18     1     3   18
#
# [10 rows x 34 columns]

# %% [markdown]
# *Step 4: Define Helper Functions*

# %%
def get_elo(season, team):
    try:
        return team_elos[season][team]
    except:
        try:
            # Get the previous season's ending value.
            team_elos[season][team] = team_elos[season-1][team]
            return team_elos[season][team]
        except:
            # Get the starter elo.
            team_elos[season][team] = base_elo
            return team_elos[season][team]

def calc_elo(win_team, lose_team, season):
    winner_rank = get_elo(season, win_team)
    loser_rank = get_elo(season, lose_team)
    rank_diff = winner_rank - loser_rank
    exp = (rank_diff * -1) / 400
    odds = 1 / (1 + math.pow(10, exp))
    if winner_rank < 2100:
        k = 32
    elif winner_rank >= 2100 and winner_rank < 2400:
        k = 24
    else:
        k = 16
    new_winner_rank = round(winner_rank + (k * (1 - odds)))
    new_rank_diff = new_winner_rank - winner_rank
    new_loser_rank = loser_rank - new_rank_diff
    return new_winner_rank, new_loser_rank

def get_stat(season, team, field):
    try:
        l = team_stats[season][team][field]
        return sum(l) / float(len(l))
    except:
        return 0
    
def update_stats(season, team, fields):
    if team not in team_stats[season]:
        team_stats[season][team] = {}
    for key, value in fields.items():
        # Make sure we have the field.
        if key not in team_stats[season][team]:
            team_stats[season][team][key] = []
        if len(team_stats[season][team][key]) >= 9:
            team_stats[season][team][key].pop()
        team_stats[season][team][key].append(value)
        
def predict_winner(team_1, team_2, model, season, stat_fields):
    features = []
    # Team 1
    features.append(get_elo(season, team_1))
    for stat in stat_fields:
        features.append(get_stat(season, team_1, stat))
    # Team 2
    features.append(get_elo(season, team_2))
    for stat in stat_fields:
        features.append(get_stat(season, team_2, stat))
    return model.predict_proba([features])

# %% [markdown]
# *Step 5: Feature Selection and Feature Engineering*

# %% [markdown]
# Our classifier will make its decision based off of the values for 17 features.  One important feature is a ranking metric called ELO ([Link #1](https://en.wikipedia.org/wiki/Elo_rating_system), [Link #2](https://fivethirtyeight.com/features/how-we-calculate-nba-elo-ratings/)) while the remaining 16 features are traditional basketball metrics as described below:
#
# Features:
#
#             wfgm :  field goals made
#             wfga :  field goals attempted
#             wfgm3 :  three pointers made
#             wfga3 :  three pointers attempted
#             wftm :  free throws made
#             wfta :  free throws attempted
#             wor :  offensive rebounds
#             wdr :  defensive rebounds
#             wast :  assists
#             wto :  turnovers
#             wstl :  steals
#             wblk :  blocks
#             wpf :  personal fouls
#
# Engineered Features:
#
#             fgp :  field goal percentage
#             3pp :  three point percentage
#             ftp:  free throw percentage

# %%
def build_season_data(all_data):
    # Calculate the elo for every game for every team, each season.
    # Store the elo per season so we can retrieve their end elo
    # later in order to predict the tournaments without having to
    # inject the prediction into this loop.
    for index, row in all_data.iterrows():
        # Used to skip matchups where we don't have usable stats yet.
        skip = 0
        # Get starter or previous elos.
        team_1_elo = get_elo(row['Season'], row['WTeamID'])
        team_2_elo = get_elo(row['Season'], row['LTeamID'])
        # Add 100 to the home team (# taken from Nate Silver analysis.)
        if row['WLoc'] == 'H':
            team_1_elo += 100
        elif row['WLoc'] == 'A':
            team_2_elo += 100         
        # We'll create some arrays to use later.
        team_1_features = [team_1_elo]
        team_2_features = [team_2_elo]
        # Build arrays out of the stats we're tracking..
        for field in stat_fields:
            team_1_stat = get_stat(row['Season'], row['WTeamID'], field)
            team_2_stat = get_stat(row['Season'], row['LTeamID'], field)
            if team_1_stat is not 0 and team_2_stat is not 0:
                team_1_features.append(team_1_stat)
                team_2_features.append(team_2_stat)
            else:
                skip = 1
        if skip == 0:  # Make sure we have stats.
            # Randomly select left and right and 0 or 1 so we can train
            # for multiple classes.
            if random.random() > 0.5:
                X.append(team_1_features + team_2_features)
                y.append(0)
            else:
                X.append(team_2_features + team_1_features)
                y.append(1)
        # AFTER we add the current stuff to the prediction, update for
        # next time. Order here is key so we don't fit on data from the
        # same game we're trying to predict.
        if row['WFTA'] != 0 and row['LFTA'] != 0:
            stat_1_fields = {
                'score': row['WScore'],
                'fgp': row['WFGM'] / row['WFGA'] * 100,
                'fga': row['WFGA'],
                'fga3': row['WFGA3'],
                '3pp': row['WFGM3'] / row['WFGA3'] * 100,
                'ftp': row['WFTM'] / row['WFTA'] * 100,
                'or': row['WOR'],
                'dr': row['WDR'],
                'ast': row['WAst'],
                'to': row['WTO'],
                'stl': row['WStl'],
                'blk': row['WBlk'],
                'pf': row['WPF']
            }            
            stat_2_fields = {
                'score': row['LScore'],
                'fgp': row['LFGM'] / row['LFGA'] * 100,
                'fga': row['LFGA'],
                'fga3': row['LFGA3'],
                '3pp': row['LFGM3'] / row['LFGA3'] * 100,
                'ftp': row['LFTM'] / row['LFTA'] * 100,
                'or': row['LOR'],
                'dr': row['LDR'],
                'ast': row['LAst'],
                'to': row['LTO'],
                'stl': row['LStl'],
                'blk': row['LBlk'],
                'pf': row['LPF']
            }
            update_stats(row['Season'], row['WTeamID'], stat_1_fields)
            update_stats(row['Season'], row['LTeamID'], stat_2_fields)
        # Now that we've added them, calc the new elo.
        new_winner_rank, new_loser_rank = calc_elo(
            row['WTeamID'], row['LTeamID'], row['Season'])
        team_elos[row['Season']][row['WTeamID']] = new_winner_rank
        team_elos[row['Season']][row['LTeamID']] = new_loser_rank
    return X, y
X, y = build_season_data(all_data)

# %% [markdown]
# *Step 6: Use Logistic Regression To Predict Game Outcomes*

# %%
model = linear_model.LogisticRegression()
print("Let's hope to be correct 75% of the time")
print(cross_validation.cross_val_score(model, numpy.array(X), numpy.array(y), cv=10, scoring='accuracy', n_jobs=-1).mean())
model.fit(X, y)
tourney_teams = []
for index, row in seeds.iterrows():
    if row['Season'] == prediction_year:
        tourney_teams.append(row['TeamID'])
tourney_teams.sort()
for team_1 in tourney_teams:
    for team_2 in tourney_teams:
        if team_1 < team_2:
            prediction = predict_winner(
                team_1, team_2, model, prediction_year, stat_fields)
            label = str(prediction_year) + '_' + str(team_1) + '_' + \
                str(team_2)
            submission_data.append([label, prediction[0][0]])
# Out:
# Let's hope to be correct 75% of the time
# 0.7260128073395251

# %% [markdown]
# *Step 7: Submit Results*

# %%
print("Writing %d results." % len(submission_data))
submission_data2=pd.DataFrame(submission_data)
submission_data2.to_csv("submission1.csv", index=False)
def build_team_dict():
    team_ids = pd.read_csv(folder + '/mens-machine-learning-competition-2018/Teams.csv')
    team_id_map = {}
    for index, row in team_ids.iterrows():
        team_id_map[row['TeamID']] = row['TeamName']
    return team_id_map
team_id_map = build_team_dict()
readable = []
less_readable = []  # A version that's easy to look up.
for pred in submission_data:
    parts = pred[0].split('_')
    less_readable.append(
        [team_id_map[int(parts[1])], team_id_map[int(parts[2])], pred[1]])
    # Order them properly.
    if pred[1] > 0.5:
        winning = int(parts[1])
        losing = int(parts[2])
        proba = pred[1]
    else:
        winning = int(parts[2])
        losing = int(parts[1])
        proba = 1 - pred[1]
    readable.append(
        [
            '%s beats %s: %f' %
            (team_id_map[winning], team_id_map[losing], proba)
        ]
    )
readable
# Out:
# Writing 2278 results.
# [['Arizona beats Alabama: 0.782418'],
#  ['Arizona St beats Alabama: 0.518115'],
#  ['Arkansas beats Alabama: 0.563638'],
#  ['Auburn beats Alabama: 0.590357'],
#  ['Alabama beats Bucknell: 0.713181'],
#  ['Alabama beats Buffalo: 0.651474'],
#  ['Butler beats Alabama: 0.576445'],
#  ['Cincinnati beats Alabama: 0.786580'],
#  ['Clemson beats Alabama: 0.612985'],
#  ['Alabama beats Col Charleston: 0.710605'],
#  ['Creighton beats Alabama: 0.606804'],
#  ['Alabama beats CS Fullerton: 0.865036'],
#  ['Alabama beats Davidson: 0.526432'],
#  ['Duke beats Alabama: 0.814096'],
#  ['Florida beats Alabama: 0.615163'],
#  ['Florida St beats Alabama: 0.685759'],
#  ['Alabama beats Georgia St: 0.802545'],
#  ['Gonzaga beats Alabama: 0.784289'],
#  ['Houston beats Alabama: 0.607369'],
#  ['Alabama beats Iona: 0.791874'],
#  ['Kansas beats Alabama: 0.822081'],
#  ['Kansas St beats Alabama: 0.686178'],
#  ['Kentucky beats Alabama: 0.709947'],
#  ['Alabama beats Lipscomb: 0.862446'],
#  ['Alabama beats Long Island: 0.933204'],
#  ['Alabama beats Loyola-Chicago: 0.598182'],
#  ['Alabama beats Marshall: 0.695946'],
#  ['Miami FL beats Alabama: 0.648198'],
#  ['Michigan beats Alabama: 0.778106'],
#  ['Michigan St beats Alabama: 0.778053'],
#  ['Alabama beats Missouri: 0.560041'],
#  ['Alabama beats Montana: 0.755467'],
#  ['Alabama beats Murray St: 0.701352'],
#  ['Alabama beats NC Central: 0.950459'],
#  ['NC State beats Alabama: 0.527780'],
#  ['Nevada beats Alabama: 0.585662'],
#  ['Alabama beats New Mexico St: 0.608604'],
#  ['North Carolina beats Alabama: 0.711189'],
#  ['Ohio St beats Alabama: 0.554981'],
#  ['Oklahoma beats Alabama: 0.525383'],
#  ['Alabama beats Penn: 0.802807'],
#  ['Providence beats Alabama: 0.615098'],
#  ['Purdue beats Alabama: 0.766437'],
#  ['Alabama beats Radford: 0.901880'],
#  ['Rhode Island beats Alabama: 0.522642'],
#  ['Alabama beats S Dakota St: 0.684894'],
#  ['Alabama beats San Diego St: 0.546356'],
#  ['Seton Hall beats Alabama: 0.615903'],
#  ['Alabama beats SF Austin: 0.772705'],
#  ['St Bonaventure beats Alabama: 0.564764'],
#  ['Syracuse beats Alabama: 0.598655'],
#  ['TCU beats Alabama: 0.598386'],
#  ['Tennessee beats Alabama: 0.686848'],
#  ['Texas beats Alabama: 0.581866'],
#  ['Texas A&M beats Alabama: 0.553133'],
#  ['Texas Tech beats Alabama: 0.657834'],
#  ['Alabama beats TX Southern: 0.938485'],
#  ['UCLA beats Alabama: 0.629546'],
#  ['Alabama beats UMBC: 0.854454'],
#  ['Alabama beats UNC Greensboro: 0.727561'],
#  ['Villanova beats Alabama: 0.859574'],
#  ['Virginia beats Alabama: 0.842993'],
#  ['Virginia Tech beats Alabama: 0.623701'],
#  ['West Virginia beats Alabama: 0.795429'],
#  ['Wichita St beats Alabama: 0.729741'],
#  ['Alabama beats Wright St: 0.824842'],
#  ['Xavier beats Alabama: 0.794140'],
#  ['Arizona beats Arizona St: 0.761452'],
#  ['Arizona beats Arkansas: 0.726554'],
#  ['Arizona beats Auburn: 0.704269'],
#  ['Arizona beats Bucknell: 0.895110'],
#  ['Arizona beats Buffalo: 0.865142'],
#  ['Arizona beats Butler: 0.716050'],
#  ['Cincinnati beats Arizona: 0.517814'],
#  ['Arizona beats Clemson: 0.684228'],
#  ['Arizona beats Col Charleston: 0.893925'],
#  ['Arizona beats Creighton: 0.689814'],
#  ['Arizona beats CS Fullerton: 0.956516'],
#  ['Arizona beats Davidson: 0.792321'],
#  ['Duke beats Arizona: 0.560625'],
#  ['Arizona beats Florida: 0.682239'],
#  ['Arizona beats Florida St: 0.611300'],
#  ['Arizona beats Georgia St: 0.933107'],
#  ['Gonzaga beats Arizona: 0.514418'],
#  ['Arizona beats Houston: 0.689307'],
#  ['Arizona beats Iona: 0.928867'],
#  ['Kansas beats Arizona: 0.573798'],
#  ['Arizona beats Kansas St: 0.610839'],
#  ['Arizona beats Kentucky: 0.583710'],
#  ['Arizona beats Lipscomb: 0.955592'],
#  ['Arizona beats Long Island: 0.979570'],
#  ['Arizona beats Loyola-Chicago: 0.836313'],
#  ['Arizona beats Marshall: 0.887076'],
#  ['Arizona beats Miami FL: 0.650678'],
#  ['Michigan beats Arizona: 0.505378'],
#  ['Michigan St beats Arizona: 0.505301'],
#  ['Arizona beats Missouri: 0.813737'],
#  ['Arizona beats Montana: 0.913815'],
#  ['Arizona beats Murray St: 0.889623'],
#  ['Arizona beats NC Central: 0.985040'],
#  ['Arizona beats NC State: 0.754344'],
#  ['Arizona beats Nevada: 0.708289'],
#  ['Arizona beats New Mexico St: 0.842188'],
#  ['Arizona beats North Carolina: 0.582242'],
#  ['Arizona beats Ohio St: 0.733476'],
#  ['Arizona beats Oklahoma: 0.756121'],
#  ['Arizona beats Penn: 0.933210'],
#  ['Arizona beats Providence: 0.682298'],
#  ['Arizona beats Purdue: 0.511210'],
#  ['Arizona beats Radford: 0.969274'],
#  ['Arizona beats Rhode Island: 0.758142'],
#  ['Arizona beats S Dakota St: 0.881791'],
#  ['Arizona beats San Diego St: 0.805198'],
#  ['Arizona beats Seton Hall: 0.681561'],
#  ['Arizona beats SF Austin: 0.921057'],
#  ['Arizona beats St Bonaventure: 0.725643'],
#  ['Arizona beats Syracuse: 0.697049'],
#  ['Arizona beats TCU: 0.697286'],
#  ['Arizona beats Tennessee: 0.610098'],
#  ['Arizona beats Texas: 0.711506'],
#  ['Arizona beats Texas A&M: 0.734936'],
#  ['Arizona beats Texas Tech: 0.640951'],
#  ['Arizona beats TX Southern: 0.981259'],
#  ['Arizona beats UCLA: 0.668826'],
#  ['Arizona beats UMBC: 0.952715'],
#  ['Arizona beats UNC Greensboro: 0.901627'],
#  ['Villanova beats Arizona: 0.640746'],
#  ['Virginia beats Arizona: 0.610049'],
#  ['Arizona beats Virginia Tech: 0.674336'],
#  ['West Virginia beats Arizona: 0.531163'],
#  ['Arizona beats Wichita St: 0.559674'],
#  ['Arizona beats Wright St: 0.941731'],
#  ['Xavier beats Arizona: 0.529195'],
#  ['Arkansas beats Arizona St: 0.535137'],
#  ['Auburn beats Arizona St: 0.562245'],
#  ['Arizona St beats Bucknell: 0.736148'],
#  ['Arizona St beats Buffalo: 0.677145'],
#  ['Butler beats Arizona St: 0.548110'],
#  ['Cincinnati beats Arizona St: 0.766611'],
#  ['Clemson beats Arizona St: 0.585336'],
#  ['Arizona St beats Col Charleston: 0.733702'],
#  ['Creighton beats Arizona St: 0.579017'],
#  ['Arizona St beats CS Fullerton: 0.877925'],
#  ['Arizona St beats Davidson: 0.555023'],
#  ['Duke beats Arizona St: 0.796034'],
#  ['Florida beats Arizona St: 0.587565'],
#  ['Florida St beats Arizona St: 0.660429'],
#  ['Arizona St beats Georgia St: 0.820161'],
#  ['Gonzaga beats Arizona St: 0.764170'],
#  ['Houston beats Arizona St: 0.579594'],
#  ['Arizona St beats Iona: 0.810217'],
#  ['Kansas beats Arizona St: 0.804609'],
#  ['Kansas St beats Arizona St: 0.660865'],
#  ['Kentucky beats Arizona St: 0.685673'],
#  ['Arizona St beats Lipscomb: 0.875546'],
#  ['Arizona St beats Long Island: 0.940034'],
#  ['Arizona St beats Loyola-Chicago: 0.625522'],
#  ['Arizona St beats Marshall: 0.719751'],
#  ['Miami FL beats Arizona St: 0.621511'],
#  ['Michigan beats Arizona St: 0.757589'],
#  ['Michigan St beats Arizona St: 0.757532'],
#  ['Arizona St beats Missouri: 0.588190'],
#  ['Arizona St beats Montana: 0.776111'],
#  ['Arizona St beats Murray St: 0.724901'],
#  ['Arizona St beats NC Central: 0.955609'],
#  ['Arizona St beats NC State: 0.500981'],
#  ['Nevada beats Arizona St: 0.557470'],
#  ['Arizona St beats New Mexico St: 0.635667'],
#  ['North Carolina beats Arizona St: 0.686973'],
#  ['Ohio St beats Arizona St: 0.526390'],
#  ['Arizona St beats Oklahoma: 0.503385'],
#  ['Arizona St beats Penn: 0.820404'],
#  ['Providence beats Arizona St: 0.587499'],
#  ['Purdue beats Arizona St: 0.745194'],
#  ['Arizona St beats Radford: 0.911609'],
#  ['Arizona St beats Rhode Island: 0.506133'],
#  ['Arizona St beats S Dakota St: 0.709202'],
#  ['Arizona St beats San Diego St: 0.574716'],
#  ['Seton Hall beats Arizona St: 0.588323'],
#  ['Arizona St beats SF Austin: 0.792294'],
#  ['St Bonaventure beats Arizona St: 0.536276'],
#  ['Syracuse beats Arizona St: 0.570699'],
#  ['TCU beats Arizona St: 0.570425'],
#  ['Tennessee beats Arizona St: 0.661562'],
#  ['Texas beats Arizona St: 0.553613'],
#  ['Texas A&M beats Arizona St: 0.524525'],
#  ['Texas Tech beats Arizona St: 0.631462'],
#  ['Arizona St beats TX Southern: 0.944807'],
#  ['UCLA beats Arizona St: 0.602313'],
#  ['Arizona St beats UMBC: 0.868199'],
#  ['Arizona St beats UNC Greensboro: 0.749781'],
#  ['Villanova beats Arizona St: 0.845089'],
#  ['Virginia beats Arizona St: 0.827142'],
#  ['Virginia Tech beats Arizona St: 0.596313'],
#  ['West Virginia beats Arizona St: 0.776052'],
#  ['Wichita St beats Arizona St: 0.706439'],
#  ['Arizona St beats Wright St: 0.840863'],
#  ['Xavier beats Arizona St: 0.774676'],
#  ['Auburn beats Arkansas: 0.526734'],
#  ['Arkansas beats Bucknell: 0.763016'],
#  ['Arkansas beats Buffalo: 0.707635'],
#  ['Butler beats Arkansas: 0.512446'],
#  ['Cincinnati beats Arkansas: 0.740012'],
#  ['Clemson beats Arkansas: 0.550199'],
#  ['Arkansas beats Col Charleston: 0.760738'],
#  ['Creighton beats Arkansas: 0.543762'],
#  ['Arkansas beats CS Fullerton: 0.892464'],
#  ['Arkansas beats Davidson: 0.590064'],
#  ['Duke beats Arkansas: 0.771790'],
#  ['Florida beats Arkansas: 0.552473'],
#  ['Florida St beats Arkansas: 0.627607'],
#  ['Arkansas beats Georgia St: 0.840329'],
#  ['Gonzaga beats Arkansas: 0.737388'],
#  ['Houston beats Arkansas: 0.544349'],
#  ['Arkansas beats Iona: 0.831271'],
#  ['Kansas beats Arkansas: 0.781104'],
#  ['Kansas St beats Arkansas: 0.628061'],
#  ['Kentucky beats Arkansas: 0.654012'],
#  ['Arkansas beats Lipscomb: 0.890334'],
#  ['Arkansas beats Long Island: 0.947617'],
#  ['Arkansas beats Loyola-Chicago: 0.658428'],
#  ['Arkansas beats Marshall: 0.747716'],
#  ['Miami FL beats Arkansas: 0.587278'],
#  ['Michigan beats Arkansas: 0.730323'],
#  ['Michigan St beats Arkansas: 0.730262'],
#  ['Arkansas beats Missouri: 0.622396'],
#  ['Arkansas beats Montana: 0.800015'],
#  ['Arkansas beats Murray St: 0.752529'],
#  ['Arkansas beats NC Central: 0.961304'],
#  ['Arkansas beats NC State: 0.536726'],
#  ['Nevada beats Arkansas: 0.521901'],
#  ['Arkansas beats New Mexico St: 0.668154'],
#  ['North Carolina beats Arkansas: 0.655377'],
#  ['Arkansas beats Ohio St: 0.509395'],
#  ['Arkansas beats Oklahoma: 0.539116'],
#  ['Arkansas beats Penn: 0.840551'],
#  ['Providence beats Arkansas: 0.552405'],
#  ['Purdue beats Arkansas: 0.717055'],
#  ['Arkansas beats Radford: 0.922491'],
#  ['Arkansas beats Rhode Island: 0.541846'],
#  ['Arkansas beats S Dakota St: 0.737837'],
#  ['Arkansas beats San Diego St: 0.609297'],
#  ['Seton Hall beats Arkansas: 0.553246'],
#  ['Arkansas beats SF Austin: 0.814882'],
#  ['St Bonaventure beats Arkansas: 0.500529'],
#  ['Syracuse beats Arkansas: 0.535307'],
#  ['TCU beats Arkansas: 0.535028'],
#  ['Tennessee beats Arkansas: 0.628788'],
#  ['Texas beats Arkansas: 0.518001'],
#  ['Arkansas beats Texas A&M: 0.511264'],
#  ['Texas Tech beats Arkansas: 0.597547'],
#  ['Arkansas beats TX Southern: 0.951818'],
#  ['UCLA beats Arkansas: 0.567552'],
#  ['Arkansas beats UMBC: 0.883744'],
#  ['Arkansas beats UNC Greensboro: 0.775684'],
#  ['Villanova beats Arkansas: 0.825397'],
#  ['Virginia beats Arkansas: 0.805693'],
#  ['Virginia Tech beats Arkansas: 0.561409'],
#  ['West Virginia beats Arkansas: 0.750178'],
#  ['Wichita St beats Arkansas: 0.675881'],
#  ['Arkansas beats Wright St: 0.859109'],
#  ['Xavier beats Arkansas: 0.748694'],
#  ['Auburn beats Bucknell: 0.787658'],
#  ['Auburn beats Buffalo: 0.736043'],
#  ['Auburn beats Butler: 0.522930'],
#  ['Cincinnati beats Auburn: 0.711864'],
#  ['Clemson beats Auburn: 0.514971'],
#  ['Auburn beats Col Charleston: 0.785549'],
#  ['Creighton beats Auburn: 0.508479'],
#  ['Auburn beats CS Fullerton: 0.905316'],
#  ['Auburn beats Davidson: 0.623822'],
#  ['Duke beats Auburn: 0.745901'],
#  ['Florida beats Auburn: 0.517266'],
#  ['Florida St beats Auburn: 0.593967'],
#  ['Auburn beats Georgia St: 0.858423'],
#  ['Gonzaga beats Auburn: 0.709067'],
#  ['Houston beats Auburn: 0.509071'],
#  ['Auburn beats Iona: 0.850209'],
#  ['Kansas beats Auburn: 0.755938'],
#  ['Kansas St beats Auburn: 0.594436'],
#  ['Kentucky beats Auburn: 0.621318'],
#  ['Auburn beats Lipscomb: 0.903413'],
#  ['Auburn beats Long Island: 0.954216'],
#  ['Auburn beats Loyola-Chicago: 0.689519'],
#  ['Auburn beats Marshall: 0.773476'],
#  ['Miami FL beats Auburn: 0.552592'],
#  ['Michigan beats Auburn: 0.701549'],
#  ['Michigan St beats Auburn: 0.701484'],
#  ['Auburn beats Missouri: 0.655049'],
#  ['Auburn beats Montana: 0.821708'],
#  ['Auburn beats Murray St: 0.777944'],
#  ['Auburn beats NC Central: 0.966240'],
#  ['Auburn beats NC State: 0.571689'],
#  ['Auburn beats Nevada: 0.513476'],
#  ['Auburn beats New Mexico St: 0.698765'],
#  ['North Carolina beats Auburn: 0.622738'],
#  ['Auburn beats Ohio St: 0.544671'],
#  ['Auburn beats Oklahoma: 0.574041'],
#  ['Auburn beats Penn: 0.858624'],
#  ['Providence beats Auburn: 0.517197'],
#  ['Purdue beats Auburn: 0.687471'],
#  ['Auburn beats Radford: 0.932028'],
#  ['Auburn beats Rhode Island: 0.576727'],
#  ['Auburn beats S Dakota St: 0.764288'],
#  ['Auburn beats San Diego St: 0.642432'],
#  ['Seton Hall beats Auburn: 0.518047'],
#  ['Auburn beats SF Austin: 0.835295'],
#  ['Auburn beats St Bonaventure: 0.534808'],
#  ['Auburn beats Syracuse: 0.500028'],
#  ['Auburn beats TCU: 0.500309'],
#  ['Tennessee beats Auburn: 0.595186'],
#  ['Auburn beats Texas: 0.517378'],
#  ['Auburn beats Texas A&M: 0.546525'],
#  ['Texas Tech beats Auburn: 0.563081'],
#  ['Auburn beats TX Southern: 0.957911'],
#  ['UCLA beats Auburn: 0.532527'],
#  ['Auburn beats UMBC: 0.897518'],
#  ['Auburn beats UNC Greensboro: 0.799354'],
#  ['Villanova beats Auburn: 0.804046'],
#  ['Virginia beats Auburn: 0.782567'],
#  ['Virginia Tech beats Auburn: 0.526303'],
#  ['West Virginia beats Auburn: 0.722718'],
#  ['Wichita St beats Auburn: 0.644129'],
#  ['Auburn beats Wright St: 0.875390'],
#  ['Xavier beats Auburn: 0.721132'],
#  ['Buffalo beats Bucknell: 0.576004'],
#  ['Butler beats Bucknell: 0.775583'],
#  ['Cincinnati beats Bucknell: 0.903466'],
#  ['Clemson beats Bucknell: 0.800878'],
#  ['Col Charleston beats Bucknell: 0.508396'],
#  ['Creighton beats Bucknell: 0.796703'],
#  ['Bucknell beats CS Fullerton: 0.716232'],
#  ['Davidson beats Bucknell: 0.695527'],
#  ['Duke beats Bucknell: 0.917493'],
#  ['Florida beats Bucknell: 0.802340'],
#  ['Florida St beats Bucknell: 0.847132'],
#  ['Bucknell beats Georgia St: 0.615470'],
#  ['Gonzaga beats Bucknell: 0.902274'],
#  ['Houston beats Bucknell: 0.797086'],
#  ['Bucknell beats Iona: 0.599732'],
#  ['Kansas beats Bucknell: 0.921465'],
#  ['Kansas St beats Bucknell: 0.847383'],
#  ['Kentucky beats Bucknell: 0.861409'],
#  ['Bucknell beats Lipscomb: 0.711739'],
#  ['Bucknell beats Long Island: 0.846194'],
#  ['Loyola-Chicago beats Bucknell: 0.630420'],
#  ['Marshall beats Bucknell: 0.525938'],
#  ['Miami FL beats Bucknell: 0.823906'],
#  ['Michigan beats Bucknell: 0.899038'],
#  ['Michigan St beats Bucknell: 0.899010'],
#  ['Missouri beats Bucknell: 0.666097'],
#  ['Bucknell beats Montana: 0.548861'],
#  ['Murray St beats Bucknell: 0.519532'],
#  ['Bucknell beats NC Central: 0.883112'],
#  ['NC State beats Bucknell: 0.739457'],
#  ['Nevada beats Bucknell: 0.782105'],
#  ['New Mexico St beats Bucknell: 0.620216'],
#  ['North Carolina beats Bucknell: 0.862128'],
#  ['Ohio St beats Bucknell: 0.760009'],
#  ['Oklahoma beats Bucknell: 0.737600'],
#  ['Bucknell beats Penn: 0.615861'],
#  ['Providence beats Bucknell: 0.802296'],
#  ['Purdue beats Bucknell: 0.892852'],
#  ['Bucknell beats Radford: 0.783533'],
#  ['Rhode Island beats Bucknell: 0.735467'],
#  ['S Dakota St beats Bucknell: 0.538812'],
#  ['San Diego St beats Bucknell: 0.678297'],
#  ['Seton Hall beats Bucknell: 0.802835'],
#  ['Bucknell beats SF Austin: 0.572421'],
#  ['St Bonaventure beats Bucknell: 0.767176'],
#  ['Syracuse beats Bucknell: 0.791135'],
#  ['TCU beats Bucknell: 0.790949'],
#  ['Tennessee beats Bucknell: 0.847786'],
#  ['Texas beats Bucknell: 0.779431'],
#  ['Texas A&M beats Bucknell: 0.758643'],
#  ['Texas Tech beats Bucknell: 0.829992'],
#  ['Bucknell beats TX Southern: 0.857304'],
#  ['UCLA beats Bucknell: 0.811867'],
#  ['Bucknell beats UMBC: 0.698055'],
#  ['Bucknell beats UNC Greensboro: 0.512590'],
#  ['Villanova beats Bucknell: 0.939555'],
#  ['Virginia beats Bucknell: 0.931667'],
#  ['Virginia Tech beats Bucknell: 0.808021'],
#  ['West Virginia beats Bucknell: 0.908035'],
#  ['Wichita St beats Bucknell: 0.872720'],
#  ['Bucknell beats Wright St: 0.649670'],
#  ['Xavier beats Bucknell: 0.907373'],
#  ['Butler beats Buffalo: 0.724808'],
#  ['Cincinnati beats Buffalo: 0.877038'],
#  ['Clemson beats Buffalo: 0.754011'],
#  ['Buffalo beats Col Charleston: 0.559241'],
#  ['Creighton beats Buffalo: 0.749161'],
#  ['Buffalo beats CS Fullerton: 0.768083'],
#  ['Davidson beats Buffalo: 0.635160'],
#  ['Duke beats Buffalo: 0.894456'],
#  ['Florida beats Buffalo: 0.755712'],
#  ['Florida St beats Buffalo: 0.808549'],
#  ['Buffalo beats Georgia St: 0.677440'],
#  ['Gonzaga beats Buffalo: 0.875564'],
#  ['Houston beats Buffalo: 0.749606'],
#  ['Buffalo beats Iona: 0.662849'],
#  ['Kansas beats Buffalo: 0.899416'],
#  ['Kansas St beats Buffalo: 0.808850'],
#  ['Kentucky beats Buffalo: 0.825688'],
#  ['Buffalo beats Lipscomb: 0.764140'],
#  ['Buffalo beats Long Island: 0.878332'],
#  ['Loyola-Chicago beats Buffalo: 0.565214'],
#  ['Buffalo beats Marshall: 0.541858'],
#  ['Miami FL beats Buffalo: 0.780977'],
#  ['Michigan beats Buffalo: 0.871569'],
#  ['Michigan St beats Buffalo: 0.871535'],
#  ['Missouri beats Buffalo: 0.603224'],
#  ['Buffalo beats Montana: 0.614849'],
#  ['Buffalo beats Murray St: 0.548225'],
#  ['Buffalo beats NC Central: 0.908371'],
#  ['NC State beats Buffalo: 0.683840'],
#  ['Nevada beats Buffalo: 0.732296'],
#  ['New Mexico St beats Buffalo: 0.554482'],
#  ['North Carolina beats Buffalo: 0.826555'],
#  ['Ohio St beats Buffalo: 0.707042'],
#  ['Oklahoma beats Buffalo: 0.681758'],
#  ['Buffalo beats Penn: 0.677801'],
#  ['Providence beats Buffalo: 0.755661'],
#  ['Purdue beats Buffalo: 0.863956'],
#  ['Buffalo beats Radford: 0.826073'],
#  ['Rhode Island beats Buffalo: 0.679368'],
#  ['Buffalo beats S Dakota St: 0.528995'],
#  ['San Diego St beats Buffalo: 0.616398'],
#  ['Seton Hall beats Buffalo: 0.756289'],
#  ['Buffalo beats SF Austin: 0.637240'],
#  ['St Bonaventure beats Buffalo: 0.715197'],
#  ['Syracuse beats Buffalo: 0.742711'],
#  ['TCU beats Buffalo: 0.742497'],
#  ['Tennessee beats Buffalo: 0.809331'],
#  ['Texas beats Buffalo: 0.729223'],
#  ['Texas A&M beats Buffalo: 0.705491'],
#  ['Texas Tech beats Buffalo: 0.788165'],
#  ['Buffalo beats TX Southern: 0.887429'],
#  ['UCLA beats Buffalo: 0.766833'],
#  ['Buffalo beats UMBC: 0.752078'],
#  ['Buffalo beats UNC Greensboro: 0.579822'],
#  ['Villanova beats Buffalo: 0.922155'],
#  ['Virginia beats Buffalo: 0.912209'],
#  ['Virginia Tech beats Buffalo: 0.762336'],
#  ['West Virginia beats Buffalo: 0.882695'],
#  ['Wichita St beats Buffalo: 0.839371'],
#  ['Buffalo beats Wright St: 0.708737'],
#  ['Xavier beats Buffalo: 0.881875'],
#  ['Cincinnati beats Butler: 0.748516'],
#  ['Clemson beats Butler: 0.561230'],
#  ['Butler beats Col Charleston: 0.752511'],
#  ['Creighton beats Butler: 0.554823'],
#  ['Butler beats CS Fullerton: 0.888101'],
#  ['Butler beats Davidson: 0.579214'],
#  ['Duke beats Butler: 0.779564'],
#  ['Florida beats Butler: 0.563492'],
#  ['Florida St beats Butler: 0.637989'],
#  ['Butler beats Georgia St: 0.834242'],
#  ['Gonzaga beats Butler: 0.745948'],
#  ['Houston beats Butler: 0.555408'],
#  ['Butler beats Iona: 0.824911'],
#  ['Kansas beats Butler: 0.788647'],
#  ['Kansas St beats Butler: 0.638438'],
#  ['Kentucky beats Butler: 0.664052'],
#  ['Butler beats Lipscomb: 0.885895'],
#  ['Butler beats Long Island: 0.945355'],
#  ['Butler beats Loyola-Chicago: 0.648309'],
#  ['Butler beats Marshall: 0.739195'],
#  ['Miami FL beats Butler: 0.598064'],
#  ['Michigan beats Butler: 0.739032'],
#  ['Michigan St beats Butler: 0.738972'],
#  ['Butler beats Missouri: 0.611839'],
#  ['Butler beats Montana: 0.792770'],
#  ['Butler beats Murray St: 0.744115'],
#  ['Butler beats NC Central: 0.959607'],
#  ['Butler beats NC State: 0.525599'],
#  ['Nevada beats Butler: 0.533037'],
#  ['Butler beats New Mexico St: 0.658174'],
#  ['North Carolina beats Butler: 0.665398'],
#  ['Ohio St beats Butler: 0.501774'],
#  ['Butler beats Oklahoma: 0.527996'],
#  ['Butler beats Penn: 0.834471'],
#  ['Providence beats Butler: 0.563425'],
#  ['Purdue beats Butler: 0.726032'],
#  ['Butler beats Radford: 0.919236'],
#  ['Butler beats Rhode Island: 0.530735'],
#  ['Butler beats S Dakota St: 0.729103'],
#  ['Butler beats San Diego St: 0.598611'],
#  ['Seton Hall beats Butler: 0.564261'],
#  ['Butler beats SF Austin: 0.808047'],
#  ['St Bonaventure beats Butler: 0.511697'],
#  ['Syracuse beats Butler: 0.546402'],
#  ['TCU beats Butler: 0.546124'],
#  ['Tennessee beats Butler: 0.639156'],
#  ['Texas beats Butler: 0.529146'],
#  ['Butler beats Texas A&M: 0.500096'],
#  ['Texas Tech beats Butler: 0.608243'],
#  ['Butler beats TX Southern: 0.949727'],
#  ['UCLA beats Butler: 0.578483'],
#  ['Butler beats UMBC: 0.879074'],
#  ['Butler beats UNC Greensboro: 0.767814'],
#  ['Villanova beats Butler: 0.831743'],
#  ['Virginia beats Butler: 0.812593'],
#  ['Virginia Tech beats Butler: 0.572379'],
#  ['West Virginia beats Butler: 0.758458'],
#  ['Wichita St beats Butler: 0.685591'],
#  ['Butler beats Wright St: 0.853613'],
#  ['Xavier beats Butler: 0.757007'],
#  ['Cincinnati beats Clemson: 0.709684'],
#  ['Cincinnati beats Col Charleston: 0.904827'],
#  ['Cincinnati beats Creighton: 0.715007'],
#  ['Cincinnati beats CS Fullerton: 0.961264'],
#  ['Cincinnati beats Davidson: 0.811464'],
#  ['Duke beats Cincinnati: 0.530742'],
#  ['Cincinnati beats Florida: 0.707787'],
#  ['Cincinnati beats Florida St: 0.639538'],
#  ['Cincinnati beats Georgia St: 0.940251'],
#  ['Cincinnati beats Gonzaga: 0.515717'],
#  ['Cincinnati beats Houston: 0.714524'],
#  ['Cincinnati beats Iona: 0.936433'],
#  ['Kansas beats Cincinnati: 0.544082'],
#  ['Cincinnati beats Kansas St: 0.639090'],
#  ['Cincinnati beats Kentucky: 0.612682'],
#  ['Cincinnati beats Lipscomb: 0.960437'],
#  ['Cincinnati beats Long Island: 0.981849'],
#  ['Cincinnati beats Loyola-Chicago: 0.852157'],
#  ['Cincinnati beats Marshall: 0.898603'],
#  ['Cincinnati beats Miami FL: 0.677564'],
#  ['Cincinnati beats Michigan: 0.524746'],
#  ['Cincinnati beats Michigan St: 0.524823'],
#  ['Cincinnati beats Missouri: 0.831326'],
#  ['Cincinnati beats Montana: 0.922850'],
#  ['Cincinnati beats Murray St: 0.900918'],
#  ['Cincinnati beats NC Central: 0.986717'],
#  ['Cincinnati beats NC State: 0.775998'],
#  ['Cincinnati beats Nevada: 0.732563'],
#  ['Cincinnati beats New Mexico St: 0.857560'],
#  ['Cincinnati beats North Carolina: 0.611249'],
#  ['Cincinnati beats Ohio St: 0.756375'],
#  ['Cincinnati beats Oklahoma: 0.777664'],
#  ['Cincinnati beats Penn: 0.940344'],
#  ['Cincinnati beats Providence: 0.707843'],
#  ['Cincinnati beats Purdue: 0.541262'],
#  ['Cincinnati beats Radford: 0.972669'],
#  ['Cincinnati beats Rhode Island: 0.779559'],
#  ['Cincinnati beats S Dakota St: 0.893793'],
#  ['Cincinnati beats San Diego St: 0.823419'],
#  ['Cincinnati beats Seton Hall: 0.707139'],
#  ['Cincinnati beats SF Austin: 0.929391'],
#  ['Cincinnati beats St Bonaventure: 0.748985'],
#  ['Cincinnati beats Syracuse: 0.721891'],
#  ['Cincinnati beats TCU: 0.722116'],
#  ['Cincinnati beats Tennessee: 0.638371'],
#  ['Cincinnati beats Texas: 0.735613'],
#  ['Cincinnati beats Texas A&M: 0.757751'],
#  ['Cincinnati beats Texas Tech: 0.668204'],
#  ['Cincinnati beats TX Southern: 0.983353'],
#  ['Cincinnati beats UCLA: 0.694969'],
#  ['Cincinnati beats UMBC: 0.957860'],
#  ['Cincinnati beats UNC Greensboro: 0.911816'],
#  ['Villanova beats Cincinnati: 0.612546'],
#  ['Virginia beats Cincinnati: 0.581014'],
#  ['Cincinnati beats Virginia Tech: 0.700240'],
#  ['West Virginia beats Cincinnati: 0.501059'],
#  ['Cincinnati beats Wichita St: 0.589142'],
#  ['Cincinnati beats Wright St: 0.948006'],
#  ['Cincinnati beats Xavier: 0.500916'],
#  ['Clemson beats Col Charleston: 0.791675'],
#  ['Clemson beats Creighton: 0.500706'],
#  ['Clemson beats CS Fullerton: 0.908419'],
#  ['Clemson beats Davidson: 0.632405'],
#  ['Duke beats Clemson: 0.738874'],
#  ['Florida beats Clemson: 0.508086'],
#  ['Florida St beats Clemson: 0.585075'],
#  ['Clemson beats Georgia St: 0.862830'],
#  ['Gonzaga beats Clemson: 0.701429'],
#  ['Clemson beats Houston: 0.500114'],
#  ['Clemson beats Iona: 0.854828'],
#  ['Kansas beats Clemson: 0.749095'],
#  ['Kansas St beats Clemson: 0.585547'],
#  ['Kentucky beats Clemson: 0.612635'],
#  ['Clemson beats Lipscomb: 0.906572'],
#  ['Clemson beats Long Island: 0.955795'],
#  ['Clemson beats Loyola-Chicago: 0.697330'],
#  ['Clemson beats Marshall: 0.779850'],
#  ['Miami FL beats Clemson: 0.543491'],
#  ['Michigan beats Clemson: 0.693799'],
#  ['Michigan St beats Clemson: 0.693733'],
#  ['Clemson beats Missouri: 0.663304'],
#  ['Clemson beats Montana: 0.827028'],
#  ['Clemson beats Murray St: 0.784226'],
#  ['Clemson beats NC Central: 0.967418'],
#  ['Clemson beats NC State: 0.580661'],
#  ['Clemson beats Nevada: 0.522650'],
#  ['Clemson beats New Mexico St: 0.706443'],
#  ['North Carolina beats Clemson: 0.614067'],
#  ['Clemson beats Ohio St: 0.553768'],
#  ['Clemson beats Oklahoma: 0.583001'],
#  ['Clemson beats Penn: 0.863026'],
#  ['Providence beats Clemson: 0.508017'],
#  ['Purdue beats Clemson: 0.679523'],
#  ['Clemson beats Radford: 0.934319'],
#  ['Clemson beats Rhode Island: 0.585670'],
#  ['Clemson beats S Dakota St: 0.770843'],
#  ['Clemson beats San Diego St: 0.650828'],
#  ['Seton Hall beats Clemson: 0.508867'],
#  ['Clemson beats SF Austin: 0.840288'],
#  ['Clemson beats St Bonaventure: 0.543937'],
#  ['Clemson beats Syracuse: 0.509214'],
#  ['Clemson beats TCU: 0.509494'],
#  ['Tennessee beats Clemson: 0.586302'],
#  ['Clemson beats Texas: 0.526546'],
#  ['Clemson beats Texas A&M: 0.555615'],
#  ['Texas Tech beats Clemson: 0.554021'],
#  ['Clemson beats TX Southern: 0.959368'],
#  ['UCLA beats Clemson: 0.523370'],
#  ['Clemson beats UMBC: 0.900849'],
#  ['Clemson beats UNC Greensboro: 0.805183'],
#  ['Villanova beats Clemson: 0.798192'],
#  ['Virginia beats Clemson: 0.776250'],
#  ['Virginia Tech beats Clemson: 0.517134'],
#  ['West Virginia beats Clemson: 0.715295'],
#  ['Wichita St beats Clemson: 0.635662'],
#  ['Clemson beats Wright St: 0.879343'],
#  ['Xavier beats Clemson: 0.713683'],
#  ['Creighton beats Col Charleston: 0.800399'],
#  ['Col Charleston beats CS Fullerton: 0.711539'],
#  ['Davidson beats Col Charleston: 0.700372'],
#  ['Duke beats Col Charleston: 0.919216'],
#  ['Florida beats Col Charleston: 0.805959'],
#  ['Florida St beats Col Charleston: 0.850084'],
#  ['Col Charleston beats Georgia St: 0.610017'],
#  ['Gonzaga beats Col Charleston: 0.904282'],
#  ['Houston beats Col Charleston: 0.800778'],
#  ['Col Charleston beats Iona: 0.594203'],
#  ['Kansas beats Col Charleston: 0.923112'],
#  ['Kansas St beats Col Charleston: 0.850332'],
#  ['Kentucky beats Col Charleston: 0.864129'],
#  ['Col Charleston beats Lipscomb: 0.707001'],
#  ['Col Charleston beats Long Island: 0.843180'],
#  ['Loyola-Chicago beats Col Charleston: 0.635758'],
#  ['Marshall beats Col Charleston: 0.531664'],
#  ['Miami FL beats Col Charleston: 0.827216'],
#  ['Michigan beats Col Charleston: 0.901104'],
#  ['Michigan St beats Col Charleston: 0.901077'],
#  ['Missouri beats Col Charleston: 0.671188'],
#  ['Col Charleston beats Montana: 0.543165'],
#  ['Murray St beats Col Charleston: 0.525266'],
#  ['Col Charleston beats NC Central: 0.880718'],
#  ['NC State beats Col Charleston: 0.743860'],
#  ['Nevada beats Col Charleston: 0.785996'],
#  ['New Mexico St beats Col Charleston: 0.625614'],
#  ['North Carolina beats Col Charleston: 0.864837'],
#  ['Ohio St beats Col Charleston: 0.764176'],
#  ['Oklahoma beats Col Charleston: 0.742024'],
#  ['Col Charleston beats Penn: 0.610410'],
#  ['Providence beats Col Charleston: 0.805916'],
#  ['Purdue beats Col Charleston: 0.895031'],
#  ['Col Charleston beats Radford: 0.779610'],
#  ['Rhode Island beats Col Charleston: 0.739914'],
#  ['S Dakota St beats Col Charleston: 0.544517'],
#  ['San Diego St beats Col Charleston: 0.683291'],
#  ['Seton Hall beats Col Charleston: 0.806447'],
#  ['Col Charleston beats SF Austin: 0.566787'],
#  ['St Bonaventure beats Col Charleston: 0.771255'],
#  ['Syracuse beats Col Charleston: 0.794906'],
#  ['TCU beats Col Charleston: 0.794724'],
#  ['Tennessee beats Col Charleston: 0.850727'],
#  ['Texas beats Col Charleston: 0.783356'],
#  ['Texas A&M beats Col Charleston: 0.762825'],
#  ['Texas Tech beats Col Charleston: 0.833210'],
#  ['Col Charleston beats TX Southern: 0.854469'],
#  ['UCLA beats Col Charleston: 0.815351'],
#  ['Col Charleston beats UMBC: 0.693190'],
#  ['Col Charleston beats UNC Greensboro: 0.506847'],
#  ['Villanova beats Col Charleston: 0.940847'],
#  ['Virginia beats Col Charleston: 0.933115'],
#  ['Virginia Tech beats Col Charleston: 0.811560'],
#  ['West Virginia beats Col Charleston: 0.909936'],
#  ['Wichita St beats Col Charleston: 0.875250'],
#  ['Col Charleston beats Wright St: 0.644422'],
#  ['Xavier beats Col Charleston: 0.909287'],
#  ['Creighton beats CS Fullerton: 0.910871'],
#  ['Creighton beats Davidson: 0.639312'],
#  ['Duke beats Creighton: 0.733078'],
#  ['Florida beats Creighton: 0.500628'],
#  ['Florida St beats Creighton: 0.577816'],
#  ['Creighton beats Georgia St: 0.866323'],
#  ['Gonzaga beats Creighton: 0.695144'],
#  ['Creighton beats Houston: 0.507571'],
#  ['Creighton beats Iona: 0.858491'],
#  ['Kansas beats Creighton: 0.743446'],
#  ['Kansas St beats Creighton: 0.578289'],
#  ['Kentucky beats Creighton: 0.605532'],
#  ['Creighton beats Lipscomb: 0.909068'],
#  ['Creighton beats Long Island: 0.957038'],
#  ['Creighton beats Loyola-Chicago: 0.703590'],
#  ['Creighton beats Marshall: 0.784929'],
#  ['Miami FL beats Creighton: 0.536080'],
#  ['Michigan beats Creighton: 0.687425'],
#  ['Michigan St beats Creighton: 0.687359'],
#  ['Creighton beats Missouri: 0.669933'],
#  ['Creighton beats Montana: 0.831254'],
#  ['Creighton beats Murray St: 0.789232'],
#  ['Creighton beats NC Central: 0.968345'],
#  ['Creighton beats NC State: 0.587907'],
#  ['Creighton beats Nevada: 0.530087'],
#  ['Creighton beats New Mexico St: 0.712591'],
#  ['North Carolina beats Creighton: 0.606974'],
#  ['Creighton beats Ohio St: 0.561127'],
#  ['Creighton beats Oklahoma: 0.590235'],
#  ['Creighton beats Penn: 0.866514'],
#  ['Providence beats Creighton: 0.500560'],
#  ['Purdue beats Creighton: 0.672991'],
#  ['Creighton beats Radford: 0.936126'],
#  ['Creighton beats Rhode Island: 0.592890'],
#  ['Creighton beats S Dakota St: 0.776070'],
#  ['Creighton beats San Diego St: 0.657577'],
#  ['Seton Hall beats Creighton: 0.501410'],
#  ['Creighton beats SF Austin: 0.844251'],
#  ['Creighton beats St Bonaventure: 0.551327'],
#  ['Creighton beats Syracuse: 0.516667'],
#  ['Creighton beats TCU: 0.516946'],
#  ['Tennessee beats Creighton: 0.579049'],
#  ['Creighton beats Texas: 0.533977'],
#  ['Creighton beats Texas A&M: 0.562968'],
#  ['Texas Tech beats Creighton: 0.546639'],
#  ['Creighton beats TX Southern: 0.960515'],
#  ['UCLA beats Creighton: 0.515924'],
#  ['Creighton beats UMBC: 0.903482'],
#  ['Creighton beats UNC Greensboro: 0.809820'],
#  ['Villanova beats Creighton: 0.793344'],
#  ['Virginia beats Creighton: 0.771025'],
#  ['Virginia Tech beats Creighton: 0.509681'],
#  ['West Virginia beats Creighton: 0.709181'],
#  ['Wichita St beats Creighton: 0.628726'],
#  ['Creighton beats Wright St: 0.882473'],
#  ['Xavier beats Creighton: 0.707549'],
#  ['Davidson beats CS Fullerton: 0.852195'],
#  ['Duke beats CS Fullerton: 0.965597'],
#  ['Florida beats CS Fullerton: 0.911074'],
#  ['Florida St beats CS Fullerton: 0.933275'],
#  ['Georgia St beats CS Fullerton: 0.611939'],
#  ['Gonzaga beats CS Fullerton: 0.958853'],
#  ['Houston beats CS Fullerton: 0.908380'],
#  ['Iona beats CS Fullerton: 0.627495'],
#  ['Kansas beats CS Fullerton: 0.967336'],
#  ['Kansas St beats CS Fullerton: 0.933396'],
#  ['Kentucky beats CS Fullerton: 0.940075'],
#  ['Lipscomb beats CS Fullerton: 0.505498'],
#  ['CS Fullerton beats Long Island: 0.685513'],
#  ['Loyola-Chicago beats CS Fullerton: 0.811510'],
#  ['Marshall beats CS Fullerton: 0.736854'],
#  ['Miami FL beats CS Fullerton: 0.921931'],
#  ['Michigan beats CS Fullerton: 0.957402'],
#  ['Michigan St beats CS Fullerton: 0.957389'],
#  ['Missouri beats CS Fullerton: 0.834301'],
#  ['Montana beats CS Fullerton: 0.674753'],
#  ['Murray St beats CS Fullerton: 0.731845'],
#  ['CS Fullerton beats NC Central: 0.749585'],
#  ['NC State beats CS Fullerton: 0.877502'],
#  ['Nevada beats CS Fullerton: 0.900591'],
#  ['New Mexico St beats CS Fullerton: 0.804758'],
#  ['North Carolina beats CS Fullerton: 0.940415'],
#  ['Ohio St beats CS Fullerton: 0.888802'],
#  ['Oklahoma beats CS Fullerton: 0.876464'],
#  ['Penn beats CS Fullerton: 0.611547'],
#  ['Providence beats CS Fullerton: 0.911051'],
#  ['Purdue beats CS Fullerton: 0.954612'],
#  ['CS Fullerton beats Radford: 0.589171'],
#  ['Rhode Island beats CS Fullerton: 0.875269'],
#  ['S Dakota St beats CS Fullerton: 0.746758'],
#  ['San Diego St beats CS Fullerton: 0.841814'],
#  ['Seton Hall beats CS Fullerton: 0.911327'],
#  ['SF Austin beats CS Fullerton: 0.653418'],
#  ['St Bonaventure beats CS Fullerton: 0.892666'],
#  ['Syracuse beats CS Fullerton: 0.905305'],
#  ['TCU beats CS Fullerton: 0.905209'],
#  ['Tennessee beats CS Fullerton: 0.933589'],
#  ['Texas beats CS Fullerton: 0.899184'],
#  ['Texas A&M beats CS Fullerton: 0.888061'],
#  ['Texas Tech beats CS Fullerton: 0.924937'],
#  ['CS Fullerton beats TX Southern: 0.704171'],
#  ['UCLA beats CS Fullerton: 0.915909'],
#  ['UMBC beats CS Fullerton: 0.521931'],
#  ['UNC Greensboro beats CS Fullerton: 0.705881'],
#  ['Villanova beats CS Fullerton: 0.975144'],
#  ['Virginia beats CS Fullerton: 0.971761'],
#  ['Virginia Tech beats CS Fullerton: 0.913965'],
#  ['West Virginia beats CS Fullerton: 0.961421'],
#  ['Wichita St beats CS Fullerton: 0.945373'],
#  ['Wright St beats CS Fullerton: 0.576457'],
#  ['Xavier beats CS Fullerton: 0.961127'],
#  ['Duke beats Davidson: 0.834661'],
#  ['Florida beats Davidson: 0.648226'],
#  ['Florida St beats Davidson: 0.715561'],
#  ['Davidson beats Georgia St: 0.779042'],
#  ['Gonzaga beats Davidson: 0.807371'],
#  ['Houston beats Davidson: 0.640711'],
#  ['Davidson beats Iona: 0.767470'],
#  ['Kansas beats Davidson: 0.841935'],
#  ['Kansas St beats Davidson: 0.715957'],
#  ['Kentucky beats Davidson: 0.738330'],
#  ['Davidson beats Lipscomb: 0.844694'],
#  ['Davidson beats Long Island: 0.923776'],
#  ['Davidson beats Loyola-Chicago: 0.563582'],
#  ['Davidson beats Marshall: 0.665051'],
#  ['Miami FL beats Davidson: 0.679899'],
#  ['Michigan beats Davidson: 0.801683'],
#  ['Michigan St beats Davidson: 0.801634'],
#  ['Davidson beats Missouri: 0.524766'],
#  ['Davidson beats Montana: 0.728258'],
#  ['Davidson beats Murray St: 0.670746'],
#  ['Davidson beats NC Central: 0.943319'],
#  ['NC State beats Davidson: 0.563017'],
#  ['Nevada beats Davidson: 0.619692'],
#  ['Davidson beats New Mexico St: 0.574263'],
#  ['North Carolina beats Davidson: 0.739495'],
#  ['Ohio St beats Davidson: 0.589766'],
#  ['Oklahoma beats Davidson: 0.560650'],
#  ['Davidson beats Penn: 0.779327'],
#  ['Providence beats Davidson: 0.648164'],
#  ['Purdue beats Davidson: 0.790921'],
#  ['Davidson beats Radford: 0.888559'],
#  ['Rhode Island beats Davidson: 0.557941'],
#  ['Davidson beats S Dakota St: 0.653435'],
#  ['Davidson beats San Diego St: 0.510942'],
#  ['Seton Hall beats Davidson: 0.648939'],
#  ['Davidson beats SF Austin: 0.746771'],
#  ['St Bonaventure beats Davidson: 0.599336'],
#  ['Syracuse beats Davidson: 0.632288'],
#  ['TCU beats Davidson: 0.632028'],
#  ['Tennessee beats Davidson: 0.716589'],
#  ['Texas beats Davidson: 0.616004'],
#  ['Texas A&M beats Davidson: 0.587956'],
#  ['Texas Tech beats Davidson: 0.689083'],
#  ['Davidson beats TX Southern: 0.929747'],
#  ['UCLA beats Davidson: 0.662052'],
#  ['Davidson beats UMBC: 0.835866'],
#  ['Davidson beats UNC Greensboro: 0.698487'],
#  ['Villanova beats Davidson: 0.875875'],
#  ['Virginia beats Davidson: 0.860907'],
#  ['Virginia Tech beats Davidson: 0.656440'],
#  ['West Virginia beats Davidson: 0.817596'],
#  ['Wichita St beats Davidson: 0.756851'],
#  ['Davidson beats Wright St: 0.803343'],
#  ['Xavier beats Davidson: 0.816415'],
#  ['Duke beats Florida: 0.738624'],
#  ['Duke beats Florida St: 0.674263'],
#  ['Duke beats Georgia St: 0.948347'],
#  ['Duke beats Gonzaga: 0.554053'],
#  ['Duke beats Houston: 0.744907'],
#  ['Duke beats Iona: 0.945016'],
#  ['Kansas beats Duke: 0.505653'],
#  ['Duke beats Kansas St: 0.673836'],
#  ['Duke beats Kentucky: 0.648573'],
#  ['Duke beats Lipscomb: 0.965896'],
#  ['Duke beats Long Island: 0.984402'],
#  ['Duke beats Loyola-Chicago: 0.870546'],
#  ['Duke beats Marshall: 0.911812'],
#  ['Duke beats Miami FL: 0.710286'],
#  ['Duke beats Michigan: 0.562973'],
#  ['Duke beats Michigan St: 0.563048'],
#  ['Duke beats Missouri: 0.851855'],
#  ['Duke beats Montana: 0.933136'],
#  ['Duke beats Murray St: 0.913855'],
#  ['Duke beats NC Central: 0.988593'],
#  ['Duke beats NC State: 0.801654'],
#  ['Duke beats Nevada: 0.761666'],
#  ['Duke beats New Mexico St: 0.875375'],
#  ['Duke beats North Carolina: 0.647196'],
#  ['Duke beats Ohio St: 0.783653'],
#  ['Duke beats Oklahoma: 0.803178'],
#  ['Duke beats Penn: 0.948428'],
#  ['Duke beats Providence: 0.738677'],
#  ['Duke beats Purdue: 0.579226'],
#  ['Duke beats Radford: 0.976482'],
#  ['Duke beats Rhode Island: 0.804910'],
#  ['Duke beats S Dakota St: 0.907564'],
#  ['Duke beats San Diego St: 0.844731'],
#  ['Duke beats Seton Hall: 0.738020'],
#  ['Duke beats SF Austin: 0.938863'],
#  ['Duke beats St Bonaventure: 0.776846'],
#  ['Duke beats Syracuse: 0.751762'],
#  ['Duke beats TCU: 0.751971'],
#  ['Duke beats Tennessee: 0.673152'],
#  ['Duke beats Texas: 0.764491'],
#  ['Duke beats Texas A&M: 0.784918'],
#  ['Duke beats Texas Tech: 0.701456'],
#  ['Duke beats TX Southern: 0.985697'],
#  ['Duke beats UCLA: 0.726637'],
#  ['Duke beats UMBC: 0.963662'],
#  ['Duke beats UNC Greensboro: 0.923451'],
#  ['Villanova beats Duke: 0.575385'],
#  ['Virginia beats Duke: 0.543085'],
#  ['Duke beats Virginia Tech: 0.731572'],
#  ['Duke beats West Virginia: 0.537414'],
#  ['Duke beats Wichita St: 0.625882'],
#  ['Duke beats Wright St: 0.955101'],
#  ['Duke beats Xavier: 0.539377'],
#  ['Florida St beats Florida: 0.571765'],
#  ['Florida beats Georgia St: 0.869164'],
#  ['Gonzaga beats Florida: 0.689873'],
#  ['Florida beats Houston: 0.513758'],
#  ['Florida beats Iona: 0.861472'],
#  ['Kansas beats Florida: 0.738696'],
#  ['Kansas St beats Florida: 0.572241'],
#  ['Kentucky beats Florida: 0.599604'],
#  ['Florida beats Lipscomb: 0.911094'],
#  ['Florida beats Long Island: 0.958045'],
#  ['Florida beats Loyola-Chicago: 0.708726'],
#  ['Florida beats Marshall: 0.789078'],
#  ['Miami FL beats Florida: 0.529918'],
#  ['Michigan beats Florida: 0.682081'],
#  ['Michigan St beats Florida: 0.682014'],
#  ['Florida beats Missouri: 0.675384'],
#  ['Florida beats Montana: 0.834698'],
#  ['Florida beats Murray St: 0.793320'],
#  ['Florida beats NC Central: 0.969095'],
#  ['Florida beats NC State: 0.593892'],
#  ['Florida beats Nevada: 0.536249'],
#  ['Florida beats New Mexico St: 0.717635'],
#  ['North Carolina beats Florida: 0.601052'],
#  ['Florida beats Ohio St: 0.567214'],
#  ['Florida beats Oklahoma: 0.596208'],
#  ['Florida beats Penn: 0.869352'],
#  ['Florida beats Providence: 0.505629'],
#  ['Purdue beats Florida: 0.667520'],
#  ['Florida beats Radford: 0.937591'],
#  ['Florida beats Rhode Island: 0.598852'],
#  ['Florida beats S Dakota St: 0.780343'],
#  ['Florida beats San Diego St: 0.663129'],
#  ['Florida beats Seton Hall: 0.504779'],
#  ['Florida beats SF Austin: 0.847478'],
#  ['Florida beats St Bonaventure: 0.557443'],
#  ['Florida beats Syracuse: 0.522846'],
#  ['Florida beats TCU: 0.523125'],
#  ['Tennessee beats Florida: 0.573003'],
#  ['Florida beats Texas: 0.540132'],
#  ['Florida beats Texas A&M: 0.569049'],
#  ['Texas Tech beats Florida: 0.540497'],
#  ['Florida beats TX Southern: 0.961443'],
#  ['UCLA beats Florida: 0.509739'],
#  ['Florida beats UMBC: 0.905619'],
#  ['Florida beats UNC Greensboro: 0.813603'],
#  ['Villanova beats Florida: 0.789255'],
#  ['Virginia beats Florida: 0.766625'],
#  ['Virginia Tech beats Florida: 0.503493'],
#  ['West Virginia beats Florida: 0.704048'],
#  ['Wichita St beats Florida: 0.622928'],
#  ['Florida beats Wright St: 0.885016'],
#  ['Xavier beats Florida: 0.702400'],
#  ['Florida St beats Georgia St: 0.899619'],
#  ['Gonzaga beats Florida St: 0.622486'],
#  ['Florida St beats Houston: 0.587698'],
#  ['Florida St beats Iona: 0.893498'],
#  ['Kansas beats Florida St: 0.676950'],
#  ['Florida St beats Kansas St: 0.502103'],
#  ['Kentucky beats Florida St: 0.526077'],
#  ['Florida St beats Lipscomb: 0.932546'],
#  ['Florida St beats Long Island: 0.968559'],
#  ['Florida St beats Loyola-Chicago: 0.766494'],
#  ['Florida St beats Marshall: 0.834628'],
#  ['Florida St beats Miami FL: 0.544779'],
#  ['Michigan beats Florida St: 0.613948'],
#  ['Michigan St beats Florida St: 0.613875'],
#  ['Florida St beats Missouri: 0.737314'],
#  ['Florida St beats Montana: 0.871994'],
#  ['Florida St beats Murray St: 0.838142'],
#  ['Florida St beats NC Central: 0.976907'],
#  ['Florida St beats NC State: 0.663625'],
#  ['Florida St beats Nevada: 0.609370'],
#  ['Florida St beats New Mexico St: 0.774198'],
#  ['North Carolina beats Florida St: 0.527582'],
#  ['Florida St beats Ohio St: 0.638742'],
#  ['Florida St beats Oklahoma: 0.665768'],
#  ['Florida St beats Penn: 0.899768'],
#  ['Florida St beats Providence: 0.579794'],
#  ['Purdue beats Florida St: 0.598105'],
#  ['Florida St beats Radford: 0.952980'],
#  ['Florida St beats Rhode Island: 0.668209'],
#  ['Florida St beats S Dakota St: 0.827367'],
#  ['Florida St beats San Diego St: 0.726449'],
#  ['Florida St beats Seton Hall: 0.578966'],
#  ['Florida St beats SF Austin: 0.882298'],
#  ['Florida St beats St Bonaventure: 0.629531'],
#  ['Florida St beats Syracuse: 0.596490'],
#  ['Florida St beats TCU: 0.596759'],
#  ['Florida St beats Tennessee: 0.501325'],
#  ['Florida St beats Texas: 0.613082'],
#  ['Florida St beats Texas A&M: 0.640466'],
#  ['Florida St beats Texas Tech: 0.534214'],
#  ['Florida St beats TX Southern: 0.971132'],
#  ['Florida St beats UCLA: 0.564748'],
#  ['Florida St beats UMBC: 0.928289'],
#  ['Florida St beats UNC Greensboro: 0.854831'],
#  ['Villanova beats Florida St: 0.735173'],
#  ['Virginia beats Florida St: 0.708878'],
#  ['Florida St beats Virginia Tech: 0.570879'],
#  ['West Virginia beats Florida St: 0.638126'],
#  ...]

# %%
Finalpredictions=pd.DataFrame(readable)
Finalpredictions.to_csv("Finalpredictions.csv", index=False)
