# %% [markdown]
# **Predict NCAA Basketball 2017
# **
#
# Here we will use Logistic Regression to predict the outcomes of every possible matchup in the 2017 March Madness basketball tournament.  Our classifier will make its decision based off of the values for 17 features.  One important feature is a ranking metric called ELO ([Link #1](https://en.wikipedia.org/wiki/Elo_rating_system), [Link #2](https://fivethirtyeight.com/features/how-we-calculate-nba-elo-ratings/)) while the remaining 16 features are traditional basketball metrics (described below).  Note that many functions are adapted from [this solution]( https://github.com/harvitronix/kaggle-march-madness-machine-learning) from 2016.

# %% [markdown]
# *Step 1: Import Libraries*

# %%
import pandas as pd
import numpy
import math
import csv
import random
from sklearn import cross_validation, linear_model, model_selection
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV

# %% [markdown]
# *Step 2: Load Data*

# %%
folder = '../input'
season_data = pd.read_csv(folder + '/march-machine-learning-mania-2017/RegularSeasonDetailedResults.csv')
tourney_data = pd.read_csv(folder + '/march-machine-learning-mania-2017/TourneyDetailedResults.csv')
seeds = pd.read_csv(folder + '/march-machine-learning-mania-2017/TourneySeeds.csv')
frames = [season_data, tourney_data]
all_data = pd.concat(frames)
stat_fields = ['score', 'fga', 'fgp', 'fga3', '3pp', 'ftp', 'or', 'dr',
                   'ast', 'to', 'stl', 'blk', 'pf']
prediction_year = 2017
base_elo = 1600
team_elos = {}
team_stats = {}
X = []
y = []
submission_data = []
def initialize_data():
    for i in range(1985, prediction_year+1):
        team_elos[i] = {}
        team_stats[i] = {}
initialize_data()

# %% [markdown]
# *Step 3: Explore Data*

# %%
all_data.head(10)
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga ...   \
# 0    2003      10   1104      68   1328      62    N      0    27    58 ...
# 1    2003      10   1272      70   1393      63    N      0    26    62 ...
# 2    2003      11   1266      73   1437      61    N      0    24    58 ...
# 3    2003      11   1296      56   1457      50    N      0    18    38 ...
# 4    2003      11   1400      77   1208      71    N      0    30    61 ...
# 5    2003      11   1458      81   1186      55    H      0    26    57 ...
# 6    2003      12   1161      80   1236      62    H      0    23    55 ...
# 7    2003      12   1186      75   1457      61    N      0    28    62 ...
# 8    2003      12   1194      71   1156      66    N      0    28    58 ...
# 9    2003      12   1458      84   1296      56    H      0    32    67 ...
#
#    Lfga3  Lftm  Lfta  Lor  Ldr  Last  Lto  Lstl  Lblk  Lpf
# 0     10    16    22   10   22     8   18     9     2   20
# 1     24     9    20   20   25     7   12     8     6   16
# 2     26    14    23   31   22     9   12     2     5   23
# 3     22     8    15   17   20     9   19     4     3   23
# 4     16    17    27   21   15    12   10     7     1   14
# 5     11    12    17    6   22     8   19     4     3   25
# 6     15    20    28    9   21    11   30    10     4   28
# 7     17    17    23    8   25    10   15    14     8   18
# 8     18    12    27   13   26    13   25     8     2   18
# 9     14     7    12    9   23    10   18     1     3   18
#
# [10 rows x 34 columns]

# %% [markdown]
# *Step 4: Define Helper Functions*

# %%
def get_elo(season, team):
    try:
        return team_elos[season][team]
    except:
        try:
            # Get the previous season's ending value.
            team_elos[season][team] = team_elos[season-1][team]
            return team_elos[season][team]
        except:
            # Get the starter elo.
            team_elos[season][team] = base_elo
            return team_elos[season][team]

def calc_elo(win_team, lose_team, season):
    winner_rank = get_elo(season, win_team)
    loser_rank = get_elo(season, lose_team)
    rank_diff = winner_rank - loser_rank
    exp = (rank_diff * -1) / 400
    odds = 1 / (1 + math.pow(10, exp))
    if winner_rank < 2100:
        k = 32
    elif winner_rank >= 2100 and winner_rank < 2400:
        k = 24
    else:
        k = 16
    new_winner_rank = round(winner_rank + (k * (1 - odds)))
    new_rank_diff = new_winner_rank - winner_rank
    new_loser_rank = loser_rank - new_rank_diff
    return new_winner_rank, new_loser_rank

def get_stat(season, team, field):
    try:
        l = team_stats[season][team][field]
        return sum(l) / float(len(l))
    except:
        return 0
    
def update_stats(season, team, fields):
    if team not in team_stats[season]:
        team_stats[season][team] = {}
    for key, value in fields.items():
        # Make sure we have the field.
        if key not in team_stats[season][team]:
            team_stats[season][team][key] = []
        if len(team_stats[season][team][key]) >= 9:
            team_stats[season][team][key].pop()
        team_stats[season][team][key].append(value)
        
def predict_winner(team_1, team_2, model, season, stat_fields):
    features = []
    # Team 1
    features.append(get_elo(season, team_1))
    for stat in stat_fields:
        features.append(get_stat(season, team_1, stat))
    # Team 2
    features.append(get_elo(season, team_2))
    for stat in stat_fields:
        features.append(get_stat(season, team_2, stat))
    return model.predict_proba([features])

# %% [markdown]
# *Step 5: Feature Selection and Feature Engineering*

# %% [markdown]
# Our classifier will make its decision based off of the values for 17 features.  One important feature is a ranking metric called ELO ([Link #1](https://en.wikipedia.org/wiki/Elo_rating_system), [Link #2](https://fivethirtyeight.com/features/how-we-calculate-nba-elo-ratings/)) while the remaining 16 features are traditional basketball metrics as described below:
#
# Features:
#
#             wfgm :  field goals made
#             wfga :  field goals attempted
#             wfgm3 :  three pointers made
#             wfga3 :  three pointers attempted
#             wftm :  free throws made
#             wfta :  free throws attempted
#             wor :  offensive rebounds
#             wdr :  defensive rebounds
#             wast :  assists
#             wto :  turnovers
#             wstl :  steals
#             wblk :  blocks
#             wpf :  personal fouls
#
# Engineered Features:
#
#             fgp :  field goal percentage
#             3pp :  three point percentage
#             ftp:  free throw percentage

# %%
def build_season_data(all_data):
    # Calculate the elo for every game for every team, each season.
    # Store the elo per season so we can retrieve their end elo
    # later in order to predict the tournaments without having to
    # inject the prediction into this loop.
    for index, row in all_data.iterrows():
        # Used to skip matchups where we don't have usable stats yet.
        skip = 0
        # Get starter or previous elos.
        team_1_elo = get_elo(row['Season'], row['Wteam'])
        team_2_elo = get_elo(row['Season'], row['Lteam'])
        # Add 100 to the home team (# taken from Nate Silver analysis.)
        if row['Wloc'] == 'H':
            team_1_elo += 100
        elif row['Wloc'] == 'A':
            team_2_elo += 100         
        # We'll create some arrays to use later.
        team_1_features = [team_1_elo]
        team_2_features = [team_2_elo]
        # Build arrays out of the stats we're tracking..
        for field in stat_fields:
            team_1_stat = get_stat(row['Season'], row['Wteam'], field)
            team_2_stat = get_stat(row['Season'], row['Lteam'], field)
            if team_1_stat is not 0 and team_2_stat is not 0:
                team_1_features.append(team_1_stat)
                team_2_features.append(team_2_stat)
            else:
                skip = 1
        if skip == 0:  # Make sure we have stats.
            # Randomly select left and right and 0 or 1 so we can train
            # for multiple classes.
            if random.random() > 0.5:
                X.append(team_1_features + team_2_features)
                y.append(0)
            else:
                X.append(team_2_features + team_1_features)
                y.append(1)
        # AFTER we add the current stuff to the prediction, update for
        # next time. Order here is key so we don't fit on data from the
        # same game we're trying to predict.
        if row['Wfta'] != 0 and row['Lfta'] != 0:
            stat_1_fields = {
                'score': row['Wscore'],
                'fgp': row['Wfgm'] / row['Wfga'] * 100,
                'fga': row['Wfga'],
                'fga3': row['Wfga3'],
                '3pp': row['Wfgm3'] / row['Wfga3'] * 100,
                'ftp': row['Wftm'] / row['Wfta'] * 100,
                'or': row['Wor'],
                'dr': row['Wdr'],
                'ast': row['Wast'],
                'to': row['Wto'],
                'stl': row['Wstl'],
                'blk': row['Wblk'],
                'pf': row['Wpf']
            }         
            stat_2_fields = {
                'score': row['Lscore'],
                'fgp': row['Lfgm'] / row['Lfga'] * 100,
                'fga': row['Lfga'],
                'fga3': row['Lfga3'],
                '3pp': row['Lfgm3'] / row['Lfga3'] * 100,
                'ftp': row['Lftm'] / row['Lfta'] * 100,
                'or': row['Lor'],
                'dr': row['Ldr'],
                'ast': row['Last'],
                'to': row['Lto'],
                'stl': row['Lstl'],
                'blk': row['Lblk'],
                'pf': row['Lpf']
            }
            update_stats(row['Season'], row['Wteam'], stat_1_fields)
            update_stats(row['Season'], row['Lteam'], stat_2_fields)
        # Now that we've added them, calc the new elo.
        new_winner_rank, new_loser_rank = calc_elo(
            row['Wteam'], row['Lteam'], row['Season'])
        team_elos[row['Season']][row['Wteam']] = new_winner_rank
        team_elos[row['Season']][row['Lteam']] = new_loser_rank
    return X, y
X, y = build_season_data(all_data)

# %% [markdown]
# *Step 6: Use Logistic Regression To Predict Game Outcomes*

# %%
model = linear_model.LogisticRegression()
print("Let's hope to be correct 75% of the time")
print(cross_validation.cross_val_score(model, numpy.array(X), numpy.array(y), cv=10, scoring='accuracy', n_jobs=-1).mean())
model.fit(X, y)
tourney_teams = []
for index, row in seeds.iterrows():
    if row['Season'] == prediction_year:
        tourney_teams.append(row['Team'])
tourney_teams.sort()
for team_1 in tourney_teams:
    for team_2 in tourney_teams:
        if team_1 < team_2:
            prediction = predict_winner(
                team_1, team_2, model, prediction_year, stat_fields)
            label = str(prediction_year) + '_' + str(team_1) + '_' + \
                str(team_2)
            submission_data.append([label, prediction[0][0]])
# Out:
# Let's hope to be correct 75% of the time
# 0.7263450015902814

# %% [markdown]
# *Step 7: Submit Results*

# %%
print("Writing %d results." % len(submission_data))
submission_data2=pd.DataFrame(submission_data)
submission_data2.to_csv("submission1.csv", index=False)
def build_team_dict():
    team_ids = pd.read_csv(folder + '/march-machine-learning-mania-2017/Teams.csv')
    team_id_map = {}
    for index, row in team_ids.iterrows():
        team_id_map[row['Team_Id']] = row['Team_Name']
    return team_id_map
team_id_map = build_team_dict()
readable = []
less_readable = []  # A version that's easy to look up.
for pred in submission_data:
    parts = pred[0].split('_')
    less_readable.append(
        [team_id_map[int(parts[1])], team_id_map[int(parts[2])], pred[1]])
    # Order them properly.
    if pred[1] > 0.5:
        winning = int(parts[1])
        losing = int(parts[2])
        proba = pred[1]
    else:
        winning = int(parts[2])
        losing = int(parts[1])
        proba = 1 - pred[1]
    readable.append(
        [
            '%s beats %s: %f' %
            (team_id_map[winning], team_id_map[losing], proba)
        ]
    )
readable
# Out:
# Writing 2278 results.
# [['Arizona beats Arkansas: 0.655554'],
#  ['Arizona beats Baylor: 0.566242'],
#  ['Arizona beats Bucknell: 0.930614'],
#  ['Arizona beats Butler: 0.624446'],
#  ['Arizona beats Cincinnati: 0.582132'],
#  ['Arizona beats Creighton: 0.705411'],
#  ['Arizona beats Dayton: 0.762708'],
#  ['Arizona beats Duke: 0.505073'],
#  ['Arizona beats ETSU: 0.898301'],
#  ['Arizona beats FL Gulf Coast: 0.927422'],
#  ['Arizona beats Florida: 0.655543'],
#  ['Arizona beats Florida St: 0.647000'],
#  ['Arizona beats Gonzaga: 0.502747'],
#  ['Arizona beats Iona: 0.915558'],
#  ['Arizona beats Iowa St: 0.596969'],
#  ['Arizona beats Jacksonville St: 0.972313'],
#  ['Kansas beats Arizona: 0.583473'],
#  ['Arizona beats Kansas St: 0.737763'],
#  ['Arizona beats Kent: 0.881937'],
#  ['Kentucky beats Arizona: 0.598997'],
#  ['Arizona beats Louisville: 0.538149'],
#  ['Arizona beats Marquette: 0.697944'],
#  ['Arizona beats Maryland: 0.731208'],
#  ['Arizona beats Miami FL: 0.697767'],
#  ['Arizona beats Michigan: 0.666316'],
#  ['Arizona beats Michigan St: 0.767149'],
#  ['Arizona beats Minnesota: 0.791178'],
#  ["Arizona beats Mt St Mary's: 0.985964"],
#  ['Arizona beats MTSU: 0.782638'],
#  ['Arizona beats N Kentucky: 0.938536'],
#  ['Arizona beats NC Central: 0.976821'],
#  ['Arizona beats Nevada: 0.771513'],
#  ['Arizona beats New Mexico St: 0.883168'],
#  ['Arizona beats New Orleans: 0.979997'],
#  ['North Carolina beats Arizona: 0.552732'],
#  ['Arizona beats North Dakota: 0.965295'],
#  ['Arizona beats Northwestern: 0.739019'],
#  ['Notre Dame beats Arizona: 0.544111'],
#  ['Arizona beats Oklahoma St: 0.682001'],
#  ['Arizona beats Oregon: 0.537920'],
#  ['Arizona beats Princeton: 0.890530'],
#  ['Arizona beats Providence: 0.774295'],
#  ['Arizona beats Purdue: 0.641463'],
#  ['Arizona beats Rhode Island: 0.717847'],
#  ['Arizona beats S Dakota St: 0.943229'],
#  ['Arizona beats Seton Hall: 0.668939'],
#  ['Arizona beats SMU: 0.582586'],
#  ['Arizona beats South Carolina: 0.760496'],
#  ["Arizona beats St Mary's CA: 0.654910"],
#  ['Arizona beats Troy: 0.962027'],
#  ['Arizona beats TX Southern: 0.964609'],
#  ['Arizona beats UC Davis: 0.965000'],
#  ['Arizona beats UCLA: 0.519074'],
#  ['Arizona beats UNC Wilmington: 0.818547'],
#  ['Arizona beats USC: 0.725160'],
#  ['Arizona beats VA Commonwealth: 0.746589'],
#  ['Arizona beats Vanderbilt: 0.817898'],
#  ['Arizona beats Vermont: 0.895703'],
#  ['Villanova beats Arizona: 0.604358'],
#  ['Arizona beats Virginia: 0.533211'],
#  ['Arizona beats Virginia Tech: 0.762562'],
#  ['Arizona beats Wake Forest: 0.790073'],
#  ['West Virginia beats Arizona: 0.568679'],
#  ['Arizona beats Wichita St: 0.587914'],
#  ['Arizona beats Winthrop: 0.953114'],
#  ['Arizona beats Wisconsin: 0.634358'],
#  ['Arizona beats Xavier: 0.688671'],
#  ['Baylor beats Arkansas: 0.599165'],
#  ['Arkansas beats Bucknell: 0.872987'],
#  ['Butler beats Arkansas: 0.539929'],
#  ['Cincinnati beats Arkansas: 0.583459'],
#  ['Arkansas beats Creighton: 0.550991'],
#  ['Arkansas beats Dayton: 0.622239'],
#  ['Duke beats Arkansas: 0.656612'],
#  ['Arkansas beats ETSU: 0.819056'],
#  ['Arkansas beats FL Gulf Coast: 0.867522'],
#  ['Florida beats Arkansas: 0.506257'],
#  ['Florida St beats Arkansas: 0.515656'],
#  ['Gonzaga beats Arkansas: 0.658706'],
#  ['Arkansas beats Iona: 0.847476'],
#  ['Iowa St beats Arkansas: 0.568485'],
#  ['Arkansas beats Jacksonville St: 0.947360'],
#  ['Kansas beats Arkansas: 0.732152'],
#  ['Arkansas beats Kansas St: 0.590456'],
#  ['Arkansas beats Kent: 0.792882'],
#  ['Kentucky beats Arkansas: 0.744561'],
#  ['Louisville beats Arkansas: 0.626125'],
#  ['Arkansas beats Marquette: 0.542151'],
#  ['Arkansas beats Maryland: 0.582304'],
#  ['Arkansas beats Miami FL: 0.541942'],
#  ['Arkansas beats Michigan: 0.505762'],
#  ['Arkansas beats Michigan St: 0.628026'],
#  ['Arkansas beats Minnesota: 0.660050'],
#  ["Arkansas beats Mt St Mary's: 0.972972"],
#  ['Arkansas beats MTSU: 0.648530'],
#  ['Arkansas beats N Kentucky: 0.886688'],
#  ['Arkansas beats NC Central: 0.955745'],
#  ['Arkansas beats Nevada: 0.633753'],
#  ['Arkansas beats New Mexico St: 0.794824'],
#  ['Arkansas beats New Orleans: 0.961696'],
#  ['North Carolina beats Arkansas: 0.706872'],
#  ['Arkansas beats North Dakota: 0.934444'],
#  ['Arkansas beats Northwestern: 0.592027'],
#  ['Notre Dame beats Arkansas: 0.699607'],
#  ['Arkansas beats Oklahoma St: 0.523597'],
#  ['Oregon beats Arkansas: 0.626341'],
#  ['Arkansas beats Princeton: 0.806535'],
#  ['Arkansas beats Providence: 0.637423'],
#  ['Purdue beats Arkansas: 0.521687'],
#  ['Arkansas beats Rhode Island: 0.565935'],
#  ['Arkansas beats S Dakota St: 0.894897'],
#  ['Arkansas beats Seton Hall: 0.508716'],
#  ['SMU beats Arkansas: 0.583006'],
#  ['Arkansas beats South Carolina: 0.619370'],
#  ["St Mary's CA beats Arkansas: 0.506957"],
#  ['Arkansas beats Troy: 0.928486'],
#  ['Arkansas beats TX Southern: 0.933190'],
#  ['Arkansas beats UC Davis: 0.933903'],
#  ['UCLA beats Arkansas: 0.643867'],
#  ['Arkansas beats UNC Wilmington: 0.698047'],
#  ['Arkansas beats USC: 0.574853'],
#  ['Arkansas beats VA Commonwealth: 0.601563'],
#  ['Arkansas beats Vanderbilt: 0.697126'],
#  ['Arkansas beats Vermont: 0.814850'],
#  ['Villanova beats Arkansas: 0.748792'],
#  ['Virginia beats Arkansas: 0.630761'],
#  ['Arkansas beats Virginia Tech: 0.622050'],
#  ['Arkansas beats Wake Forest: 0.658551'],
#  ['West Virginia beats Arkansas: 0.720106'],
#  ['Wichita St beats Arkansas: 0.577659'],
#  ['Arkansas beats Winthrop: 0.912416'],
#  ['Wisconsin beats Arkansas: 0.529357'],
#  ['Arkansas beats Xavier: 0.531307'],
#  ['Baylor beats Bucknell: 0.910835'],
#  ['Baylor beats Butler: 0.558774'],
#  ['Baylor beats Cincinnati: 0.514810'],
#  ['Baylor beats Creighton: 0.645867'],
#  ['Baylor beats Dayton: 0.709984'],
#  ['Duke beats Baylor: 0.562665'],
#  ['Baylor beats ETSU: 0.870593'],
#  ['Baylor beats FL Gulf Coast: 0.906825'],
#  ['Baylor beats Florida: 0.591753'],
#  ['Baylor beats Florida St: 0.582636'],
#  ['Gonzaga beats Baylor: 0.564952'],
#  ['Baylor beats Iona: 0.891986'],
#  ['Baylor beats Iowa St: 0.530107'],
#  ['Baylor beats Jacksonville St: 0.963961'],
#  ['Kansas beats Baylor: 0.647786'],
#  ['Baylor beats Kansas St: 0.681809'],
#  ['Baylor beats Kent: 0.850513'],
#  ['Kentucky beats Baylor: 0.662300'],
#  ['Louisville beats Baylor: 0.529810'],
#  ['Baylor beats Marquette: 0.637667'],
#  ['Baylor beats Maryland: 0.674473'],
#  ['Baylor beats Miami FL: 0.637472'],
#  ['Baylor beats Michigan: 0.603315'],
#  ['Baylor beats Michigan St: 0.715043'],
#  ['Baylor beats Minnesota: 0.742646'],
#  ["Baylor beats Mt St Mary's: 0.981652"],
#  ['Baylor beats MTSU: 0.732792'],
#  ['Baylor beats N Kentucky: 0.920824'],
#  ['Baylor beats NC Central: 0.969786'],
#  ['Baylor beats Nevada: 0.720028'],
#  ['Baylor beats New Mexico St: 0.852016'],
#  ['Baylor beats New Orleans: 0.973900'],
#  ['North Carolina beats Baylor: 0.618690'],
#  ['Baylor beats North Dakota: 0.954924'],
#  ['Baylor beats Northwestern: 0.683218'],
#  ['Notre Dame beats Baylor: 0.610444'],
#  ['Baylor beats Oklahoma St: 0.620273'],
#  ['Oregon beats Baylor: 0.530039'],
#  ['Baylor beats Princeton: 0.861033'],
#  ['Baylor beats Providence: 0.723211'],
#  ['Baylor beats Purdue: 0.576750'],
#  ['Baylor beats Rhode Island: 0.659605'],
#  ['Baylor beats S Dakota St: 0.926764'],
#  ['Baylor beats Seton Hall: 0.606140'],
#  ['Baylor beats SMU: 0.515276'],
#  ['Baylor beats South Carolina: 0.707469'],
#  ["Baylor beats St Mary's CA: 0.591076"],
#  ['Baylor beats Troy: 0.950730'],
#  ['Baylor beats TX Southern: 0.954043'],
#  ['Baylor beats UC Davis: 0.954545'],
#  ['UCLA beats Baylor: 0.548829'],
#  ['Baylor beats UNC Wilmington: 0.774564'],
#  ['Baylor beats USC: 0.667728'],
#  ['Baylor beats VA Commonwealth: 0.691732'],
#  ['Baylor beats Vanderbilt: 0.773800'],
#  ['Baylor beats Vermont: 0.867391'],
#  ['Villanova beats Baylor: 0.667286'],
#  ['Virginia beats Baylor: 0.534753'],
#  ['Baylor beats Virginia Tech: 0.709819'],
#  ['Baylor beats Wake Forest: 0.741368'],
#  ['West Virginia beats Baylor: 0.633843'],
#  ['Baylor beats Wichita St: 0.520757'],
#  ['Baylor beats Winthrop: 0.939332'],
#  ['Baylor beats Wisconsin: 0.569224'],
#  ['Baylor beats Xavier: 0.627531'],
#  ['Butler beats Bucknell: 0.886340'],
#  ['Cincinnati beats Bucknell: 0.902983'],
#  ['Creighton beats Bucknell: 0.844113'],
#  ['Dayton beats Bucknell: 0.801352'],
#  ['Duke beats Bucknell: 0.927038'],
#  ['ETSU beats Bucknell: 0.594805'],
#  ['FL Gulf Coast beats Bucknell: 0.503651'],
#  ['Florida beats Bucknell: 0.872011'],
#  ['Florida St beats Bucknell: 0.876151'],
#  ['Gonzaga beats Bucknell: 0.927665'],
#  ['Iona beats Bucknell: 0.544603'],
#  ['Iowa St beats Bucknell: 0.897477'],
#  ['Bucknell beats Jacksonville St: 0.730343'],
#  ['Kansas beats Bucknell: 0.947817'],
#  ['Kansas St beats Bucknell: 0.821710'],
#  ['Kent beats Bucknell: 0.634471'],
#  ['Kentucky beats Bucknell: 0.950904'],
#  ['Louisville beats Bucknell: 0.917546'],
#  ['Marquette beats Bucknell: 0.848749'],
#  ['Maryland beats Bucknell: 0.826582'],
#  ['Miami FL beats Bucknell: 0.848857'],
#  ['Michigan beats Bucknell: 0.866548'],
#  ['Michigan St beats Bucknell: 0.797392'],
#  ['Minnesota beats Bucknell: 0.773873'],
#  ["Bucknell beats Mt St Mary's: 0.844177"],
#  ['MTSU beats Bucknell: 0.782661'],
#  ['Bucknell beats N Kentucky: 0.540789'],
#  ['Bucknell beats NC Central: 0.764714'],
#  ['Nevada beats Bucknell: 0.793389'],
#  ['New Mexico St beats Bucknell: 0.631714'],
#  ['Bucknell beats New Orleans: 0.790726'],
#  ['North Carolina beats Bucknell: 0.941258'],
#  ['Bucknell beats North Dakota: 0.682051'],
#  ['Northwestern beats Bucknell: 0.820756'],
#  ['Notre Dame beats Bucknell: 0.939304'],
#  ['Oklahoma St beats Bucknell: 0.858072'],
#  ['Oregon beats Bucknell: 0.917615'],
#  ['Princeton beats Bucknell: 0.614479'],
#  ['Providence beats Bucknell: 0.790779'],
#  ['Purdue beats Bucknell: 0.878748'],
#  ['Rhode Island beats Bucknell: 0.835970'],
#  ['Bucknell beats S Dakota St: 0.561669'],
#  ['Seton Hall beats Bucknell: 0.865176'],
#  ['SMU beats Bucknell: 0.902820'],
#  ['South Carolina beats Bucknell: 0.803285'],
#  ["St Mary's CA beats Bucknell: 0.872323"],
#  ['Bucknell beats Troy: 0.661465'],
#  ['Bucknell beats TX Southern: 0.677635'],
#  ['Bucknell beats UC Davis: 0.680142'],
#  ['UCLA beats Bucknell: 0.923156'],
#  ['UNC Wilmington beats Bucknell: 0.741890'],
#  ['USC beats Bucknell: 0.830918'],
#  ['VA Commonwealth beats Bucknell: 0.814851'],
#  ['Vanderbilt beats Bucknell: 0.742725'],
#  ['Vermont beats Bucknell: 0.601565'],
#  ['Villanova beats Bucknell: 0.951938'],
#  ['Virginia beats Bucknell: 0.919035'],
#  ['Virginia Tech beats Bucknell: 0.801480'],
#  ['Wake Forest beats Bucknell: 0.775038'],
#  ['West Virginia beats Bucknell: 0.944738'],
#  ['Wichita St beats Bucknell: 0.900876'],
#  ['Bucknell beats Winthrop: 0.610561'],
#  ['Wisconsin beats Bucknell: 0.881988'],
#  ['Xavier beats Bucknell: 0.854263'],
#  ['Cincinnati beats Butler: 0.537097'],
#  ['Butler beats Creighton: 0.597006'],
#  ['Butler beats Dayton: 0.665386'],
#  ['Duke beats Butler: 0.612991'],
#  ['Butler beats ETSU: 0.845312'],
#  ['Butler beats FL Gulf Coast: 0.887709'],
#  ['Butler beats Florida: 0.540735'],
#  ['Butler beats Florida St: 0.531381'],
#  ['Gonzaga beats Butler: 0.615195'],
#  ['Butler beats Iona: 0.870262'],
#  ['Iowa St beats Butler: 0.521822'],
#  ['Butler beats Jacksonville St: 0.955998'],
#  ['Kansas beats Butler: 0.693650'],
#  ['Butler beats Kansas St: 0.635106'],
#  ['Butler beats Kent: 0.822111'],
#  ['Kentucky beats Butler: 0.707129'],
#  ['Louisville beats Butler: 0.581102'],
#  ['Butler beats Marquette: 0.588395'],
#  ['Butler beats Maryland: 0.627281'],
#  ['Butler beats Miami FL: 0.588191'],
#  ['Butler beats Michigan: 0.552649'],
#  ['Butler beats Michigan St: 0.670862'],
#  ['Butler beats Minnesota: 0.700955'],
#  ["Butler beats Mt St Mary's: 0.977507"],
#  ['Butler beats MTSU: 0.690170'],
#  ['Butler beats N Kentucky: 0.904277'],
#  ['Butler beats NC Central: 0.963061'],
#  ['Butler beats Nevada: 0.676270'],
#  ['Butler beats New Mexico St: 0.823840'],
#  ['Butler beats New Orleans: 0.968061'],
#  ['North Carolina beats Butler: 0.666391'],
#  ['Butler beats North Dakota: 0.945079'],
#  ['Butler beats Northwestern: 0.636611'],
#  ['Notre Dame beats Butler: 0.658608'],
#  ['Butler beats Oklahoma St: 0.570230'],
#  ['Oregon beats Butler: 0.581326'],
#  ['Butler beats Princeton: 0.834240'],
#  ['Butler beats Providence: 0.679730'],
#  ['Butler beats Purdue: 0.525360'],
#  ['Butler beats Rhode Island: 0.611499'],
#  ['Butler beats S Dakota St: 0.911339'],
#  ['Butler beats Seton Hall: 0.555569'],
#  ['SMU beats Butler: 0.536633'],
#  ['Butler beats South Carolina: 0.662668'],
#  ["Butler beats St Mary's CA: 0.540039"],
#  ['Butler beats Troy: 0.940025'],
#  ['Butler beats TX Southern: 0.944016'],
#  ['Butler beats UC Davis: 0.944621'],
#  ['UCLA beats Butler: 0.599614'],
#  ['Butler beats UNC Wilmington: 0.736207'],
#  ['Butler beats USC: 0.620109'],
#  ['Butler beats VA Commonwealth: 0.645728'],
#  ['Butler beats Vanderbilt: 0.735358'],
#  ['Butler beats Vermont: 0.841598'],
#  ['Villanova beats Butler: 0.711740'],
#  ['Virginia beats Butler: 0.585927'],
#  ['Butler beats Virginia Tech: 0.665207'],
#  ['Butler beats Wake Forest: 0.699554'],
#  ['West Virginia beats Butler: 0.680627'],
#  ['Wichita St beats Butler: 0.531170'],
#  ['Butler beats Winthrop: 0.926343'],
#  ['Butler beats Wisconsin: 0.517685'],
#  ['Butler beats Xavier: 0.577793'],
#  ['Cincinnati beats Creighton: 0.633938'],
#  ['Cincinnati beats Dayton: 0.699209'],
#  ['Duke beats Cincinnati: 0.575361'],
#  ['Cincinnati beats ETSU: 0.864647'],
#  ['Cincinnati beats FL Gulf Coast: 0.902357'],
#  ['Cincinnati beats Florida: 0.579188'],
#  ['Cincinnati beats Florida St: 0.569995'],
#  ['Gonzaga beats Cincinnati: 0.577632'],
#  ['Cincinnati beats Iona: 0.886896'],
#  ['Cincinnati beats Iowa St: 0.517193'],
#  ['Cincinnati beats Jacksonville St: 0.962118'],
#  ['Kansas beats Cincinnati: 0.659507'],
#  ['Cincinnati beats Kansas St: 0.670473'],
#  ['Cincinnati beats Kent: 0.843810'],
#  ['Kentucky beats Cincinnati: 0.673781'],
#  ['Louisville beats Cincinnati: 0.542685'],
#  ['Cincinnati beats Marquette: 0.625621'],
#  ['Cincinnati beats Maryland: 0.663004'],
#  ['Cincinnati beats Miami FL: 0.625424'],
#  ['Cincinnati beats Michigan: 0.590860'],
#  ['Cincinnati beats Michigan St: 0.704377'],
#  ['Cincinnati beats Minnesota: 0.732627'],
#  ["Cincinnati beats Mt St Mary's: 0.980696"],
#  ['Cincinnati beats MTSU: 0.722532'],
#  ['Cincinnati beats N Kentucky: 0.916966'],
#  ['Cincinnati beats NC Central: 0.968232'],
#  ['Cincinnati beats Nevada: 0.709473'],
#  ['Cincinnati beats New Mexico St: 0.845368'],
#  ['Cincinnati beats New Orleans: 0.972551'],
#  ['North Carolina beats Cincinnati: 0.630827'],
#  ['Cincinnati beats North Dakota: 0.952642'],
#  ['Cincinnati beats Northwestern: 0.671907'],
#  ['Notre Dame beats Cincinnati: 0.622684'],
#  ['Cincinnati beats Oklahoma St: 0.608004'],
#  ['Oregon beats Cincinnati: 0.542914'],
#  ['Cincinnati beats Princeton: 0.854721'],
#  ['Cincinnati beats Providence: 0.712728'],
#  ['Cincinnati beats Purdue: 0.564063'],
#  ['Cincinnati beats Rhode Island: 0.647886'],
#  ['Cincinnati beats S Dakota St: 0.923172'],
#  ['Cincinnati beats Seton Hall: 0.593714'],
#  ['Cincinnati beats SMU: 0.502337'],
#  ['Cincinnati beats South Carolina: 0.696640'],
#  ["Cincinnati beats St Mary's CA: 0.578506"],
#  ['Cincinnati beats Troy: 0.948247'],
#  ['Cincinnati beats TX Southern: 0.951719'],
#  ['Cincinnati beats UC Davis: 0.952245'],
#  ['UCLA beats Cincinnati: 0.561614'],
#  ['Cincinnati beats UNC Wilmington: 0.765395'],
#  ['Cincinnati beats USC: 0.656143'],
#  ['Cincinnati beats VA Commonwealth: 0.680584'],
#  ['Cincinnati beats Vanderbilt: 0.764610'],
#  ['Cincinnati beats Vermont: 0.861322'],
#  ['Villanova beats Cincinnati: 0.678679'],
#  ['Virginia beats Cincinnati: 0.547608'],
#  ['Cincinnati beats Virginia Tech: 0.699040'],
#  ['Cincinnati beats Wake Forest: 0.731318'],
#  ['West Virginia beats Cincinnati: 0.645774'],
#  ['Cincinnati beats Wichita St: 0.507824'],
#  ['Cincinnati beats Winthrop: 0.936313'],
#  ['Cincinnati beats Wisconsin: 0.556485'],
#  ['Cincinnati beats Xavier: 0.615351'],
#  ['Creighton beats Dayton: 0.577850'],
#  ['Duke beats Creighton: 0.697060'],
#  ['Creighton beats ETSU: 0.789988'],
#  ['Creighton beats FL Gulf Coast: 0.844765'],
#  ['Florida beats Creighton: 0.552342'],
#  ['Florida St beats Creighton: 0.561622'],
#  ['Gonzaga beats Creighton: 0.699021'],
#  ['Creighton beats Iona: 0.821982'],
#  ['Iowa St beats Creighton: 0.613199'],
#  ['Creighton beats Jacksonville St: 0.937326'],
#  ['Kansas beats Creighton: 0.766862'],
#  ['Creighton beats Kansas St: 0.545064'],
#  ['Creighton beats Kent: 0.760838'],
#  ['Kentucky beats Creighton: 0.778150'],
#  ['Louisville beats Creighton: 0.668350'],
#  ['Marquette beats Creighton: 0.504025'],
#  ['Creighton beats Maryland: 0.536717'],
#  ['Miami FL beats Creighton: 0.504236'],
#  ['Michigan beats Creighton: 0.540426'],
#  ['Creighton beats Michigan St: 0.583863'],
#  ['Creighton beats Minnesota: 0.617373'],
#  ["Creighton beats Mt St Mary's: 0.967653"],
#  ['Creighton beats MTSU: 0.605272'],
#  ['Creighton beats N Kentucky: 0.866717'],
#  ['Creighton beats NC Central: 0.947221'],
#  ['Creighton beats Nevada: 0.589826'],
#  ['Creighton beats New Mexico St: 0.762991'],
#  ['Creighton beats New Orleans: 0.954263'],
#  ['North Carolina beats Creighton: 0.743711'],
#  ['Creighton beats North Dakota: 0.922151'],
#  ['Creighton beats Northwestern: 0.546675'],
#  ['Notre Dame beats Creighton: 0.737019'],
#  ['Oklahoma St beats Creighton: 0.522646'],
#  ['Oregon beats Creighton: 0.668555'],
#  ['Creighton beats Princeton: 0.776006'],
#  ['Creighton beats Providence: 0.593654'],
#  ['Purdue beats Creighton: 0.567562'],
#  ['Creighton beats Rhode Island: 0.520034'],
#  ['Creighton beats S Dakota St: 0.876171'],
#  ['Seton Hall beats Creighton: 0.537489'],
#  ['SMU beats Creighton: 0.627202'],
#  ['Creighton beats South Carolina: 0.574875'],
#  ["St Mary's CA beats Creighton: 0.553034"],
#  ['Creighton beats Troy: 0.915177'],
#  ['Creighton beats TX Southern: 0.920682'],
#  ['Creighton beats UC Davis: 0.921518'],
#  ['UCLA beats Creighton: 0.685097'],
#  ['Creighton beats UNC Wilmington: 0.657665'],
#  ['Creighton beats USC: 0.529111'],
#  ['Creighton beats VA Commonwealth: 0.556477'],
#  ['Creighton beats Vanderbilt: 0.656682'],
#  ['Creighton beats Vermont: 0.785285'],
#  ['Villanova beats Creighton: 0.781988'],
#  ['Virginia beats Creighton: 0.672737'],
#  ['Creighton beats Virginia Tech: 0.577654'],
#  ['Creighton beats Wake Forest: 0.615795'],
#  ['West Virginia beats Creighton: 0.755856'],
#  ['Wichita St beats Creighton: 0.622055'],
#  ['Creighton beats Winthrop: 0.896450'],
#  ['Wisconsin beats Creighton: 0.575095'],
#  ['Xavier beats Creighton: 0.514924'],
#  ['Duke beats Dayton: 0.750665'],
#  ['Dayton beats ETSU: 0.741932'],
#  ['Dayton beats FL Gulf Coast: 0.806167'],
#  ['Florida beats Dayton: 0.617502'],
#  ['Florida St beats Dayton: 0.626346'],
#  ['Gonzaga beats Dayton: 0.752402'],
#  ['Dayton beats Iona: 0.779201'],
#  ['Iowa St beats Dayton: 0.674718'],
#  ['Dayton beats Jacksonville St: 0.919551'],
#  ['Kansas beats Dayton: 0.811456'],
#  ['Kansas St beats Dayton: 0.522005'],
#  ['Dayton beats Kent: 0.708571'],
#  ['Kentucky beats Dayton: 0.821088'],
#  ['Louisville beats Dayton: 0.725031'],
#  ['Marquette beats Dayton: 0.570753'],
#  ['Maryland beats Dayton: 0.530385'],
#  ['Miami FL beats Dayton: 0.570959'],
#  ['Michigan beats Dayton: 0.606084'],
#  ['Dayton beats Michigan St: 0.517450'],
#  ['Dayton beats Minnesota: 0.552206'],
#  ["Dayton beats Mt St Mary's: 0.958095"],
#  ['Dayton beats MTSU: 0.539581'],
#  ['Dayton beats N Kentucky: 0.832496'],
#  ['Dayton beats NC Central: 0.932049'],
#  ['Dayton beats Nevada: 0.523589'],
#  ['Dayton beats New Mexico St: 0.711016'],
#  ['Dayton beats New Orleans: 0.940989'],
#  ['North Carolina beats Dayton: 0.791529'],
#  ['Dayton beats North Dakota: 0.900529'],
#  ['Northwestern beats Dayton: 0.520383'],
#  ['Notre Dame beats Dayton: 0.785727'],
#  ['Oklahoma St beats Dayton: 0.588912'],
#  ['Oregon beats Dayton: 0.725215'],
#  ['Dayton beats Princeton: 0.725860'],
#  ['Dayton beats Providence: 0.527540'],
#  ['Purdue beats Dayton: 0.631983'],
#  ['Rhode Island beats Dayton: 0.547021'],
#  ['Dayton beats S Dakota St: 0.843940'],
#  ['Seton Hall beats Dayton: 0.603259'],
#  ['SMU beats Dayton: 0.687628'],
#  ['Dayton beats South Carolina: 0.508236'],
#  ["St Mary's CA beats Dayton: 0.618163"],
#  ['Dayton beats Troy: 0.891845'],
#  ['Dayton beats TX Southern: 0.898696'],
#  ['Dayton beats UC Davis: 0.899739'],
#  ['UCLA beats Dayton: 0.740029'],
#  ['Dayton beats UNC Wilmington: 0.594858'],
#  ['USC beats Dayton: 0.537989'],
#  ['VA Commonwealth beats Dayton: 0.510485'],
#  ['Dayton beats Vanderbilt: 0.593806'],
#  ['Dayton beats Vermont: 0.736511'],
#  ['Villanova beats Dayton: 0.824351'],
#  ['Virginia beats Dayton: 0.728972'],
#  ['Dayton beats Virginia Tech: 0.511080'],
#  ['Dayton beats Wake Forest: 0.550556'],
#  ['West Virginia beats Dayton: 0.802012'],
#  ['Wichita St beats Dayton: 0.682893'],
#  ['Dayton beats Winthrop: 0.868706'],
#  ['Wisconsin beats Dayton: 0.639107'],
#  ['Xavier beats Dayton: 0.581404'],
#  ['Duke beats ETSU: 0.900666'],
#  ['Duke beats FL Gulf Coast: 0.929163'],
#  ['Duke beats Florida: 0.661425'],
#  ['Duke beats Florida St: 0.652951'],
#  ['Duke beats Gonzaga: 0.509286'],
#  ['Duke beats Iona: 0.917558'],
#  ['Duke beats Iowa St: 0.603246'],
#  ['Duke beats Jacksonville St: 0.973009'],
#  ['Kansas beats Duke: 0.577103'],
#  ['Duke beats Kansas St: 0.742792'],
#  ['Duke beats Kent: 0.884634'],
#  ['Kentucky beats Duke: 0.592698'],
#  ['Duke beats Louisville: 0.544644'],
#  ['Duke beats Marquette: 0.703430'],
#  ['Duke beats Maryland: 0.736318'],
#  ['Duke beats Miami FL: 0.703254'],
#  ['Duke beats Michigan: 0.672107'],
#  ['Duke beats Michigan St: 0.771788'],
#  ['Duke beats Minnesota: 0.795467'],
#  ["Duke beats Mt St Mary's: 0.986321"],
#  ['Duke beats MTSU: 0.787055'],
#  ['Duke beats N Kentucky: 0.940028'],
#  ['Duke beats NC Central: 0.977406'],
#  ['Duke beats Nevada: 0.776092'],
#  ['Duke beats New Mexico St: 0.885840'],
#  ['Duke beats New Orleans: 0.980503'],
#  ['North Carolina beats Duke: 0.546257'],
#  ['Duke beats North Dakota: 0.966161'],
#  ['Duke beats Northwestern: 0.744032'],
#  ['Notre Dame beats Duke: 0.537616'],
#  ['Duke beats Oklahoma St: 0.687646'],
#  ['Duke beats Oregon: 0.544415'],
#  ['Duke beats Princeton: 0.893055'],
#  ['Duke beats Providence: 0.778833'],
#  ['Duke beats Purdue: 0.647456'],
#  ['Duke beats Rhode Island: 0.723115'],
#  ['Duke beats S Dakota St: 0.944614'],
#  ['Duke beats Seton Hall: 0.674706'],
#  ['Duke beats SMU: 0.588932'],
#  ['Duke beats South Carolina: 0.765228'],
#  ["Duke beats St Mary's CA: 0.660797"],
#  ['Duke beats Troy: 0.962972'],
#  ['Duke beats TX Southern: 0.965492'],
#  ['Duke beats UC Davis: 0.965873'],
#  ['Duke beats UCLA: 0.525600'],
#  ['Duke beats UNC Wilmington: 0.822400'],
#  ['Duke beats USC: 0.730343'],
#  ['Duke beats VA Commonwealth: 0.751506'],
#  ['Duke beats Vanderbilt: 0.821762'],
#  ['Duke beats Vermont: 0.898121'],
#  ['Villanova beats Duke: 0.598087'],
#  ['Duke beats Virginia: 0.539716'],
#  ['Duke beats Virginia Tech: 0.767266'],
#  ['Duke beats Wake Forest: 0.794379'],
#  ['West Virginia beats Duke: 0.562252'],
#  ['Duke beats Wichita St: 0.594237'],
#  ['Duke beats Winthrop: 0.954269'],
#  ['Duke beats Wisconsin: 0.640404'],
#  ['Duke beats Xavier: 0.694251'],
#  ['ETSU beats FL Gulf Coast: 0.585664'],
#  ['Florida beats ETSU: 0.826093'],
#  ['Florida St beats ETSU: 0.831430'],
#  ['Gonzaga beats ETSU: 0.899410'],
#  ['ETSU beats Iona: 0.545322'],
#  ['Iowa St beats ETSU: 0.859220'],
#  ['ETSU beats Jacksonville St: 0.795278'],
#  ['Kansas beats ETSU: 0.926812'],
#  ['Kansas St beats ETSU: 0.762657'],
#  ['Kent beats ETSU: 0.547549'],
#  ['Kentucky beats ETSU: 0.931052'],
#  ['Louisville beats ETSU: 0.885825'],
#  ['Marquette beats ETSU: 0.796434'],
#  ['Maryland beats ETSU: 0.768688'],
#  ['Miami FL beats ETSU: 0.796570'],
#  ['Michigan beats ETSU: 0.819077'],
#  ['Michigan St beats ETSU: 0.732902'],
#  ['Minnesota beats ETSU: 0.704670'],
#  ["ETSU beats Mt St Mary's: 0.885980"],
#  ['MTSU beats ETSU: 0.715158'],
#  ['ETSU beats N Kentucky: 0.628127'],
#  ['ETSU beats NC Central: 0.823374'],
#  ['Nevada beats ETSU: 0.728060'],
#  ['New Mexico St beats ETSU: 0.544607'],
#  ['ETSU beats New Orleans: 0.844221'],
#  ['North Carolina beats ETSU: 0.917843'],
#  ['ETSU beats North Dakota: 0.754709'],
#  ['Northwestern beats ETSU: 0.761479'],
#  ['Notre Dame beats ETSU: 0.915180'],
#  ['Oklahoma St beats ETSU: 0.808253'],
#  ['Oregon beats ETSU: 0.885918'],
#  ['Princeton beats ETSU: 0.526353'],
#  ['Providence beats ETSU: 0.724912'],
#  ['Purdue beats ETSU: 0.834789'],
#  ['Rhode Island beats ETSU: 0.780378'],
#  ['ETSU beats S Dakota St: 0.647624'],
#  ['Seton Hall beats ETSU: 0.817319'],
#  ['SMU beats ETSU: 0.866259'],
#  ['South Carolina beats ETSU: 0.740060'],
#  ["St Mary's CA beats ETSU: 0.826495"],
#  ['ETSU beats Troy: 0.737013'],
#  ['ETSU beats TX Southern: 0.750933'],
#  ['ETSU beats UC Davis: 0.753078'],
#  ['UCLA beats ETSU: 0.893342'],
#  ['UNC Wilmington beats ETSU: 0.667110'],
#  ['USC beats ETSU: 0.774077'],
#  ['VA Commonwealth beats ETSU: 0.754206'],
#  ['Vanderbilt beats ETSU: 0.668079'],
#  ['Vermont beats ETSU: 0.512827'],
#  ['Villanova beats ETSU: 0.932475'],
#  ['Virginia beats ETSU: 0.887817'],
#  ['Virginia Tech beats ETSU: 0.737865'],
#  ['Wake Forest beats ETSU: 0.706057'],
#  ['West Virginia beats ETSU: 0.922595'],
#  ['Wichita St beats ETSU: 0.863695'],
#  ['ETSU beats Winthrop: 0.692182'],
#  ['Wisconsin beats ETSU: 0.838988'],
#  ['Xavier beats ETSU: 0.803413'],
#  ['Florida beats FL Gulf Coast: 0.874458'],
#  ['Florida St beats FL Gulf Coast: 0.878529'],
#  ['Gonzaga beats FL Gulf Coast: 0.929134'],
#  ['Iona beats FL Gulf Coast: 0.550079'],
#  ['Iowa St beats FL Gulf Coast: 0.899493'],
#  ['FL Gulf Coast beats Jacksonville St: 0.725968'],
#  ['Kansas beats FL Gulf Coast: 0.948899'],
#  ['Kansas St beats FL Gulf Coast: 0.824925'],
#  ['Kent beats FL Gulf Coast: 0.639582'],
#  ['Kentucky beats FL Gulf Coast: 0.951926'],
#  ['Louisville beats FL Gulf Coast: 0.919202'],
#  ['Marquette beats FL Gulf Coast: 0.851565'],
#  ['Maryland beats FL Gulf Coast: 0.829727'],
#  ['Miami FL beats FL Gulf Coast: 0.851671'],
#  ['Michigan beats FL Gulf Coast: 0.869084'],
#  ['Michigan St beats FL Gulf Coast: 0.800939'],
#  ['Minnesota beats FL Gulf Coast: 0.777718'],
#  ["FL Gulf Coast beats Mt St Mary's: 0.841248"],
#  ['MTSU beats FL Gulf Coast: 0.786398'],
#  ['FL Gulf Coast beats N Kentucky: 0.535295'],
#  ['FL Gulf Coast beats NC Central: 0.760714'],
#  ['Nevada beats FL Gulf Coast: 0.796989'],
#  ['New Mexico St beats FL Gulf Coast: 0.636841'],
#  ['FL Gulf Coast beats New Orleans: 0.787045'],
#  ['North Carolina beats FL Gulf Coast: 0.942469'],
#  ['FL Gulf Coast beats North Dakota: 0.677238'],
#  ['Northwestern beats FL Gulf Coast: 0.823985'],
#  ['Notre Dame beats FL Gulf Coast: 0.940552'],
#  ['Oklahoma St beats FL Gulf Coast: 0.860743'],
#  ['Oregon beats FL Gulf Coast: 0.919271'],
#  ['Princeton beats FL Gulf Coast: 0.619702'],
#  ['Providence beats FL Gulf Coast: 0.794413'],
#  ['Purdue beats FL Gulf Coast: 0.881084'],
#  ['Rhode Island beats FL Gulf Coast: 0.838978'],
#  ['FL Gulf Coast beats S Dakota St: 0.556220'],
#  ['Seton Hall beats FL Gulf Coast: 0.867733'],
#  ['SMU beats FL Gulf Coast: 0.904742'],
#  ['South Carolina beats FL Gulf Coast: 0.806754'],
#  ["St Mary's CA beats FL Gulf Coast: 0.874765"],
#  ['FL Gulf Coast beats Troy: 0.656497'],
#  ['FL Gulf Coast beats TX Southern: 0.672787'],
#  ['FL Gulf Coast beats UC Davis: 0.675315'],
#  ['UCLA beats FL Gulf Coast: 0.924709'],
#  ['UNC Wilmington beats FL Gulf Coast: 0.746100'],
#  ['USC beats FL Gulf Coast: 0.834001'],
#  ['VA Commonwealth beats FL Gulf Coast: 0.818163'],
#  ['Vanderbilt beats FL Gulf Coast: 0.746926'],
#  ['Vermont beats FL Gulf Coast: 0.606851'],
#  ['Villanova beats FL Gulf Coast: 0.952939'],
#  ['Virginia beats FL Gulf Coast: 0.920665'],
#  ['Virginia Tech beats FL Gulf Coast: 0.804974'],
#  ['Wake Forest beats FL Gulf Coast: 0.778869'],
#  ['West Virginia beats FL Gulf Coast: 0.945880'],
#  ['Wichita St beats FL Gulf Coast: 0.902833'],
#  ['FL Gulf Coast beats Winthrop: 0.605292'],
#  ['Wisconsin beats FL Gulf Coast: 0.884269'],
#  ['Xavier beats FL Gulf Coast: 0.856994'],
#  ['Florida beats Florida St: 0.504397'],
#  ['Gonzaga beats Florida: 0.640446'],
#  ['Florida beats Iona: 0.857561'],
#  ['Iowa St beats Florida: 0.548705'],
#  ['Florida beats Jacksonville St: 0.951220'],
#  ['Kansas beats Florida: 0.716128'],
#  ['Florida beats Kansas St: 0.609708'],
#  ['Florida beats Kent: 0.805748'],
#  ['Kentucky beats Florida: 0.729004'],
#  ['Louisville beats Florida: 0.607161'],
#  ['Florida beats Marquette: 0.561989'],
#  ['Florida beats Maryland: 0.601680'],
#  ['Florida beats Miami FL: 0.561782'],
#  ['Florida beats Michigan: 0.525798'],
#  ['Florida beats Michigan St: 0.646569'],
#  ['Florida beats Minnesota: 0.677816'],
#  ["Florida beats Mt St Mary's: 0.975004"],
#  ['Florida beats MTSU: 0.666594'],
#  ['Florida beats N Kentucky: 0.894502'],
#  ['Florida beats NC Central: 0.959017'],
#  ['Florida beats Nevada: 0.652169'],
#  ['Florida beats New Mexico St: 0.807599'],
#  ['Florida beats New Orleans: 0.964544'],
#  ['North Carolina beats Florida: 0.689976'],
#  ['Florida beats North Dakota: 0.939191'],
#  ['Florida beats Northwestern: 0.611254'],
#  ['Notre Dame beats Florida: 0.682481'],
#  ['Florida beats Oklahoma St: 0.543562'],
#  ['Oregon beats Florida: 0.607381'],
#  ['Florida beats Princeton: 0.818747'],
#  ['Florida beats Providence: 0.655755'],
#  ['Purdue beats Florida: 0.501642'],
#  ['Florida beats Rhode Island: 0.585531'],
#  ['Florida beats S Dakota St: 0.902208'],
#  ['Florida beats Seton Hall: 0.528744'],
#  ['SMU beats Florida: 0.563380'],
#  ['Florida beats South Carolina: 0.638096'],
#  ["Florida beats St Mary's CA: 0.513098"],
#  ['Florida beats Troy: 0.933633'],
#  ['Florida beats TX Southern: 0.938021'],
#  ['Florida beats UC Davis: 0.938687'],
#  ['UCLA beats Florida: 0.625265'],
#  ['Florida beats UNC Wilmington: 0.714685'],
#  ['Florida beats USC: 0.594335'],
#  ['Florida beats VA Commonwealth: 0.620628'],
#  ['Florida beats Vanderbilt: 0.713794'],
#  ['Florida beats Vermont: 0.826650'],
#  ['Villanova beats Florida: 0.733401'],
#  ['Virginia beats Florida: 0.611887'],
#  ['Florida beats Virginia Tech: 0.640720'],
#  ['Florida beats Wake Forest: 0.676357'],
#  ['West Virginia beats Florida: 0.703653'],
#  ['Wichita St beats Florida: 0.557973'],
#  ['Florida beats Winthrop: 0.918619'],
#  ['Wisconsin beats Florida: 0.509331'],
#  ['Florida beats Xavier: 0.551226'],
#  ['Gonzaga beats Florida St: 0.634090'],
#  ['Florida St beats Iona: 0.860886'],
#  ['Iowa St beats Florida St: 0.541888'],
#  ['Florida St beats Jacksonville St: 0.952480'],
#  ['Kansas beats Florida St: 0.710506'],
#  ['Florida St beats Kansas St: 0.616231'],
#  ['Florida St beats Kent: 0.810016'],
#  ['Kentucky beats Florida St: 0.723538'],
#  ['Louisville beats Florida St: 0.600584'],
#  ['Florida St beats Marquette: 0.568745'],
#  ['Florida St beats Maryland: 0.608251'],
#  ['Florida St beats Miami FL: 0.568539'],
#  ['Florida St beats Michigan: 0.532648'],
#  ['Florida St beats Michigan St: 0.652826'],
#  ['Florida St beats Minnesota: 0.683790'],
#  ["Florida St beats Mt St Mary's: 0.975665"],
#  ['Florida St beats MTSU: 0.672676'],
#  ['Florida St beats N Kentucky: 0.897069'],
#  ['Florida St beats NC Central: 0.960085'],
#  ['Florida St beats Nevada: 0.658380'],
#  ['Florida St beats New Mexico St: 0.811835'],
#  ['Florida St beats New Orleans: 0.965473'],
#  ['North Carolina beats Florida St: 0.684064'],
#  ['Florida St beats North Dakota: 0.940742'],
#  ['Florida St beats Northwestern: 0.617767'],
#  ['Notre Dame beats Florida St: 0.676493'],
#  ['Florida St beats Oklahoma St: 0.550375'],
#  ['Oregon beats Florida St: 0.600805'],
#  ['Florida St beats Princeton: 0.822792'],
#  ['Florida St beats Providence: 0.661934'],
#  ['Florida St beats Purdue: 0.505231'],
#  ['Florida St beats Rhode Island: 0.592187'],
#  ['Florida St beats S Dakota St: 0.904607'],
#  ['Florida St beats Seton Hall: 0.535589'],
#  ['SMU beats Florida St: 0.556606'],
#  ['Florida St beats South Carolina: 0.644421'],
#  ["Florida St beats St Mary's CA: 0.519964"],
#  ['Florida St beats Troy: 0.935317'],
#  ['Florida St beats TX Southern: 0.939601'],
#  ['Florida St beats UC Davis: 0.940250'],
#  ['UCLA beats Florida St: 0.618801'],
#  ['Florida St beats UNC Wilmington: 0.720258'],
#  ['Florida St beats USC: 0.600946'],
#  ['Florida St beats VA Commonwealth: 0.627080'],
#  ['Florida St beats Vanderbilt: 0.719378'],
#  ['Florida St beats Vermont: 0.830555'],
#  ['Villanova beats Florida St: 0.727991'],
#  ['Virginia beats Florida St: 0.605337'],
#  ['Florida St beats Virginia Tech: 0.647024'],
#  ['Florida St beats Wake Forest: 0.682346'],
#  ['West Virginia beats Florida St: 0.697887'],
#  ['Wichita St beats Florida St: 0.551181'],
#  ['Florida St beats Winthrop: 0.920651'],
#  ['Wisconsin beats Florida St: 0.502459'],
#  ['Florida St beats Xavier: 0.558017'],
#  ['Gonzaga beats Iona: 0.918630'],
#  ['Gonzaga beats Iowa St: 0.606651'],
#  ['Gonzaga beats Jacksonville St: 0.973380'],
#  ['Kansas beats Gonzaga: 0.573621'],
#  ['Gonzaga beats Kansas St: 0.745505'],
#  ['Gonzaga beats Kent: 0.886080'],
#  ['Kentucky beats Gonzaga: 0.589253'],
#  ['Gonzaga beats Louisville: 0.548176'],
#  ['Gonzaga beats Marquette: 0.706394'],
#  ['Gonzaga beats Maryland: 0.739075'],
#  ['Gonzaga beats Miami FL: 0.706219'],
#  ['Gonzaga beats Michigan: 0.675239'],
#  ['Gonzaga beats Michigan St: 0.774289'],
#  ['Gonzaga beats Minnesota: 0.797775'],
#  ["Gonzaga beats Mt St Mary's: 0.986512"],
#  ['Gonzaga beats MTSU: 0.789434'],
#  ['Gonzaga beats N Kentucky: 0.940826'],
#  ['Gonzaga beats NC Central: 0.977718'],
#  ['Gonzaga beats Nevada: 0.778558'],
#  ['Gonzaga beats New Mexico St: 0.887273'],
#  ['Gonzaga beats New Orleans: 0.980774'],
#  ['North Carolina beats Gonzaga: 0.542723'],
#  ['Gonzaga beats North Dakota: 0.966624'],
#  ['Gonzaga beats Northwestern: 0.746737'],
#  ['Notre Dame beats Gonzaga: 0.534072'],
#  ['Gonzaga beats Oklahoma St: 0.690699'],
#  ['Gonzaga beats Oregon: 0.547947'],
#  ['Gonzaga beats Princeton: 0.894408'],
#  ['Gonzaga beats Providence: 0.781278'],
#  ['Gonzaga beats Purdue: 0.650702'],
#  ['Gonzaga beats Rhode Island: 0.725959'],
#  ['Gonzaga beats S Dakota St: 0.945355'],
#  ['Gonzaga beats Seton Hall: 0.677826'],
#  ['Gonzaga beats SMU: 0.592378'],
#  ['Gonzaga beats South Carolina: 0.767778'],
#  ["Gonzaga beats St Mary's CA: 0.663984"],
#  ['Gonzaga beats Troy: 0.963476'],
#  ['Gonzaga beats TX Southern: 0.965963'],
#  ['Gonzaga beats UC Davis: 0.966339'],
#  ['Gonzaga beats UCLA: 0.529152'],
#  ['Gonzaga beats UNC Wilmington: 0.824472'],
#  ['Gonzaga beats USC: 0.733140'],
#  ['Gonzaga beats VA Commonwealth: 0.754158'],
#  ['Gonzaga beats Vanderbilt: 0.823839'],
#  ['Gonzaga beats Vermont: 0.899417'],
#  ['Villanova beats Gonzaga: 0.594657'],
#  ['Gonzaga beats Virginia: 0.543253'],
#  ['Gonzaga beats Virginia Tech: 0.769801'],
#  ['Gonzaga beats Wake Forest: 0.796697'],
#  ['West Virginia beats Gonzaga: 0.558742'],
#  ['Gonzaga beats Wichita St: 0.597668'],
#  ['Gonzaga beats Winthrop: 0.954887'],
#  ['Gonzaga beats Wisconsin: 0.643679'],
#  ['Gonzaga beats Xavier: 0.697268'],
#  ['Iowa St beats Iona: 0.878197'],
#  ['Iona beats Jacksonville St: 0.766812'],
#  ['Kansas beats Iona: 0.937342'],
#  ['Kansas St beats Iona: 0.791492'],
#  ['Kent beats Iona: 0.588413'],
#  ['Kentucky beats Iona: 0.941011'],
#  ['Louisville beats Iona: 0.901626'],
#  ['Marquette beats Iona: 0.822122'],
#  ['Maryland beats Iona: 0.796985'],
#  ['Miami FL beats Iona: 0.822245'],
#  ['Michigan beats Iona: 0.842473'],
#  ['Michigan St beats Iona: 0.764234'],
#  ['Minnesota beats Iona: 0.738131'],
#  ["Iona beats Mt St Mary's: 0.868033"],
#  ['MTSU beats Iona: 0.747856'],
#  ['Iona beats N Kentucky: 0.588448'],
#  ['Iona beats NC Central: 0.797822'],
#  ['Nevada beats Iona: 0.759774'],
#  ['New Mexico St beats Iona: 0.585536'],
#  ['Iona beats New Orleans: 0.821030'],
#  ['North Carolina beats Iona: 0.929565'],
#  ['Iona beats North Dakota: 0.722570'],
#  ['Northwestern beats Iona: 0.790417'],
#  ['Notre Dame beats Iona: 0.927252'],
#  ['Oklahoma St beats Iona: 0.832763'],
#  ['Oregon beats Iona: 0.901708'],
#  ['Princeton beats Iona: 0.567620'],
#  ['Providence beats Iona: 0.756870'],
#  ['Purdue beats Iona: 0.856510'],
#  ['Rhode Island beats Iona: 0.807603'],
#  ['Iona beats S Dakota St: 0.608729'],
#  ['Seton Hall beats Iona: 0.840898'],
#  ['SMU beats Iona: 0.884415'],
#  ['South Carolina beats Iona: 0.770815'],
#  ["St Mary's CA beats Iona: 0.849108"],
#  ['Iona beats Troy: 0.703467'],
#  ['Iona beats TX Southern: 0.718485'],
#  ['Iona beats UC Davis: 0.720806'],
#  ['UCLA beats Iona: 0.908211'],
#  ['UNC Wilmington beats Iona: 0.703032'],
#  ['USC beats Iona: 0.801884'],
#  ['VA Commonwealth beats Iona: 0.783777'],
#  ['Vanderbilt beats Iona: 0.703943'],
#  ['Vermont beats Iona: 0.554274'],
#  ['Villanova beats Iona: 0.942241'],
#  ['Virginia beats Iona: 0.903373'],
#  ['Virginia Tech beats Iona: 0.768798'],
#  ['Wake Forest beats Iona: 0.739419'],
#  ['West Virginia beats Iona: 0.933689'],
#  ['Wichita St beats Iona: 0.882152'],
#  ['Iona beats Winthrop: 0.655590'],
#  ['Wisconsin beats Iona: 0.860249'],
#  ['Xavier beats Iona: 0.828410'],
#  ['Iowa St beats Jacksonville St: 0.962655'],
#  ['Kansas beats Iowa St: 0.656169'],
#  ['Iowa St beats Kansas St: 0.673741'],
#  ['Iowa St beats Kent: 0.845755'],
#  ['Kentucky beats Iowa St: 0.670513'],
#  ['Louisville beats Iowa St: 0.539002'],
#  ['Iowa St beats Marquette: 0.629088'],
#  ['Iowa St beats Maryland: 0.666310'],
#  ['Iowa St beats Miami FL: 0.628892'],
#  ['Iowa St beats Michigan: 0.594440'],
#  ['Iowa St beats Michigan St: 0.707456'],
#  ['Iowa St beats Minnesota: 0.735522'],
#  ["Iowa St beats Mt St Mary's: 0.980975"],
#  ['Iowa St beats MTSU: 0.725496'],
#  ['Iowa St beats N Kentucky: 0.918088'],
#  ['Iowa St beats NC Central: 0.968685'],
#  ['Iowa St beats Nevada: 0.712520'],
#  ['Iowa St beats New Mexico St: 0.847297'],
#  ['Iowa St beats New Orleans: 0.972945'],
#  ['North Carolina beats Iowa St: 0.627366'],
#  ['Iowa St beats North Dakota: 0.953307'],
#  ['Iowa St beats Northwestern: 0.675169'],
#  ['Notre Dame beats Iowa St: 0.619193'],
#  ['Iowa St beats Oklahoma St: 0.611533'],
#  ['Oregon beats Iowa St: 0.539231'],
#  ['Iowa St beats Princeton: 0.856553'],
#  ['Iowa St beats Providence: 0.715755'],
#  ['Iowa St beats Purdue: 0.567707'],
#  ['Iowa St beats Rhode Island: 0.651262'],
#  ['Iowa St beats S Dakota St: 0.924217'],
#  ['Iowa St beats Seton Hall: 0.597287'],
#  ['Iowa St beats SMU: 0.506044'],
#  ['Iowa St beats South Carolina: 0.699765'],
#  ["Iowa St beats St Mary's CA: 0.582118"],
#  ['Iowa St beats Troy: 0.948970'],
#  ['Iowa St beats TX Southern: 0.952396'],
#  ['Iowa St beats UC Davis: 0.952914'],
#  ['UCLA beats Iowa St: 0.557960'],
#  ['Iowa St beats UNC Wilmington: 0.768047'],
#  ['Iowa St beats USC: 0.659482'],
#  ['Iowa St beats VA Commonwealth: 0.683799'],
#  ['Iowa St beats Vanderbilt: 0.767269'],
#  ['Iowa St beats Vermont: 0.863084'],
#  ['Villanova beats Iowa St: 0.675436'],
#  ['Virginia beats Iowa St: 0.543931'],
#  ['Iowa St beats Virginia Tech: 0.702151'],
#  ['Iowa St beats Wake Forest: 0.734222'],
#  ['West Virginia beats Iowa St: 0.642374'],
#  ['Iowa St beats Wichita St: 0.511531'],
#  ['Iowa St beats Winthrop: 0.937192'],
#  ['Iowa St beats Wisconsin: 0.560143'],
#  ['Iowa St beats Xavier: 0.618856'],
#  ['Kansas beats Jacksonville St: 0.981002'],
#  ['Kansas St beats Jacksonville St: 0.929093'],
#  ['Kent beats Jacksonville St: 0.831501'],
#  ['Kentucky beats Jacksonville St: 0.982163'],
#  ['Louisville beats Jacksonville St: 0.969360'],
#  ['Marquette beats Jacksonville St: 0.941016'],
#  ['Maryland beats Jacksonville St: 0.931276'],
#  ['Miami FL beats Jacksonville St: 0.941062'],
#  ['Michigan beats Jacksonville St: 0.948614'],
#  ['Michigan St beats Jacksonville St: 0.917959'],
#  ['Minnesota beats Jacksonville St: 0.906800'],
#  ["Jacksonville St beats Mt St Mary's: 0.655834"],
#  ['MTSU beats Jacksonville St: 0.911016'],
#  ['N Kentucky beats Jacksonville St: 0.707100'],
#  ['Jacksonville St beats NC Central: 0.533410'],
#  ['Nevada beats Jacksonville St: 0.916087'],
#  ['New Mexico St beats Jacksonville St: 0.829832'],
#  ['Jacksonville St beats New Orleans: 0.570636'],
#  ['North Carolina beats Jacksonville St: 0.978520'],
#  ['North Dakota beats Jacksonville St: 0.569950'],
#  ['Northwestern beats Jacksonville St: 0.928663'],
#  ['Notre Dame beats Jacksonville St: 0.977776'],
#  ['Oklahoma St beats Jacksonville St: 0.945020'],
#  ['Oregon beats Jacksonville St: 0.969387'],
#  ['Princeton beats Jacksonville St: 0.819215'],
#  ['Providence beats Jacksonville St: 0.914861'],
#  ['Purdue beats Jacksonville St: 0.953713'],
#  ['Rhode Island beats Jacksonville St: 0.935439'],
#  ['S Dakota St beats Jacksonville St: 0.689315'],
#  ['Seton Hall beats Jacksonville St: 0.948035'],
#  ['SMU beats Jacksonville St: 0.963520'],
#  ['South Carolina beats Jacksonville St: 0.920694'],
#  ["St Mary's CA beats Jacksonville St: 0.951038"],
#  ['Troy beats Jacksonville St: 0.592674'],
#  ['TX Southern beats Jacksonville St: 0.574916'],
#  ['UC Davis beats Jacksonville St: 0.572102'],
#  ['UCLA beats Jacksonville St: 0.971554'],
#  ['UNC Wilmington beats Jacksonville St: 0.890969'],
#  ['USC beats Jacksonville St: 0.933206'],
#  ['VA Commonwealth beats Jacksonville St: 0.925993'],
#  ['Vanderbilt beats Jacksonville St: 0.891392'],
#  ['Vermont beats Jacksonville St: 0.811050'],
#  ['Villanova beats Jacksonville St: 0.982551'],
#  ['Virginia beats Jacksonville St: 0.969944'],
#  ['Virginia Tech beats Jacksonville St: 0.919859'],
#  ['Wake Forest beats Jacksonville St: 0.907362'],
#  ['West Virginia beats Jacksonville St: 0.979840'],
#  ['Wichita St beats Jacksonville St: 0.962740'],
#  ...]

# %%
Finalpredictions=pd.DataFrame(readable)
Finalpredictions.to_csv("Finalpredictions.csv", index=False)
