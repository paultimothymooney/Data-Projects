# %% [markdown]
# **Poetry Generator (RNN Markov)**
# -- Paul Mooney, 12/12/2017

# %% [markdown]
# This scipt uses Recurrent Neural Networks and Markov Chains in order to generate new verses in the style of the poems that it is given as input.  Here we will generate new poems in the style of Dr. Seuss, Lil Wayne, and Kanye West.  We will also generate a new poem in the combined style of Dr Seuss, Lil Wayne, and Kanye West.

# %% [markdown]
# Here are the first 1000 characters from the collection of poems by Lil Wayne

# %%
artist_file = '../input/Lil_Wayne_20171210_B.txt'
with open(artist_file) as f: # The with keyword automatically closes the file when you are done
    print (f.read(1000))
# Out:
# I bought my first key from my baby momma brother
# I bought my first key
# Bought my bought my first key
# I bought my first key from my baby momma brother
# I bought my first key
# Bought my bought my first key
# Yeah hustling on my city streets
# Trying to get a whole key i bought my frist key my first key
# Inand we was getting em like for twenty five
# Colombian connect homey we was getting fly
# We on the grind and our nuts got bigga
# And every day we in the motherfucking hood our guns got bigga
# Stunting on them niggas getting money staying fly every day a nigga spending
# Riding s and we blazing getting high nigga showing off his ride
# Crusing through the beach nigga rolling in them bimmers
# Them people pull me over hating cause they cant see us
# Know I got the money laws wont leave me alone
# Now they acting funny cause they know a nigga strong
# Money long and we coming
# I bought my first key from my baby momma brother
# I bought my first key
# Bought my bought my first key
# I bought my first key from my baby mom

# %% [markdown]
# Here are the first 1000 characters from the collection of poems by Kanye West

# %%
artist_file = '../input/Kanye_West_20171210_D.txt'
with open(artist_file) as f: # The with keyword automatically closes the file when you are done
    print (f.read(1000))
# Out:
# Let the suicide doors up
# I threw suicides on the tour bus
# I threw suicides on the private jet
# You know what that mean, I'm fly to death
# I step in Def Jam buildin' like I'm the shit
# Tell 'em give me fifty million or I'ma quit
# Most rappers' taste level ain't at my waist level
# Turn up the bass 'til it's up-in-yo-face level
# Don't do no press but I get the most press kit
# Plus, yo, my bitch make your bitch look like Precious
# Somethin' 'bout Mary, she gone off that molly
# Now the whole party is melted like Dalí
# Now everybody is movin' they body
# Don't sell me apartment, I'll move in the lobby
# Niggas is loiterin' just to feel important
# You gon' see lawyers and niggas in Jordans
#
# She said, "'Ye, can we get married at the mall?"
# I said, "Look, you need to crawl 'fore you ball
# Come and meet me in the bathroom stall
# And show me why you deserve to have it all."
# (Ball so hard) That shit cray, ain't it Jay?
# What she order, fish filet?
# "Your whip so cold" – this old thing?
# Act like you'll ever be around

# %% [markdown]
# Here are the first 1000 characters from the collection of poems by Dr. Seuss

# %%
artist_file = '../input/Dr_Seuss_20171210_B.txt'
with open(artist_file) as f: # The with keyword automatically closes the file when you are done
    print (f.read(1000))
# Out:
# The Cat in the Hat
# By Dr. Seuss
# The sun did not shine.
# It was too wet to play.
# So we sat in the house
# All that cold cold wet day.
# I sat there with Sally.
# We sat there we two.
# And I said How I wish
# We had something to do!
# Too wet to go out
# And too cold to play ball.
# So we sat in the house.
# We did nothing at all.
# So all we could do was to
# Sit!
# Sit!
# Sit!
# Sit!
# And we did not like it.
# Not one little bit.
# BUMP!
# And then
# something went BUMP!
# How that bump made us jump!
# We looked!
# Then we saw him step in on the mat!
# We looked!
# And we saw him!
# The Cat in the Hat!
# And he said to us
# Why do you sit there like that?
# I know it is wet
# And the sun is not sunny.
# But we can have
# Lots of good fun that is funny!
# I know some good games we could play
# Said the cat.
# I know some new tricks
# Said the Cat in the Hat.
# A lot of good tricks.
# I will show them to you.
# Your mother
# Will not mind at all if I do.
# Then Sally and I
# Did not know what to say.
# Our mother was out of the house
# For the day.
# But our fish said No!

# %% [markdown]
# Plot word frequencies for .txt files

# %%
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline


def plotWordFrequency(input):
    f = open(artist_file,'r')
    words = [x for y in [l.split() for l in f.readlines()] for x in y]
    data = sorted([(w, words.count(w)) for w in set(words)], key = lambda x:x[1], reverse=True)[:40] 
    most_words = [x[0] for x in data]
    times_used = [int(x[1]) for x in data]
    #print(data)

    plt.figure(figsize=(20,10))
    plt.bar(x=sorted(most_words), height=times_used, color = 'grey', edgecolor = 'black',  width=.5)
    plt.xticks(rotation=45, fontsize=18)
    plt.yticks(rotation=0, fontsize=18)
    plt.xlabel('Most Common Words:', fontsize=18)
    plt.ylabel('Number of Occurences:', fontsize=18)
    plt.title('Most Commonly Used Words: %s' % (artist_file), fontsize=24)
    plt.show()

# %%
artist_file = '../input/Lil_Wayne_20171210_B.txt'
plotWordFrequency(artist_file)

# %%
artist_file = '../input/Kanye_West_20171210_D.txt'
plotWordFrequency(artist_file)

# %%
artist_file = '../input/Dr_Seuss_20171210_B.txt'
plotWordFrequency(artist_file)

# %% [markdown]
# Detailed word frequencies for .txt files

# %%
import re
from collections import Counter

print(" ")
print("Lil Wayne:")
print(" ")
with open('../input/Lil_Wayne_20171210_B.txt') as f:
    passage = f.read()
words = re.findall(r'\w+', passage)
cap_words = [word.upper() for word in words]
word_counts = Counter(cap_words)
print(word_counts)
print(" ")
# Out:
#
# Lil Wayne:
#
# Counter({'I': 977, 'THE': 741, 'A': 615, 'YOU': 556, 'AND': 541, 'MY': 426, 'IM': 402, 'TO': 349, 'LIKE': 339, 'IT': 315, 'THAT': 298, 'ME': 279, 'IN': 272, 'ON': 240, 'GOT': 200, 'BUT': 180, 'YOUR': 169, 'IS': 167, 'DONT': 158, 'WE': 153, 'OF': 153, 'AINT': 150, 'SHE': 149, 'SO': 136, 'UP': 135, 'WITH': 129, 'OUT': 126, 'NO': 126, 'FOR': 120, 'NIGGA': 119, 'GET': 118, 'THIS': 118, 'KNOW': 117, 'BOY': 113, 'THEY': 107, 'BITCH': 107, 'ITS': 106, 'YA': 105, 'DO': 104, 'MONEY': 102, 'HOT': 101, 'WHAT': 99, 'BE': 99, 'JUST': 98, 'BABY': 95, 'DA': 95, 'ALL': 90, 'THEM': 88, 'IF': 88, 'NOW': 86, 'NIGGAS': 80, 'HER': 79, 'SAY': 76, 'FUCK': 75, 'YEAH': 73, 'WAS': 73, 'SEE': 71, 'AT': 68, 'MAN': 66, 'THATS': 66, 'CAN': 64, 'THEN': 63, 'WHEN
, 'DIG': 15, 'WOULD': 15, 'DAT': 15, 'STOP': 15, 'ARE': 15, 'MOUTH': 15, 'ONLY': 15, 'DONE': 15, 'BAG': 15, 'NERVOUS': 15, 'HOOD': 14, 'LONG': 14, 'HOUSE': 14, 'CARTER': 14, 'LIVE': 14, 'TRYNA': 14, 'BOYS': 14, 'TA': 14, 'DROP': 14, 'BALLIN': 14, 'THING': 14, 'OWN': 13, 'WOMEN': 13, 'HOPE': 13, 'HANDS': 13, 'BEFORE': 13, 'ABOUT': 13, 'HATE': 13, 'IMA': 13, 'TOLD': 13, 'LIGHT': 13, 'STAY': 13, 'TURN': 13, 'WHOLE': 12, 'GETTING': 12, 'MOTHERFUCKING': 12, 'WORK': 12, 'SMOKE': 12, 'MACK': 12, 'WELL': 12, 'YES': 12, 'GROWN': 12, 'SOMEBODY': 12, 'LIGHTS': 12, 'OLD': 12, 'PLAY': 12, 'BRING': 12, 'TOP': 12, 'LOOKIN': 12, 'BLINDED': 12, 'TRYIN': 12, 'TRIED': 12, 'ALONE': 11, 'WEED': 11, 'DOG': 11, 'MEAN': 11, 'CUZ': 11, 'RED': 11, 'KILL': 11, 'DID': 11, 'HELL': 11, 'REAL': 11, 'END': 11, 'TALKIN': 11, 'HA': 11, 'PIMP': 11, 'UNDER': 11, 'LOT': 11, 'TOGETHER': 11, 'ALREADY': 11, 'DIE': 11, 'VERSE': 11, 'REALLY': 11, 'GOING': 11, 'MYSELF': 10, 'MUCH': 10, 'SHOUT': 10, 'WITHOUT': 10, 'NA': 10, 'CAMERA': 10, 'SIDE': 10, 'ALWAYS': 10, 'SHOOT': 10, 'CHECK': 10, 'MINE': 10, 'GOIN': 10, 'POP': 10, 'YOURE': 10, 'TAKIN': 10, 'TIGHT': 10, 'GUN': 10, 'SPIT': 10, 'BIZNESS': 10, 'JUMP': 10, 'STARTED': 9, 'FRESH': 9, 'TIL': 9, 'BREAK': 9, 'THANG': 9, 'LIE': 9, 'SAVE': 9, 'SIX': 9, 'SHOES': 9, 'SOMETIMES': 9, 'ACTION': 9, 'MIGHT': 9, ...

# %%
print(" ")
print("Kanye West:")
with open('../input/Kanye_West_20171210_D.txt') as f:
    passage = f.read()
words = re.findall(r'\w+', passage)
cap_words = [word.upper() for word in words]
word_counts = Counter(cap_words)
print(word_counts)
print(" ")
# Out:
#
# Kanye West:
# Counter({'I': 2593, 'THE': 2009, 'YOU': 1487, 'A': 1064, 'AND': 1027, 'TO': 1001, 'T': 827, 'THAT': 803, 'MY': 756, 'IT': 750, 'S': 699, 'IN': 661, 'ME': 607, 'M': 533, 'LIKE': 524, 'WE': 475, 'ON': 468, 'THEY': 425, 'YOUR': 385, 'SHE': 380, 'OF': 379, 'UP': 376, 'SO': 363, 'BUT': 362, 'ALL': 360, 'GOT': 354, 'WITH': 352, 'IS': 336, 'KNOW': 335, 'DON': 317, 'GET': 317, 'THIS': 294, 'NOW': 282, 'BE': 282, 'FOR': 279, 'JUST': 277, 'WHAT': 265, 'AIN': 
PLAY': 34, 'GAME': 34, 'MIGHT': 33, 'BUY': 33, 'WILL': 33, 'TWO': 33, 'SCHOOL': 33, 'THOUGH': 33, 'FLY': 32, 'WHITE': 32, 'HIGH': 32, 'SINCE': 32, 'CHI': 32, 'HELL': 32, 'COULDN': 32, 'TRYIN': 32, 'NEXT': 31, 'PLEASE': 31, 'CRAZY': 31, 'GETTING': 31, 'SOUL': 31, 'CAR': 31, 'FLOW': 31, 'NAME': 31, 'ACT': 30, 'OTHER': 30, 'HEY': 30, 'HOUSE': 30, 'TRYING': 30, 'STOP': 30, 'TOP': 30, 'BETTER': 30, 'DICK': 30, 'KANYE': 30, 'SEEN': 29, 'MAYBE': 29, 'JESUS': 29, 'HEARD': 29, 'WON': 29, 'DONE': 29, 'MAMA': 29, 'GOING': 28, 'WASN': 28, 'HOES': 28, 'FAMILY': 28, 'SOMEBODY': 28, 'HEAR': 28, 'FRIENDS': 28, 'TOOK': 28, 'YEARS': 28, 'ARE': 28, 'COLD': 27, 'AFTER': 27, 'REMEMBER': 27, 'THOUGHT': 27, 'STAY': 27, 'BENZ': 27, 'FUCKIN': 27, 'AM': 27, 'YEAR': 27, 'O': 27, 'BEAT': 27, 'GONE': 26, 'COOL': 26, 'HOMIE': 26, 'WENT': 26, 'FUCKING': 26, 'LEAVE': 26, 'BROKE': 26, 'WRONG': 26, 'RAP': 26, 'OWN': 26, 'REALIZE': 26, 'FACE': 25, 'LONG': 25, 'START': 25, 'ANOTHER': 25, 'DREAMS': 25, 'JAY': 24, 'FRESH': 24, 'NOBODY': 24, 'MIND': 24, 'HOT': 24, 'EYES': 24, 'LIGHT': 24, 'SWEAR': 24, 'WEST': 24, 'EXTRA': 24, 'DRIVE': 24, 'AWAY': 24, 'GAVE': 24, 'KILL': 23, 'MAD': 23, 'CLOTHES': 23, 'USED': 23, 'TALKIN': 23, 'ANY': 23, 'LEAST': 23, 'LIVE': 23, 'MANY': 23, 'DOG': 23, 'MA': 22, 'LOOKING': 22, 'MYSELF': 22, 'THROW': 22, 'MOTHERFUCKER': 22, 'LATE': 22, 'SAYING': 22, 'BLOW': 22, 'LOT': 22, 'WORK': 22, 'ENOUGH': 22, 'WISH': 22, 'WHILE': 22, 'MR': 22, 'FEELING': 21, 'ROCK': 21, 'CHAIN': 21, 'HEART': 21, 'C': 21, 'BRING': 21, 'TOWN': 21, 'CHECK': 21, 'KNEW': 21, 'PISS': 21, 'DRESS ...

# %%
##
print("Dr Seuss:")
with open('../input/Dr_Seuss_20171210_B.txt') as f:
    passage = f.read()
words = re.findall(r'\w+', passage)
cap_words = [word.upper() for word in words]
word_counts = Counter(cap_words)
print(word_counts)
####
# Out:
# Dr Seuss:
# %% [markdown]
# Here we use Recurrent Neural Networks and Markov chains to generate new lyrics in the style of the input text.
# The Markovify functions (Markov Chains) are used to build new sentences (based off of word1=>word2 probabilities), while the Keras.LSTM functions (Recurrent Neural Networks) are used to predict the properties of the next line of the poem (e.g. # syllables, rhyme scheme), such that an appropriate new sentence can be selected (from the setences that were generated with Markovify).

# %%
import pronouncing
import markovify
import re
import random
import numpy as np
import os
import keras
from keras.models import Sequential
from keras.layers import LSTM 
from keras.layers.core import Dense
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# Recurrent Neural Network (https://keras.io/layers/recurrent/#lstm)

# %%
def create_network(depth):
	model = Sequential()
	model.add(LSTM(4, input_shape=(2, 2), return_sequences=True))
	for i in range(depth):
		model.add(LSTM(8, return_sequences=True))
	model.add(LSTM(2, return_sequences=True))
	model.summary()
	model.compile(optimizer='rmsprop',
              loss='mse')

	if artist + ".rap" in os.listdir(".") and train_mode == False:
		model.load_weights(str(artist + ".rap"))
		print("loading saved network: " + str(artist) + ".rap") 
	return model

# %% [markdown]
# Markov Chain (https://github.com/jsvine/markovify)

# %%
def markov(text_file):
    ######
	read = open(text_file, "r", encoding='utf-8').read()
	text_model = markovify.NewlineText(read)
	return text_model

# %% [markdown]
# Determine number of syllables in line

# %%
def syllables(line):
	count = 0
	for word in line.split(" "):
		vowels = 'aeiouy'
		word = word.lower().strip(".:;?!")
		if word[0] in vowels:
			count +=1
		for index in range(1,len(word)):
			if word[index] in vowels and word[index-1] not in vowels:
				count +=1
		if word.endswith('e'):
			count -= 1
		if word.endswith('le'):
			count+=1
		if count == 0:
			count +=1
	return count / maxsyllables

# %% [markdown]
# Make index of words that rhyme with your word

# %%
def rhymeindex(lyrics):
	if str(artist) + ".rhymes" in os.listdir(".") and train_mode == False:
		print ("loading saved rhymes from " + str(artist) + ".rhymes")
		return open(str(artist) + ".rhymes", "r",encoding='utf-8').read().split("\n")
	else:
		rhyme_master_list = []
		print ("Building list of rhymes:")
		for i in lyrics:
			word = re.sub(r"\W+", '', i.split(" ")[-1]).lower()
			rhymeslist = pronouncing.rhymes(word)
			rhymeslistends = []      
			for i in rhymeslist:
				rhymeslistends.append(i[-2:])
			try:
				rhymescheme = max(set(rhymeslistends), key=rhymeslistends.count)
			except Exception:
				rhymescheme = word[-2:]
			rhyme_master_list.append(rhymescheme)
		rhyme_master_list = list(set(rhyme_master_list))
# 		print("rhyme_master_list:")
# 		print(rhyme_master_list)
		reverselist = [x[::-1] for x in rhyme_master_list]
# 		print("reverselist:")
# 		print(reverselist)
		reverselist = sorted(reverselist)
# 		print("reverselist-sorted:")
# 		print(reverselist)
		rhymelist = [x[::-1] for x in reverselist]
		print("List of Sorted 2-Letter Rhyme Ends:")
		print(rhymelist)
		f = open(str(artist) + ".rhymes", "w", encoding='utf-8')
		f.write("\n".join(rhymelist))
		f.close()
#		print(rhymelist)
		return rhymelist
#####

# %% [markdown]
# Make index of rhymes that you use

# %%
def rhyme(line, rhyme_list):
#	word = re.sub(r"\w+", '', line.split(" ")[-1]).lower()
	word = re.sub(r"\W+", '', line.split(" ")[-1]).lower()
	rhymeslist = pronouncing.rhymes(word)
#	rhymeslist = [x.encode('UTF8') for x in rhymeslist]
	rhymeslistends = []
	for i in rhymeslist:
		rhymeslistends.append(i[-2:])
	try:
		rhymescheme = max(set(rhymeslistends), key=rhymeslistends.count)
	except Exception:
		rhymescheme = word[-2:]
	try:
		float_rhyme = rhyme_list.index(rhymescheme)
		float_rhyme = float_rhyme / float(len(rhyme_list))
		return float_rhyme
	except Exception:
		float_rhyme = None
		return float_rhyme
#####

# %% [markdown]
# Separate each line of the input txt

# %%
def split_lyrics_file(text_file):
	text = open(text_file, encoding='utf-8').read()
	text = text.split("\n")
	while "" in text:
		text.remove("")
	return text

# %% [markdown]
# Generate lyrics

# %%
def generate_lyrics(text_model, text_file):
	bars = []
	last_words = []
	lyriclength = len(open(text_file,encoding='utf-8').read().split("\n"))
	count = 0
	markov_model = markov(text_file)
	
	while len(bars) < lyriclength / 9 and count < lyriclength * 2:
		bar = markov_model.make_sentence(max_overlap_ratio = .49, tries=100)

		if type(bar) != type(None) and syllables(bar) < 1:
			
			def get_last_word(bar):
				last_word = bar.split(" ")[-1]
				if last_word[-1] in "!.?,":
					last_word = last_word[:-1]
				return last_word
				
			last_word = get_last_word(bar)
			if bar not in bars and last_words.count(last_word) < 3:
				bars.append(bar)
				last_words.append(last_word)
				count += 1
	return bars

# %% [markdown]
# Build dataset

# %%
def build_dataset(lines, rhyme_list):
	dataset = []
	line_list = []
	for line in lines:
		line_list = [line, syllables(line), rhyme(line, rhyme_list)]
		dataset.append(line_list)
	
	x_data = []
	y_data = []
	
	for i in range(len(dataset) - 3):
		line1 = dataset[i    ][1:]
		line2 = dataset[i + 1][1:]
		line3 = dataset[i + 2][1:]
		line4 = dataset[i + 3][1:]

		x = [line1[0], line1[1], line2[0], line2[1]]
		x = np.array(x)
		x = x.reshape(2,2)
		x_data.append(x)

		y = [line3[0], line3[1], line4[0], line4[1]]
		y = np.array(y)
		y = y.reshape(2,2)
		y_data.append(y)
		
	x_data = np.array(x_data)
	y_data = np.array(y_data)
	
	#print "x shape " + str(x_data.shape)
	#print "y shape " + str(y_data.shape)
	return x_data, y_data

# %% [markdown]
# Compose verse

# %%
def compose_rap(lines, rhyme_list, lyrics_file, model):
	rap_vectors = []
	human_lyrics = split_lyrics_file(lyrics_file)
	
	initial_index = random.choice(range(len(human_lyrics) - 1))
	initial_lines = human_lyrics[initial_index:initial_index + 2]
	
	starting_input = []
	for line in initial_lines:
		starting_input.append([syllables(line), rhyme(line, rhyme_list)])

	starting_vectors = model.predict(np.array([starting_input]).flatten().reshape(1, 2, 2))
	rap_vectors.append(starting_vectors)
	
	for i in range(100):
		rap_vectors.append(model.predict(np.array([rap_vectors[-1]]).flatten().reshape(1, 2, 2)))
	
	return rap_vectors

# %% [markdown]
# Compose verse (part 2)

# %%
def vectors_into_song(vectors, generated_lyrics, rhyme_list):
	print ("\n\n")	
	print ("Writing verse:")
	print ("\n\n")
	def last_word_compare(rap, line2):
		penalty = 0 
		for line1 in rap:
			word1 = line1.split(" ")[-1]
			word2 = line2.split(" ")[-1]
			 
			while word1[-1] in "?!,. ":
				word1 = word1[:-1]
			
			while word2[-1] in "?!,. ":
				word2 = word2[:-1]
			
			if word1 == word2:
				penalty += 0.2
				
		return penalty

	def calculate_score(vector_half, syllables, rhyme, penalty):
		desired_syllables = vector_half[0]
		desired_rhyme = vector_half[1]
		desired_syllables = desired_syllables * maxsyllables
		desired_rhyme = desired_rhyme * len(rhyme_list)

		score = 1.0 - abs(float(desired_syllables) - float(syllables)) + abs(float(desired_rhyme) - float(rhyme)) - penalty

		return score

	dataset = []
	for line in generated_lyrics:
		line_list = [line, syllables(line), rhyme(line, rhyme_list)]
		dataset.append(line_list)
	
	rap = []
	
	vector_halves = []
	
	for vector in vectors:
		vector_halves.append(list(vector[0][0])) 
		vector_halves.append(list(vector[0][1]))
	
		
	for vector in vector_halves:
		scorelist = []
		for item in dataset:
			line = item[0]
			
			if len(rap) != 0:
				penalty = last_word_compare(rap, line)
			else:
				penalty = 0
			total_score = calculate_score(vector, item[1], item[2], penalty)
			score_entry = [line, total_score]
			scorelist.append(score_entry)
		
#
#		fixed_score_list = []
		fixed_score_list = [0]
		for score in scorelist:
			fixed_score_list.append(float(score[1]))
		max_score = max(fixed_score_list)
		for item in scorelist:
			if item[1] == max_score:
				rap.append(item[0])
				print (str(item[0]))
				
				for i in dataset:
					if item[0] == i[0]:
						dataset.remove(i)
						break
				break     
	return rap

# %% [markdown]
# Traning function

# %%
def train(x_data, y_data, model):
	model.fit(np.array(x_data), np.array(y_data),
			  batch_size=2,
			  epochs=3,
			  verbose=1)
	model.save_weights(artist + ".rap")

# %% [markdown]
# Train and run the model

# %%
def main(depth, train_mode):
	model = create_network(depth)

	text_model = markov(text_file)
	if train_mode == True:
		bars = split_lyrics_file(text_file)
	
	if train_mode == False:
		bars = generate_lyrics(text_model, text_file)
	
	rhyme_list = rhymeindex(bars)
	if train_mode == True:
		x_data, y_data = build_dataset(bars, rhyme_list)
		train(x_data, y_data, model)

	if train_mode == False:
		vectors = compose_rap(bars, rhyme_list, text_file, model)
        #
        #
		#print(vectors) 
       
		rap = vectors_into_song(vectors, bars, rhyme_list)
		f = open(rap_file, "w", encoding='utf-8')
		for bar in rap:
			f.write(bar)
			f.write("\n")

# %% [markdown]
# Some important parameters to keep in mind are as follows: (1) maxsyllables: max # of syllables per line; (2) max_overlap_ratio: how different the output should be from the original input; (3) tries: how many times to try to build a line that satisifies some parameter; (4) epochs: how mahy times for the NN to pass over the data.
#
# To reduce computational complexity, maximize (1) and (2) and minimize (3) and (4).
# Computational time will increase dramatically when (1) is less than 8 and when (2) is less than 0.5

# %%
# ####

depth = 4 # depth of the network. changing will require a retrain
maxsyllables = 8 # maximum syllables per line. Change this freely without retraining the network
artist = "artist"
rap_file = "temporary_poem.txt" # where the rap is written to

# %% [markdown]
# Write new lyrics in the style of Lil Wayne

# %%
text_file = "../input/Lil_Wayne_20171210_B.txt"
maxsyllables = 8

train_mode = True        
main(depth, train_mode)

train_mode = False
main(depth, train_mode)

##########
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 2, 4)              112
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 2, 8)              416
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 2, 8)              544
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 2, 8)              544
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 2, 8)              544
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 2, 2)              88
# =================================================================
# Total params: 2,248
# Trainable params: 2,248
# Non-trainable params: 0
# _________________________________________________________________
# Building list of rhymes:
# List of Sorted 2-Letter Rhyme Ends:
# ["s'", 'a', 'aa', 'ba', 'ca', 'da', 'ea', 'ga', 'ha', 'ia', 'ka', 'la', 'ma', 'na', 'ra', 'ta', 'va', 'ab', 'ub', 'ic', 'ad', 'ed', 'id', 'nd', 'od', 'rd', 'ud', 'wd', 'ce', 'de', 'ee', 'fe', 'ge', 'he', 'ie', 'ke', 'le', 'me', 'ne', 'pe', 're', 'se', 'te', 'ue', 've', 'ye', 'ze', 'ef', 'ff', 'lf', 'of', 'ag', 'bg', 'eg', 'gg', 'ig', 'ng', 'og', 'ug', 'wg', 'ah', 'ch', 'eh', 'hh', 'sh', 'th', 'uh', 'ai', 'bi', 'di', 'fi', 'gi', 'hi', 'ki', 'li', 'mi', 'ni', 'ri', 'ti', 'aj', 'dj', 'ck', 'ik', 'lk', 'nk', 'ok', 'rk', 'sk', 'al', 'el', 'll', 'rl', 'am', 'em', 'hm', 'im', 'mm', 'om', 'rm', 'um', 'an', 'en', 'in', 'on', 'pn', 'rn', 'un', 'wn', 'ao', 'co', 'do', 'go', 'io', 'ko', 'no', 'oo', 'ro', 'to', 'ap', 'ep', 'ip', 'lp', 'mp', 'op', 'pp', 'up', 'ar', 'er', 'or', 'ur', "'s", 'as', 'cs', 'ds', 'es', 'gs', 'hs', 'is', 'ks', 'ls', 'ms', 'ns', 'os', 'ps', 'rs', 'ss', 'ts', 'us', 'ws', 'ys', 'at', 'ct', 'dt', 'et', 'ft', 'ht', 'it', 'lt', 'nt', 'ot', 'pt', 'rt', 'st', 'tt', 'ut', 'au', 'ou', 'ov', 'aw', 'ew', 'ow', 'ex', 'ix', 'ay', 'by', 'cy', 'dy', 'ey', 'ky', 'ly', 'my', 'ny', 'oy', 'py', 'ry', 'sy', 'ty', 'vy', 'zy', 'az', 'ez', 'iz', 'lz', 'nz', 'tz']
# Epoch 1/3
# 3149/3149 [==============================] - 32s 10ms/step - loss: 0.2651
# Epoch 2/3
# 3149/3149 [==============================] - 31s 10ms/step - loss: 0.1964
# Epoch 3/3
# 3149/3149 [==============================] - 31s 10ms/step - loss: 0.1964
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 2, 4)              112
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 2, 8)              416
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 2, 8)              544
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 2, 2)              88
# =================================================================
# Total params: 2,248
# Trainable params: 2,248
# Non-trainable params: 0
# _________________________________________________________________
# Down on the scene on a Full moon
# Its crying for me me see me like a tooth gone
# Thats life to me right in the air
# If I had to wear those
# I see me I was choking
# Be on my dick like a shoe horn
# I dont like me I was airborne
# When they see me I got good luck
# My bitch got a full deck
# See what I wanna see the night
# Look what I can see by the light
# Yeah give me a big dog
# For me and Im a OG
# Im still the best to do this son
# And chicks I get it let me be the one
# Your so You know what we got the gun
# Girl I gotta get em high
# And Slim tell me bring it on down
# On the day I went to the grave
# Ya heard me I dont really no me
# Im where the fuck that nigga
# Now let me die in the right pond
# Imma take it when she call
# Trying to get to it yall
# Is how I see em I
# Trying to get to the VIP
# I see you with the life of the bus height
# Start with the rest of my car talk
# She know Im on my side prove
# Like I cant see me I got some
# But I put it back ma
# I thought I get my grind
# All the niggas put on the strip yup
# Tell me what to come home
# I want to see if my legs work
# Riding s and we made it this far
# Boy we do it for nothin
# Me and my goons to kill me here
# I take that shit but a deer
# My bitch got a bad river
# On the day I went to the locker
# And this the way you remember
# I do what you like ever
# You know I need a hammer
# And I dont know that paper
# Its crying for me me see the niggas wit the gear
# Well thats what show me to the inner
# Help I need is the ocean
# Ok I get out of breath
# Now let me be the judge
# And I see her on sight
# Phantom of the streets with the K why
# Bring it on a way fly
# Lay at the back and make me rape em
# Bitch I put it in your hands
# I take it in they titties
# She know Im on my Nikes
# And all you niggas is dogs
# Now she want to wake up ta the
# Please God dont let her see the bottom
# We was high in the bomb like
# You know what we was little
# Guess what we got the muscule
# Help I need is the flag
# Make harm in the hood a young man
# I dont want to see her again
# Thats life to me right in my Benz
# And you can see it in No Spoon
# I do but I just tell the cops
# I dont want to go back
# But I cant see me with a dip
# Let me be the judge if the kid aint right

# %% [markdown]
# Write new lyrics in the style of Kanye West

# %%
text_file = "../input/Kanye_West_20171210_D.txt"

maxsyllables = 8
train_mode = True        
main(depth, train_mode)

train_mode = False
main(depth, train_mode)

# # #lyrics = open("temporary_poem.txt", encoding='utf-8').read().split("\n") #this reads lines from a file called 'neural_rap.txt'
# # #print(lyrics)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 2, 4)              112
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 2, 8)              416
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 2, 2)              88
# =================================================================
# Total params: 2,248
# Trainable params: 2,248
# Non-trainable params: 0
# _________________________________________________________________
# Building list of rhymes:
# List of Sorted 2-Letter Rhyme Ends:
# ['', "s'", '10', '30', '1', '11', '31', '12', '32', 'k2', '4', '5', '05', '25', '45', '55', '26', 'g6', '7', '8', '9', '99', 'a', 'aa', 'ba', 'ca', 'da', 'ga', 'ha', 'ia', 'ja', 'ka', 'la', 'ma', 'na', 'pa', 'ra', 'sa', 'ta', 'va', 'ya', 'za', 'ab', 'eb', 'ib', 'ob', 'ub', 'ac', 'fc', 'ic', 'oc', 'ad', 'ed', 'id', 'ld', 'nd', 'od', 'rd', 'be', 'ce', 'de', 'ee', 'fe', 'ge', 'he', 'ie', 'ke', 'le', 'me', 'ne', 'oe', 'pe', 're', 'se', 'te', 've', 'ye', 'ze', 'af', 'ef', 'ff', 'if', 'lf', 'of', 'ag', 'eg', 'gg', 'ig', 'ng', 'og', 'rg', 'ug', 'ah', 'ch', 'gh', 'hh', 'oh', 'ph', 'sh', 'th', 'uh', 'ai', 'ci', 'gi', 'ii', 'ki', 'li', 'mi', 'ni', 'ri', 'ti', 'zi', 'pj', 'tj', 'ck', 'ek', 'lk', 'nk', 'ok', 'rk', 'sk', 'al', 'el', 'hl', 'il', 'll', 'ol', 'rl', 'tl', 'ul', 'xl', 'am', 'bm', 'em', 'im', 'lm', 'mm', 'om', 'rm', 'sm', 'um', 'an', 'en', 'gn', 'in', 'mn', 'nn', 'on', 'rn', 'un', 'wn', 'yn', 'ao', 'co', 'do', 'eo', 'fo', 'go', 'io', 'ko', 'lo', 'mo', 'no', 'oo', 'po', 'ro', 'to', 'vo', 'zo', 'ap', 'ep', 'ip', 'lp', 'mp', 'op', 'pp', 'rp', 'up', 'ar', 'cr', 'er', 'ir', 'jr', 'or', 'pr', 'rr', 'ur', "'s", '0s', 'as', 'bs', 'cs', 'ds', 'es', 'gs', 'hs', 'is', 'js', 'ks', 'ls', 'ms', 'ns', 'os', 'ps', 'rs', 'ss', 'ts', 'us', 'vs', 'ws', 'ys', 'és', 'at', 'ct', 'et', 'ft', 'ht', 'it', 'lt', 'nt', 'ot', 'pt', 'rt', 'st', 'tt', 'ut', 'au', 'cu', 'ru', 'uu', 'lv', 'ov', 'ew', 'lw', 'ow', 'ww', 'ax', 'ex', 'ix', 'ox', 'ay', 'by', 'cy', 'dy', 'ey', 'fy', 'gy', 'hy', 'ky', 'ly', 'my', 'ny', 'oy', 'ry', 'sy', 'ty', 'vy', 'zy', 'ez', 'iz', 'oz', 'tz', 'yz', 'zz', 'cé', 'né', 'lí']
# Epoch 1/3
# 6188/6188 [==============================] - 62s 10ms/step - loss: 0.2205
# Epoch 2/3
# 6188/6188 [==============================] - 60s 10ms/step - loss: 0.1780
# Epoch 3/3
# 6188/6188 [==============================] - 60s 10ms/step - loss: 0.1780
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_19 (LSTM)               (None, 2, 4)              112
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 2, 8)              416
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_24 (LSTM)               (None, 2, 2)              88
# =================================================================
# Total params: 2,248
# Trainable params: 2,248
# Non-trainable params: 0
# _________________________________________________________________
# loading saved network: artist.rap
# loading saved rhymes from artist.rhymes
#
#
#
# Writing verse:
#
#
#
# We just praying the new Slick Rick got the TV –“
# Yo, what you ask me to the models
# Treat me like Don C says she gave me the perfect 10
# She said I could make it past 25
# But as long as I'm in a 745
# We trying to come through with the CCA
# It'll go get your kids nigga
# I'm calling you the next saga
# They say I'm on your sofa
# Cause they don't see how I gotcha
# Back to school with no FEMA
# But I can't come through wanna
# This is what I know from the 312
# Don't let me hit you up like the crib
# Show you what to do in the club
# Got his own and he had that bad
# Bitch, is you talking to God
# What more could you be on at 7
# 20 Gs for the way that she 36-26, plus double-d
# And then you ain't even dead
# Got his own and he can't buy weed
# Cause I don't know me by my bed
# See, I just want you to be rude
# She got her back and smiled
# Let me show you the shit got cranked
# I know that you see the blood on the grind
# How I made it to me and said
# Fuck you and I ain't in the wo-rld
# I thought I had her in the mood
# Hey do you know it's frigid
# Activated, I'm back on the TV –“
# Some say he get what he is 3 years old
# The best in the end of the pool and
# You say you got a girlfriend
# But I know you got tanned
# Bitch I'm back up off the deep end
# More power to make it hood
# Got tracks to go, tell me what's good
# Cause they don't see that we couldn't afford
# Check out all the new Shabba
# We the cause of the day I play Kobe
# Yeah you got a new wardrobe
# Hate it when she do it for the night bae
# Then she said she ain't going back to the Chi
# And I don't know what's a black tie
# Whips with the groupies in the Benz with the lie
# But since they all up in the sky
# By the way I can see we done came
# You said you can't go home
# Things we see on the dress, you take the shame
# I'mma get you to be mine
# Made to make a movie scene
# So let it be more phony?
# Try to keep on my brain
# If God put you on Skype
# Fuck is you talking to God
# But I can't go to the floor
# Cause they don't want me by the shore
# So if he was a sophmore
# This the life of the store just froze
# If God put me on the Grey Goose
# Remind me of my best sense
# You know what you think, mami
# I put him all the way the beat
# Im bout to go and get
# Like it was the boss tonight
# But he just did the opposite
# You say he get what he is 3 years old
# And at the top is just the wave
# If we ain't safe in the Benz drive
# Now bring some more of the pool and
# You gonna be the day I play Kobe
# You see you in this existence
# That's the shit you can't tell if
# I'll show you the next saga
# Well I guess the money and the mac
# Fly, my swag and a knapsack
# She mad at me like Don C snapback
# You know I got the shit to rock
# What do it with a fishstick
# And look, tell me it was hurting me
# So next time I'm in a week
# Got me out my fucking self
# Pray for me to blame myself

# %% [markdown]
# Write new lyrics in the style of Dr. Seuss

# %%
maxsyllables = 8
text_file = "../input/Dr_Seuss_20171210_B.txt"

train_mode = True        
main(depth, train_mode)

train_mode = False
main(depth, train_mode)

#######
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_25 (LSTM)               (None, 2, 4)              112
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 2, 8)              416
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_28 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_29 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_30 (LSTM)               (None, 2, 2)              88
# =================================================================
# Total params: 2,248
# Trainable params: 2,248
# Non-trainable params: 0
# _________________________________________________________________
# Building list of rhymes:
# List of Sorted 2-Letter Rhyme Ends:
# ["s'", 'ea', 'ad', 'ed', 'id', 'ld', 'nd', 'od', 'de', 'ee', 'ke', 'le', 'me', 'ne', 're', 'se', 'te', 've', 'ig', 'ng', 'ch', 'sh', 'th', 'ai', 'ck', 'lk', 'nk', 'ok', 'rk', 'll', 'am', 'em', 'im', 'um', 'an', 'en', 'in', 'on', 'un', 'wn', 'ao', 'oo', 'ep', 'ip', 'lp', 'mp', 'op', 'pp', 'ar', 'er', 'ur', "'s", 'ds', 'es', 'gs', 'hs', 'ks', 'ms', 'ns', 'os', 'ps', 'rs', 'ss', 'ts', 'us', 'ys', 'at', 'it', 'nt', 'st', 'tt', 'ut', 'au', 'ew', 'ox', 'ay', 'ey', 'ny', 'ry']
# Epoch 1/3
# 1001/1001 [==============================] - 12s 12ms/step - loss: 0.2460
# Epoch 2/3
# 1001/1001 [==============================] - 10s 10ms/step - loss: 0.1210
# Epoch 3/3
# 1001/1001 [==============================] - 10s 10ms/step - loss: 0.1126
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_31 (LSTM)               (None, 2, 4)              112
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 2, 8)              416
# _________________________________________________________________
# lstm_33 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_34 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_35 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_36 (LSTM)               (None, 2, 2)              88
# =================================================================
# Total params: 2,248
# Trainable params: 2,248
# Non-trainable params: 0
# _________________________________________________________________
# loading saved network: artist.rap
# loading saved rhymes from artist.rhymes
#
#
#
# Writing verse:
#
#
#
# we see them come we see them come we see them come we see three.
# And I said to the chimney with glee.
# mixed up with the fan and the cake!
# Said the Cat in the dark! Not in the rain.
# Hop hop hop! I hop on the square.
# And so said the cat with a mouse.
# I will not like them in the house.
# And so said the cat with a goat
# Come down! We have a pet I bet
# Her gown with the Goo Goose is doing.
# And the fish in a puddle
# THIS is what the cat with a fish!
# Now we see them come we see them come we see them come we see three.
# Did you have to be found.
# You did not like them in the cake.
# THIS is what the cat with a hook.
# Said the Cat in the dark! Not in the dark!
# The tags! And the food up the tree!
# Down the wall in the dark! Not in the rain.
# Oh the noise! Oh the noise! Oh the things fall!
# Oh I like to hop on the wall!
# And he said That is what they call
# Would you like to hop on the ball!
# mixed up with the fan and the small
# But I like to hop on the square.
# The tags! And the cat with a mouse.
# Said the fish in the dark! Not in the house
# Her gown with the fan and the dish
# The more the Grinch I will try them.
# HE went to the cat with a goat!
# Her gown with the chicks and clocks come.
# Clocks on Knox on fox tick.
# I will not like this trick
# You get out of the box with the fan
# And he said to the chimney with glee.
# THREE TREE Three fish in the park in the hall.
# mixed up with the fan and the gown
# If you have to be found.
# Do you like to hop on the wall!
# Hop hop hop! I hop on the ball.
# Bump! Bump! Bump! Bump! Bump! Bump! Bump!
# And so said the cat with a bump
# He stood there on the top of Pop.
# THIS is what the cat with a mouse.
# The tags! And the food up the fish!
# The more the Grinch I will pick up
# HE went to the cat with a goat?
# Do you like to have fun
# But you have a little car.
# But you have a little star.
# THIS is what the cat with a sneer
# Socks on Knox on fox tick.
# Do you like to do now.
# Her gown with the chicks and clocks sir.
# And she said to the chimney with glee.
# SEE BEE THREE Now we see them come we see them come we see three.
# Her gown with the fan and the cake!
# Oh I like them in the dark.
# And the fish in a tree!
# Oh I like them in the rain?
# Her gown with the fan and the small
# Then he said to the cat with a fox.
# THIS is what the cat with a box.
# So I will not like them
# The tags! And the food up the cup
# Do you like to be found.
# All I like to hop on the wall!
# Her gown with the fan and the fish.
# Whod got out of the box with the dots
# Do you like to have fun.
# The tags! And the food up the Things
# Her gown with the fan and the strings
# Her gown with the fan and the gown
# And so said the cat with a sneer
# Her gown with the chicks and clocks sir
# Said the Cat in the dark! Not in the Hat
# Do you like to hop on the mat!
# And the fish in a house.
# But you have a little bit.
# If you have to be here.
# THREE TREE Three fish in the park in the dark?
# Said the Cat in the dark! Not in the pot.
# Oh I like to play ball.
# Bump! Bump! Bump! Bump! Bump! Bump!
# THIS is what the cat with a fox?
# They said How I like this?
# And I will not like them
# Blue goo. New goo. Blue goo. New goo.
# Then the Grinch I will not bite you.
# And we did not know what to do!
# And she said to the cat went away
# Say! I will not like it.
# The tags! And the food up the chimney!
# And I said to us fast.
# Oh I like to go out
# So we sat in the dark! Not in the Hat
# Would you like to hop on the mat!
# And the fish in a car?
# Did you have to be here.
# So we sat in the dark! Not in the pot.
# THIS is what the cat with a fox
# The more the Grinch I will show you
# And the fish in a box.
# They said How I like it
# Then he said to the cat.
# All I like to hop on the mat!
# New goo. Blue goo. New goo. Blue goo.
# You did not like them in the pot.
# And the Grinch I will not bite you.
# And the fish in a box?
# The tags! And the fish in the Hat.
# And I will not like it.

# %% [markdown]
# Write new lyrics in the combined style of Dr. Seues, Lil Wayne, and Kanye West

# %%
filenames = ['../input/Lil_Wayne_20171210_B.txt', '../input/Kanye_West_20171210_D.txt', '../input/Dr_Seuss_20171210_B.txt']
with open('combined.txt', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            for line in infile:
                outfile.write(line)

# %%
#artist_file = '../input/combined.txt'
artist_file = 'combined.txt'
plotWordFrequency(artist_file)

# %%
maxsyllables = 8
text_file = "combined.txt"

train_mode = True        
main(depth, train_mode)

train_mode = False
main(depth, train_mode)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_37 (LSTM)               (None, 2, 4)              112
# _________________________________________________________________
# lstm_38 (LSTM)               (None, 2, 8)              416
# _________________________________________________________________
# lstm_39 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_40 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_41 (LSTM)               (None, 2, 8)              544
# _________________________________________________________________
# lstm_42 (LSTM)               (None, 2, 2)              88
# =================================================================
# Total params: 2,248
# Trainable params: 2,248
# Non-trainable params: 0
# _________________________________________________________________
# Building list of rhymes:
# List of Sorted 2-Letter Rhyme Ends:
# ['', "s'", '10', '30', '1', '11', '31', '12', '32', 'k2', '4', '5', '05', '25', '45', '55', '26', 'g6', '7', '8', '9', '99', 'a', 'aa', 'ba', 'ca', 'da', 'ea', 'ga', 'ha', 'ia', 'ja', 'ka', 'la', 'ma', 'na', 'pa', 'ra', 'sa', 'ta', 'va', 'ya', 'za', 'ab', 'eb', 'ib', 'ob', 'ub', 'ac', 'fc', 'ic', 'oc', 'ad', 'ed', 'id', 'ld', 'nd', 'od', 'rd', 'ud', 'wd', 'be', 'ce', 'de', 'ee', 'fe', 'ge', 'he', 'ie', 'ke', 'le', 'me', 'ne', 'oe', 'pe', 're', 'se', 'te', 'ue', 've', 'ye', 'ze', 'af', 'ef', 'ff', 'if', 'lf', 'of', 'ag', 'bg', 'eg', 'gg', 'ig', 'ng', 'og', 'rg', 'ug', 'wg', 'ah', 'ch', 'eh', 'gh', 'hh', 'oh', 'ph', 'sh', 'th', 'uh', 'ai', 'bi', 'ci', 'di', 'fi', 'gi', 'hi', 'ii', 'ki', 'li', 'mi', 'ni', 'ri', 'ti', 'zi', 'aj', 'dj', 'pj', 'tj', 'ck', 'ek', 'ik', 'lk', 'nk', 'ok', 'rk', 'sk', 'al', 'el', 'hl', 'il', 'll', 'ol', 'rl', 'tl', 'ul', 'xl', 'am', 'bm', 'em', 'hm', 'im', 'lm', 'mm', 'om', 'rm', 'sm', 'um', 'an', 'en', 'gn', 'in', 'mn', 'nn', 'on', 'pn', 'rn', 'un', 'wn', 'yn', 'ao', 'co', 'do', 'eo', 'fo', 'go', 'io', 'ko', 'lo', 'mo', 'no', 'oo', 'po', 'ro', 'to', 'vo', 'zo', 'ap', 'ep', 'ip', 'lp', 'mp', 'op', 'pp', 'rp', 'up', 'ar', 'cr', 'er', 'ir', 'jr', 'or', 'pr', 'rr', 'ur', "'s", '0s', 'as', 'bs', 'cs', 'ds', 'es', 'gs', 'hs', 'is', 'js', 'ks', 'ls', 'ms', 'ns', 'os', 'ps', 'rs', 'ss', 'ts', 'us', 'vs', 'ws', 'ys', 'és', 'at', 'ct', 'dt', 'et', 'ft', 'ht', 'it', 'lt', 'nt', 'ot', 'pt', 'rt', 'st', 'tt', 'ut', 'au', 'cu', 'ou', 'ru', 'uu', 'lv', 'ov', 'aw', 'ew', 'lw', 'ow', 'ww', 'ax', 'ex', 'ix', 'ox', 'ay', 'by', 'cy', 'dy', 'ey', 'fy', 'gy', 'hy', 'ky', 'ly', 'my', 'ny', 'oy', 'py', 'ry', 'sy', 'ty', 'vy', 'zy', 'az', 'ez', 'iz', 'lz', 'nz', 'oz', 'tz', 'yz', 'zz', 'cé', 'né', 'lí']
# Epoch 1/3
# 10344/10344 [==============================] - 103s 10ms/step - loss: 0.1997
# Epoch 2/3
# 10344/10344 [==============================] - 97s 9ms/step - loss: 0.1745
# Epoch 3/3
# 10344/10344 [==============================] - 97s 9ms/step - loss: 0.1744
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm
# Is in the first time she had that shine
# Right now, I'm in his own lane
# What the hell could you be more Tony?
# Since my money on that lean
# How we would be a civil rights sign
# You cut me like a zebra
# They try to end up a tape
# About how I see you in the hype
# These bitches on me right in the store
# Why don't you kill me here to there.
# When you meet me in the front of the Louvre
# Living life like the fly on the square.
# Dawg, if I don't really care
# You need to put us in the air
# Yeah, he might have been that his shoes
# Well thats what we at a nun's house
# Cos she know a girl with a mouse?
# You see it in her Hampton blouse
# Thats life to live and then pose
# Try to say only God knows
# All the way she got that Slipknot loose
# Died inside of my best sense
# About how I call my spouse
# You leave your ass in reverse
# But I like this? We dont fuss fight
# They say I wish you could wait
# I'm tryna get in her throat
# And I take you to get weight
# Niggas hate me in my head, great
# Bitch I put my dick in the night
# Yeah, he might have to go in debt
# Yeah, we made it this the SorryThe Wait
# Talkin my shit, that's the way the beat
# Lot of shit but a hoe skeet skeet
# Asking me why the fuck right cook right
# From the bottom the bottom of the street
# This is what I gotta get
# You see I always tried to three peat
# When they see the way that they all hate
# By the way to rhyme with a goat!
# You cut me like I'm on 11
# Then the Grinch thought I had to move
# When I came with a new stove
# That's why I spit I get CL love
# Don't get it let me check your weave
# You know that you gotta leave
# You won't see it all on your grave
# Real nigga back to them Jazze
# Living life like a week off
# This is the end if I'm a wolf
# Straight up out my fucking self
# All I need a body bag
# That's enough Mr. West, Mr. West is the flag
# Just tell me what you got that Jag
# Begging one of my old swag
# And the flow that is why God
# Juelz why you want me at 11:26?
# Lo los wit the talk in the wo-rld
# Fuck you bitch got a taste
# Or you can get my grind
# Who was there when she call me Red.
# Crack my head up his sled
# Don't try to tell my momma
# As you can be a legend
# Im like what the fuck is you saying?
# Like she in school to be who I bang
# But we know where I stay stunting
# You remind me of me that she walking
# And all my bad bitch sweeping
# Just call me by now I'm driving
# From the place to go out to swing
# Don't let me go to the money long
# This is what I was grooving
# Just call me by now I'm crashing
# I'm in the house when it get going
# Should we tell her hop in the building
# I get it like its nothing
# I have my niggas ain't playing
# You fine and if I could
# Ohhh, why she says she gave me a big dog
# Uh, she cut it all gotta be bug
# I see her on a world tour ah
# If people don't like me, ha
# But I'm not a day in L.A
# But seem to get all in ya
# You don't see how I feel good yeah
# And look, tell me bring it back ma
# Fresh off the wall in the first place
# Go head and then we practice
# Now they say she love +Face+
# And we keep the heat get out of touch
# They dont make a nigga lunch
# Niggas cant see me on my low scrunch
# Why we can have it my way, bitch

# %% [markdown]
# Credit:
#
# This work was inspired by a Kaggle Kernel which uses Recurrent Neural Networks to generate new song lyrics one letter at a time (https://www.kaggle.com/jaderabbit/training-an-lstm-to-write-songs).  Many of the functions are adaptations from the following script:  https://github.com/robbiebarrat/rapping-neural-network.  For more information, see the following links:  http://www.emnlp2015.org/proceedings/EMNLP/pdf/EMNLP221.pdf and https://arxiv.org/pdf/1612.03205.pdf.

# %%
#experiment below

# %%
# maxsyllables = 6
# text_file = "combined.txt"

# train_mode = True        
# main(depth, train_mode)

# train_mode = False
# main(depth, train_mode)
