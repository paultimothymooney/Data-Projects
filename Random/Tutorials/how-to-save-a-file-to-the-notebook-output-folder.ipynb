# %% [markdown]
# # How to save a .CSV file to the output folder of your Kaggle notebook

# %% [markdown]
# *Step 1: Save the data to the working directory*

# %%
import pandas as pd
PHD_STIPENDS = pd.read_csv('/kaggle/input/phd-stipends/csv') # load from notebook input
PHD_STIPENDS.to_csv('/kaggle/working/phd_stipends.csv',index=False) # save to notebook output
PHD_STIPENDS.head(10)
# Out:
#                                     University  \
# 0                   City, University of London
# 1                   University of Warwick (UK)
# 2                         University of Oxford
# 3               Birkbeck, University of London
# 4                  Ohio State University (OSU)
# 5                    University of Birmingham
# 6                             Laval university
# 7  Massachusetts Institute of Technology (MIT)
# 8                          University of Tokyo
# 9                    University College London
#
#                             Department Overall Pay  LW Ratio Academic Year  \
# 0                          Mathematics     $16,000       NaN     2019-2020
# 1                            Chemistry     $19,685       NaN     2019-2020
# 2                            Chemistry     $19,700       NaN     2019-2020
# 3                  Biological sciences     $20,000       NaN     2014-2015
# 4  Electrical and Computer Engineering     $23,972      1.19     2019-2020
# 5         PhD metallurgy and Materials     $19,721       NaN     2018-2019
# 6                            Forestry      $18,000       NaN     2019-2020
# 7           Urban Studies and Planning     $24,500      0.88     2018-2019
# 8                    Computer Science      $36,000       NaN     2019-2020
# 9                              Physics     $22,336       NaN     2018-2019
#
#   Program Year 12 M Gross Pay 9 M Gross Pay 3 M Gross Pay    Fees  \
# 0          1st        $16,000           NaN           NaN     NaN
# 1          3rd        $19,685           NaN           NaN     NaN
# 2          3rd        $19,700           NaN           NaN     NaN
# 3          4th        $20,000           NaN           NaN     NaN
# 4          NaN            NaN       $18,729        $6,243  $1,000
# 5          1st        $19,721           NaN           NaN     NaN
# 6          3rd        $21,000           NaN           NaN  $3,000
# 7          2nd            NaN       $28,000           NaN  $3,500
# 8          3rd        $36,000           NaN           NaN     NaN
# 9          1st        $22,336           NaN           NaN     NaN
#
#                                             Comments
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  University covers 85% health insurance, I pay ...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# *Step 2: Download the data from the output folder of your Kaggle notebook*
# * Make sure you have committed your notebook
# * Open the notebook viewer by removing "/edit" from the URL
# * Click on the "output" tab and download your file

# %% [markdown]
# ![](https://i.imgur.com/3xdTfz8.png)
